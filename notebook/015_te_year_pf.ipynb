# %%
import os
import warnings
warnings.filterwarnings('ignore')
from typing import Any, Dict, List, Tuple
from pathlib import Path
import yaml
import pickle
import copy

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport # profile report を作る用
from matplotlib_venn import venn2 # venn図を作成する用
from tqdm import tqdm
from contextlib import contextmanager
from time import time

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_log_error, mean_squared_error
import lightgbm as lgb

from mykaggle.metric.mse import rmse
from mykaggle.util.ml_logger import MLLogger
from mykaggle.lib.lgbm_util import compute_importances, save_importances
from mykaggle.util.routine import fix_seed

sns.set_style('darkgrid')

# %%
settings = yaml.safe_load('''
name: '015_te_year_pf'
competition: atmacup8
seed: 1019
training:
    validation: 'group' 
    num_folds: 5
    num_rounds: 10000
    early_stopping_rounds: 1000
    verbose_eval: 20
lgbm_params:
    objective: regression
    learning_rate: 0.01
    max_depth: -1
    num_leaves: 31
    colsample_bytree: .7
    metric: "None"
''')
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fix_seed(settings['seed'])

# %%
datadir = Path('../data/')
ckptdir = Path('../ckpt/') / settings['name']
if not ckptdir.exists():
    ckptdir.mkdir()

# %%
df_train = pd.read_csv(datadir / 'id_train.csv')
df_test = pd.read_csv(datadir / 'id_test.csv')
df_submission = pd.read_csv(datadir / 'atmaCup8_sample-submission.csv')
df_train.shape, df_test.shape
# Out:
# ((8359, 17), (8360, 12))

# %%
# target の用意
target_columns = ['Global_Sales']
train_target_columns = target_columns + ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']

for c in train_target_columns:
    df_train.loc[:, 'mod_' + c] = df_train.loc[:, c].apply(lambda x: np.log1p(x))
df_train['target'] = df_train.loc[:, 'mod_Global_Sales']

# %%
df_base_train = df_train.loc[:, ['id']]
df_base_test = df_test.loc[:, ['id']]

train_others = {
    'main': df_train.copy(),
    'another': df_test.copy()
}
test_others = {
    'main': df_test.copy(),
    'another': df_train.copy(),
}

# %%
from mykaggle.feature.le import LE
from mykaggle.feature.score import Score
from mykaggle.feature.score_tbd import ScoreTBD
from mykaggle.feature.multi_platform import MultiPlatform
from mykaggle.feature.other_platforms import OtherPlatforms
from mykaggle.feature.ce import CE

# %%
le_train = LE(train=True)
le_test = LE(train=False)
score_train = Score(train=True)
score_test = Score(train=False)
score_tbd_train = ScoreTBD(train=True)
score_tbd_test = ScoreTBD(train=False)
mp_train = MultiPlatform(train=True)
mp_test = MultiPlatform(train=False)
op_train = OtherPlatforms(train=True)
op_test = OtherPlatforms(train=False)
ce_train = CE(train=True)
ce_test = CE(train=False)

# %%
df_f_train = df_base_train.copy()
df_f_test = df_base_test.copy()

df_f_train = le_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = le_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_tbd_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_tbd_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = mp_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = mp_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = op_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = op_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ce_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ce_test(df_f_test, others=test_others, use_cache=False, save_cache=True)

df_f_train.shape, df_f_test.shape
# Out:
# ((8359, 46), (8360, 46))

# %%
# drop some columns
df_f_train = df_f_train.drop(['le_Developer'], axis=1)
df_f_test = df_f_test.drop(['le_Developer'], axis=1)
df_f_train.shape, df_f_test.shape
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ((8359, 45), (8360, 45))

# %%
df_f_train.head(2)
# Out:
#    id  le_Platform  le_Genre  le_Rating  Critic_Score  User_Score  \
# 0   0           26         0          2          0.74        0.79
# 1   1           26         0          2          0.78        0.66
#
#    Critic_Count  User_Count  is_tbd  multi_pf_count  ...  other_platform_26  \
# 0          17.0        22.0   False               7  ...                  0
# 1          22.0        28.0   False               7  ...                  0
#
#    other_platform_27  other_platform_28  other_platform_29  other_platform_30  \
# 0                  0                  0                  1                  0
# 1                  0                  0                  1                  0
#
#    other_platform_31  count_id_groupby_Platform  count_id_groupby_Genre  \
# 0                  0                       1320                    3370
# 1                  0                       1320                    3370
#
#    count_id_groupby_Developer  count_id_groupby_Rating
# 0                        77.0                   1420.0
# 1                        77.0                   1420.0
#
# [2 rows x 45 columns]

# %%
@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mykaggle.feature.te import TE
from mykaggle.feature.te_year_platform import TEYearPlatform


te_train = TE(train=True)
te_test = TE(train=False)
te_yp_train = TEYearPlatform(train=True)
te_yp_test = TEYearPlatform(train=False)


def get_oof_feature(
    df_train: pd.DataFrame, df_valid: pd.DataFrame, y_train: np.ndarray,
    df_train_original: pd.DataFrame, df_valid_original: pd.DataFrame
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    df_train.loc[:, 'target'] = y_train.copy()
    _train_others = copy.deepcopy(train_others)
    _test_others = copy.deepcopy(test_others)
    _train_others['main'] = df_train_original.copy().reset_index().drop('index', axis=1)
    _train_others['another'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['main'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['another'] = df_train_original.copy().reset_index().drop('index', axis=1)
    df_train = df_train.reset_index().drop('index', axis=1)
    df_valid = df_valid.reset_index().drop('index', axis=1)
    df_train = te_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = te_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = te_yp_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = te_yp_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    return df_train.drop(['id', 'target'], axis=1), df_valid.drop('id', axis=1)

# %%
def train(
    settings: Dict[str, Any],
    logger: MLLogger,
    df: pd.DataFrame,
    df_original: pd.DataFrame,
    y: np.ndarray,
    ckptdir: Path
) -> Tuple:
    logger.log_params(settings['training'])
    logger.log_params(settings['lgbm_params'])
    X = df
    lgbm_params = settings['lgbm_params']
    models = []
    oof_pred = np.zeros_like(y, dtype=np.float)
    importances = pd.DataFrame()
    split_file = f'{settings["training"]["validation"]}_{settings["training"]["num_folds"]}fold.pkl'
    splits = pickle.load(open(datadir / split_file, 'rb'))

    for i, (train_idx, valid_idx) in enumerate(splits): 
        x_train, y_train = X.iloc[train_idx], y[train_idx]
        x_valid, y_valid = X.iloc[valid_idx], y[valid_idx]
        x_train, x_valid = get_oof_feature(
            x_train, x_valid, y_train,
            df_original.iloc[train_idx], df_original.iloc[valid_idx]
        )
        train_data = lgb.Dataset(x_train.values, label=y_train.astype(np.float32))
        valid_data = lgb.Dataset(x_valid.values, label=y_valid.astype(np.float32))

        with timer(prefix='train fold={} '.format(i + 1)):
            clf = lgb.train(
                lgbm_params,
                train_data, 
                num_boost_round=settings['training']['num_rounds'],
                valid_names=['train', 'valid'],
                valid_sets=[train_data, valid_data],  
                early_stopping_rounds=settings['training']['early_stopping_rounds'],
                feval=rmse,
                verbose_eval=settings['training']['verbose_eval']
            )
        pred_i = clf.predict(x_valid.values)
        oof_pred[valid_idx] = pred_i
        models.append(clf)
        importances = compute_importances(importances, x_train.columns, models[i], fold=i)
        fold_score = mean_squared_error(y_valid, pred_i) ** 0.5
        logger.log_metric(f'rmsle_fold_{i}', fold_score)
        print(f'Fold {i} RMSLE: {fold_score:.4f}')
        clf.save_model(str(ckptdir / f'model.txt'))
        logger.log_artifact(str(ckptdir / f'model.txt'), artifact_path=f'{i}')

    score = mean_squared_error(y, oof_pred) ** 0.5
    logger.log_metric(f'RMSLE', score)
    print('FINISHED; whole score: {:.4f}'.format(score))
    save_importances(importances, ckptdir)
    return oof_pred, models, score, importances

# %%
def predict(
    models: List[lgb.Booster],
    df_test: pd.DataFrame,
    df_train: pd.DataFrame,
    df_test_original: pd.DataFrame
) -> np.ndarray:
    '''
    fold 分のモデルと test の特徴 dataframe を受け取って、予測したものを返します。
    :param models: kfold 分のモデル
    :param test_df: test dataset の特徴
    :return: 予測
    '''
    _, test = get_oof_feature(
        df_train.copy(), df_test.copy(), df_train['target'].values, df_train.copy(), df_test_original.copy()
    )
    preds = np.array([model.predict(test) for model in models])
    preds = np.expm1(preds)
    preds = np.mean(preds, axis=0)
    return preds

    
def submit(preds: np.ndarray, ckptdir: Path) -> pd.DataFrame:
    '''
    test data の prediction を受け取って submission ファイルを作成します。
    :param preds: test data の予測
    :param ckptdir: 保存場所
    :return: submission df
    '''
    sub_df = pd.DataFrame({ 'Global_Sales': preds })
    sub_df.to_csv(ckptdir / f'{settings["name"]}.csv', index=False)
    return sub_df

# %%
logger = MLLogger('cfiken', ckptdir)

# %%
with logger.start(experiment_name=settings['competition'], run_name=settings['name']):
    oof, models, cv, importances = train(
        settings,
        logger,
        df_f_train,
        df_train,
        df_train.loc[:, 'target'].values,
        ckptdir
    )
    preds = predict(models, df_f_test, df_train, df_test)
    sub_df = submit(preds, ckptdir)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003061 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 984
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 37
# [LightGBM] [Info] Start training from score 3.008886
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.31301	valid's rmsle: 1.20199
# [40]	train's rmsle: 1.2311	valid's rmsle: 1.14245
# [60]	train's rmsle: 1.16863	valid's rmsle: 1.09892
# [80]	train's rmsle: 1.11977	valid's rmsle: 1.06731
# [100]	train's rmsle: 1.08212	valid's rmsle: 1.04458
# [120]	train's rmsle: 1.05275	valid's rmsle: 1.02589
# [140]	train's rmsle: 1.02853	valid's rmsle: 1.01079
# [160]	train's rmsle: 1.00986	valid's rmsle: 1.00079
# [180]	train's rmsle: 0.994191	valid's rmsle: 0.993117
# [200]	train's rmsle: 0.981489	valid's rmsle: 0.98743
# [220]	train's rmsle: 0.970527	valid's rmsle: 0.982204
# [240]	train's rmsle: 0.961016	valid's rmsle: 0.978608
# [260]	train's rmsle: 0.952669	valid's rmsle: 0.975958
# [280]	train's rmsle: 0.944948	valid's rmsle: 0.973559
# [300]	train's rmsle: 0.938378	valid's rmsle: 0.971539
# [320]	train's rmsle: 0.932507	valid's rmsle: 0.970327
# [340]	train's rmsle: 0.926799	valid's rmsle: 0.969261
# [360]	train's rmsle: 0.921508	valid's rmsle: 0.968091
# [380]	train's rmsle: 0.91663	valid's rmsle: 0.96735
# [400]	train's rmsle: 0.912416	valid's rmsle: 0.966616
# [420]	train's rmsle: 0.908382	valid's rmsle: 0.966037
# [440]	train's rmsle: 0.904638	valid's rmsle: 0.965599
# [460]	train's rmsle: 0.90099	valid's rmsle: 0.965078
# [480]	train's rmsle: 0.897586	valid's rmsle: 0.964587
# [500]	train's rmsle: 0.894405	valid's rmsle: 0.964314
# [520]	train's rmsle: 0.891352	valid's rmsle: 0.964465
# [540]	train's rmsle: 0.88867	valid's rmsle: 0.964207
# [560]	train's rmsle: 0.885926	valid's rmsle: 0.963974
# [580]	train's rmsle: 0.883195	valid's rmsle: 0.963973
# [600]	train's rmsle: 0.880849	valid's rmsle: 0.964054
# [620]	train's rmsle: 0.878433	valid's rmsle: 0.963983
# [640]	train's rmsle: 0.876176	valid's rmsle: 0.964005
# [660]	train's rmsle: 0.87401	valid's rmsle: 0.963924
# [680]	train's rmsle: 0.871708	valid's rmsle: 0.963693
# [700]	train's rmsle: 0.869439	valid's rmsle: 0.963575
# [720]	train's rmsle: 0.867448	valid's rmsle: 0.963281
# [740]	train's rmsle: 0.865323	valid's rmsle: 0.963065
# [760]	train's rmsle: 0.863253	valid's rmsle: 0.962991
# [780]	train's rmsle: 0.861053	valid's rmsle: 0.96313
# [800]	train's rmsle: 0.859001	valid's rmsle: 0.963272
# [820]	train's rmsle: 0.857036	valid's rmsle: 0.963307
# [840]	train's rmsle: 0.855121	valid's rmsle: 0.963344
# [860]	train's rmsle: 0.852922	valid's rmsle: 0.963463
# [880]	train's rmsle: 0.850661	valid's rmsle: 0.963948
# [900]	train's rmsle: 0.848638	valid's rmsle: 0.964253
# [920]	train's rmsle: 0.846864	valid's rmsle: 0.964474
# [940]	train's rmsle: 0.844928	valid's rmsle: 0.964643
# [960]	train's rmsle: 0.842964	valid's rmsle: 0.965108
# [980]	train's rmsle: 0.840694	valid's rmsle: 0.96553
# [1000]	train's rmsle: 0.838506	valid's rmsle: 0.96581
# [1020]	train's rmsle: 0.836848	valid's rmsle: 0.966189
# [1040]	train's rmsle: 0.834907	valid's rmsle: 0.96638
# [1060]	train's rmsle: 0.833188	valid's rmsle: 0.966503
# [1080]	train's rmsle: 0.831194	valid's rmsle: 0.966937
# [1100]	train's rmsle: 0.829276	valid's rmsle: 0.967599
# [1120]	train's rmsle: 0.827583	valid's rmsle: 0.967948
# [1140]	train's rmsle: 0.825731	valid's rmsle: 0.968356
# [1160]	train's rmsle: 0.824219	valid's rmsle: 0.968736
# [1180]	train's rmsle: 0.822559	valid's rmsle: 0.968957
# [1200]	train's rmsle: 0.820996	valid's rmsle: 0.969104
# [1220]	train's rmsle: 0.819362	valid's rmsle: 0.969157
# [1240]	train's rmsle: 0.817669	valid's rmsle: 0.969599
# [1260]	train's rmsle: 0.816056	valid's rmsle: 0.970047
# [1280]	train's rmsle: 0.814598	valid's rmsle: 0.970233
# [1300]	train's rmsle: 0.813121	valid's rmsle: 0.970476
# [1320]	train's rmsle: 0.811691	valid's rmsle: 0.970617
# [1340]	train's rmsle: 0.810351	valid's rmsle: 0.970668
# [1360]	train's rmsle: 0.808818	valid's rmsle: 0.97117
# [1380]	train's rmsle: 0.807367	valid's rmsle: 0.971203
# [1400]	train's rmsle: 0.805747	valid's rmsle: 0.971604
# [1420]	train's rmsle: 0.804155	valid's rmsle: 0.97169
# [1440]	train's rmsle: 0.802668	valid's rmsle: 0.971896
# [1460]	train's rmsle: 0.801235	valid's rmsle: 0.97213
# [1480]	train's rmsle: 0.799962	valid's rmsle: 0.972333
# [1500]	train's rmsle: 0.798556	valid's rmsle: 0.972464
# [1520]	train's rmsle: 0.79726	valid's rmsle: 0.972718
# [1540]	train's rmsle: 0.795925	valid's rmsle: 0.973068
# [1560]	train's rmsle: 0.794698	valid's rmsle: 0.973482
# [1580]	train's rmsle: 0.793402	valid's rmsle: 0.973723
# [1600]	train's rmsle: 0.792154	valid's rmsle: 0.974175
# [1620]	train's rmsle: 0.790946	valid's rmsle: 0.974334
# [1640]	train's rmsle: 0.789849	valid's rmsle: 0.974609
# [1660]	train's rmsle: 0.788717	valid's rmsle: 0.974929
# [1680]	train's rmsle: 0.787665	valid's rmsle: 0.975087
# [1700]	train's rmsle: 0.786516	valid's rmsle: 0.975149
# [1720]	train's rmsle: 0.78551	valid's rmsle: 0.975348
# [1740]	train's rmsle: 0.784571	valid's rmsle: 0.975352
# [1760]	train's rmsle: 0.7835	valid's rmsle: 0.975669
# Early stopping, best iteration is:
# [764]	train's rmsle: 0.862852	valid's rmsle: 0.962946
# train fold=1 11.360[s]
# Fold 0 RMSLE: 0.9629
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003592 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 978
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 37
# [LightGBM] [Info] Start training from score 2.941452
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.22347	valid's rmsle: 1.58862
# [40]	train's rmsle: 1.14931	valid's rmsle: 1.52965
# [60]	train's rmsle: 1.09214	valid's rmsle: 1.48524
# [80]	train's rmsle: 1.04744	valid's rmsle: 1.45106
# [100]	train's rmsle: 1.01252	valid's rmsle: 1.42661
# [120]	train's rmsle: 0.984749	valid's rmsle: 1.40425
# [140]	train's rmsle: 0.961927	valid's rmsle: 1.38478
# [160]	train's rmsle: 0.944201	valid's rmsle: 1.37087
# [180]	train's rmsle: 0.929567	valid's rmsle: 1.35862
# [200]	train's rmsle: 0.917176	valid's rmsle: 1.34838
# [220]	train's rmsle: 0.906687	valid's rmsle: 1.34054
# [240]	train's rmsle: 0.897545	valid's rmsle: 1.3325
# [260]	train's rmsle: 0.889501	valid's rmsle: 1.32649
# [280]	train's rmsle: 0.882398	valid's rmsle: 1.32159
# [300]	train's rmsle: 0.87586	valid's rmsle: 1.31632
# [320]	train's rmsle: 0.869888	valid's rmsle: 1.31206
# [340]	train's rmsle: 0.864491	valid's rmsle: 1.30842
# [360]	train's rmsle: 0.859375	valid's rmsle: 1.30493
# [380]	train's rmsle: 0.854769	valid's rmsle: 1.30274
# [400]	train's rmsle: 0.850329	valid's rmsle: 1.30027
# [420]	train's rmsle: 0.846357	valid's rmsle: 1.29822
# [440]	train's rmsle: 0.842487	valid's rmsle: 1.29652
# [460]	train's rmsle: 0.83883	valid's rmsle: 1.29485
# [480]	train's rmsle: 0.835535	valid's rmsle: 1.29349
# [500]	train's rmsle: 0.832248	valid's rmsle: 1.29252
# [520]	train's rmsle: 0.829248	valid's rmsle: 1.29138
# [540]	train's rmsle: 0.82613	valid's rmsle: 1.29069
# [560]	train's rmsle: 0.823399	valid's rmsle: 1.28973
# [580]	train's rmsle: 0.820794	valid's rmsle: 1.2888
# [600]	train's rmsle: 0.818235	valid's rmsle: 1.28786
# [620]	train's rmsle: 0.81588	valid's rmsle: 1.28718
# [640]	train's rmsle: 0.813337	valid's rmsle: 1.28659
# [660]	train's rmsle: 0.810872	valid's rmsle: 1.28595
# [680]	train's rmsle: 0.808641	valid's rmsle: 1.28542
# [700]	train's rmsle: 0.806268	valid's rmsle: 1.28461
# [720]	train's rmsle: 0.804137	valid's rmsle: 1.28435
# [740]	train's rmsle: 0.802107	valid's rmsle: 1.28353
# [760]	train's rmsle: 0.799982	valid's rmsle: 1.28318
# [780]	train's rmsle: 0.79786	valid's rmsle: 1.28267
# [800]	train's rmsle: 0.795842	valid's rmsle: 1.28221
# [820]	train's rmsle: 0.793924	valid's rmsle: 1.28189
# [840]	train's rmsle: 0.791897	valid's rmsle: 1.28145
# [860]	train's rmsle: 0.789948	valid's rmsle: 1.28125
# [880]	train's rmsle: 0.78801	valid's rmsle: 1.28078
# [900]	train's rmsle: 0.786015	valid's rmsle: 1.28058
# [920]	train's rmsle: 0.784216	valid's rmsle: 1.27978
# [940]	train's rmsle: 0.782219	valid's rmsle: 1.27955
# [960]	train's rmsle: 0.780333	valid's rmsle: 1.27919
# [980]	train's rmsle: 0.77852	valid's rmsle: 1.2789
# [1000]	train's rmsle: 0.776739	valid's rmsle: 1.27856
# [1020]	train's rmsle: 0.775005	valid's rmsle: 1.2783
# [1040]	train's rmsle: 0.773364	valid's rmsle: 1.27781
# [1060]	train's rmsle: 0.771566	valid's rmsle: 1.27746
# [1080]	train's rmsle: 0.76979	valid's rmsle: 1.27752
# [1100]	train's rmsle: 0.767976	valid's rmsle: 1.27725
# [1120]	train's rmsle: 0.766204	valid's rmsle: 1.27708
# [1140]	train's rmsle: 0.76459	valid's rmsle: 1.27706
# [1160]	train's rmsle: 0.763016	valid's rmsle: 1.27689
# [1180]	train's rmsle: 0.7614	valid's rmsle: 1.27688
# [1200]	train's rmsle: 0.759747	valid's rmsle: 1.27661
# [1220]	train's rmsle: 0.757944	valid's rmsle: 1.27652
# [1240]	train's rmsle: 0.756198	valid's rmsle: 1.27604
# [1260]	train's rmsle: 0.754713	valid's rmsle: 1.27612
# [1280]	train's rmsle: 0.753216	valid's rmsle: 1.27583
# [1300]	train's rmsle: 0.751658	valid's rmsle: 1.27558
# [1320]	train's rmsle: 0.750297	valid's rmsle: 1.27554
# [1340]	train's rmsle: 0.748935	valid's rmsle: 1.27547
# [1360]	train's rmsle: 0.747458	valid's rmsle: 1.27519
# [1380]	train's rmsle: 0.745942	valid's rmsle: 1.27489
# [1400]	train's rmsle: 0.744585	valid's rmsle: 1.27494
# [1420]	train's rmsle: 0.74335	valid's rmsle: 1.27515
# [1440]	train's rmsle: 0.741971	valid's rmsle: 1.27538
# [1460]	train's rmsle: 0.740593	valid's rmsle: 1.27528
# [1480]	train's rmsle: 0.739396	valid's rmsle: 1.2751
# [1500]	train's rmsle: 0.738134	valid's rmsle: 1.27508
# [1520]	train's rmsle: 0.736989	valid's rmsle: 1.27533
# [1540]	train's rmsle: 0.735756	valid's rmsle: 1.27546
# [1560]	train's rmsle: 0.734376	valid's rmsle: 1.27533
# [1580]	train's rmsle: 0.733033	valid's rmsle: 1.27513
# [1600]	train's rmsle: 0.731779	valid's rmsle: 1.27495
# [1620]	train's rmsle: 0.730633	valid's rmsle: 1.27504
# [1640]	train's rmsle: 0.729642	valid's rmsle: 1.27498
# [1660]	train's rmsle: 0.728519	valid's rmsle: 1.27526
# [1680]	train's rmsle: 0.727389	valid's rmsle: 1.27537
# [1700]	train's rmsle: 0.726265	valid's rmsle: 1.27531
# [1720]	train's rmsle: 0.725076	valid's rmsle: 1.27526
# [1740]	train's rmsle: 0.723927	valid's rmsle: 1.27537
# [1760]	train's rmsle: 0.722863	valid's rmsle: 1.27527
# [1780]	train's rmsle: 0.721799	valid's rmsle: 1.27526
# [1800]	train's rmsle: 0.720731	valid's rmsle: 1.27526
# [1820]	train's rmsle: 0.719631	valid's rmsle: 1.27536
# [1840]	train's rmsle: 0.718622	valid's rmsle: 1.27552
# [1860]	train's rmsle: 0.717537	valid's rmsle: 1.2756
# [1880]	train's rmsle: 0.716518	valid's rmsle: 1.2755
# [1900]	train's rmsle: 0.715356	valid's rmsle: 1.27564
# [1920]	train's rmsle: 0.714202	valid's rmsle: 1.27584
# [1940]	train's rmsle: 0.713128	valid's rmsle: 1.27608
# [1960]	train's rmsle: 0.712041	valid's rmsle: 1.27634
# [1980]	train's rmsle: 0.710962	valid's rmsle: 1.27636
# [2000]	train's rmsle: 0.709841	valid's rmsle: 1.27634
# [2020]	train's rmsle: 0.708697	valid's rmsle: 1.27634
# [2040]	train's rmsle: 0.707527	valid's rmsle: 1.27616
# [2060]	train's rmsle: 0.706515	valid's rmsle: 1.27612
# [2080]	train's rmsle: 0.705526	valid's rmsle: 1.27623
# [2100]	train's rmsle: 0.704545	valid's rmsle: 1.2761
# [2120]	train's rmsle: 0.703414	valid's rmsle: 1.27611
# [2140]	train's rmsle: 0.702333	valid's rmsle: 1.27613
# [2160]	train's rmsle: 0.701315	valid's rmsle: 1.27612
# [2180]	train's rmsle: 0.700357	valid's rmsle: 1.27608
# [2200]	train's rmsle: 0.699431	valid's rmsle: 1.27613
# [2220]	train's rmsle: 0.698382	valid's rmsle: 1.27612
# [2240]	train's rmsle: 0.697407	valid's rmsle: 1.27606
# [2260]	train's rmsle: 0.696559	valid's rmsle: 1.27609
# [2280]	train's rmsle: 0.695607	valid's rmsle: 1.27633
# [2300]	train's rmsle: 0.694639	valid's rmsle: 1.27631
# [2320]	train's rmsle: 0.693693	valid's rmsle: 1.27641
# [2340]	train's rmsle: 0.692634	valid's rmsle: 1.27639
# [2360]	train's rmsle: 0.691734	valid's rmsle: 1.27646
# [2380]	train's rmsle: 0.69075	valid's rmsle: 1.27646
# Early stopping, best iteration is:
# [1386]	train's rmsle: 0.745623	valid's rmsle: 1.27478
# train fold=2 15.129[s]
# Fold 1 RMSLE: 1.2748
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 992
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 38
# [LightGBM] [Info] Start training from score 3.100235
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.28672	valid's rmsle: 1.34057
# [40]	train's rmsle: 1.21084	valid's rmsle: 1.26954
# [60]	train's rmsle: 1.15213	valid's rmsle: 1.21605
# [80]	train's rmsle: 1.10562	valid's rmsle: 1.17488
# [100]	train's rmsle: 1.06923	valid's rmsle: 1.14297
# [120]	train's rmsle: 1.04026	valid's rmsle: 1.11776
# [140]	train's rmsle: 1.01711	valid's rmsle: 1.09868
# [160]	train's rmsle: 0.997738	valid's rmsle: 1.08324
# [180]	train's rmsle: 0.981626	valid's rmsle: 1.07169
# [200]	train's rmsle: 0.968328	valid's rmsle: 1.06313
# [220]	train's rmsle: 0.956942	valid's rmsle: 1.0562
# [240]	train's rmsle: 0.946762	valid's rmsle: 1.04973
# [260]	train's rmsle: 0.938149	valid's rmsle: 1.04495
# [280]	train's rmsle: 0.930591	valid's rmsle: 1.04133
# [300]	train's rmsle: 0.923991	valid's rmsle: 1.03875
# [320]	train's rmsle: 0.917683	valid's rmsle: 1.03657
# [340]	train's rmsle: 0.911906	valid's rmsle: 1.03445
# [360]	train's rmsle: 0.906576	valid's rmsle: 1.03313
# [380]	train's rmsle: 0.901749	valid's rmsle: 1.03175
# [400]	train's rmsle: 0.897411	valid's rmsle: 1.0309
# [420]	train's rmsle: 0.893236	valid's rmsle: 1.02978
# [440]	train's rmsle: 0.889271	valid's rmsle: 1.02884
# [460]	train's rmsle: 0.885604	valid's rmsle: 1.02818
# [480]	train's rmsle: 0.882142	valid's rmsle: 1.02773
# [500]	train's rmsle: 0.878779	valid's rmsle: 1.027
# [520]	train's rmsle: 0.875506	valid's rmsle: 1.02622
# [540]	train's rmsle: 0.872414	valid's rmsle: 1.02581
# [560]	train's rmsle: 0.869531	valid's rmsle: 1.02567
# [580]	train's rmsle: 0.866785	valid's rmsle: 1.02554
# [600]	train's rmsle: 0.864035	valid's rmsle: 1.02536
# [620]	train's rmsle: 0.86132	valid's rmsle: 1.02529
# [640]	train's rmsle: 0.85873	valid's rmsle: 1.02516
# [660]	train's rmsle: 0.85614	valid's rmsle: 1.02486
# [680]	train's rmsle: 0.853634	valid's rmsle: 1.02478
# [700]	train's rmsle: 0.851384	valid's rmsle: 1.02477
# [720]	train's rmsle: 0.849141	valid's rmsle: 1.02474
# [740]	train's rmsle: 0.847024	valid's rmsle: 1.02468
# [760]	train's rmsle: 0.844874	valid's rmsle: 1.02466
# [780]	train's rmsle: 0.842875	valid's rmsle: 1.02442
# [800]	train's rmsle: 0.840815	valid's rmsle: 1.02456
# [820]	train's rmsle: 0.838841	valid's rmsle: 1.02451
# [840]	train's rmsle: 0.836667	valid's rmsle: 1.02465
# [860]	train's rmsle: 0.834476	valid's rmsle: 1.02458
# [880]	train's rmsle: 0.832607	valid's rmsle: 1.02467
# [900]	train's rmsle: 0.830761	valid's rmsle: 1.02468
# [920]	train's rmsle: 0.828822	valid's rmsle: 1.02501
# [940]	train's rmsle: 0.826926	valid's rmsle: 1.02501
# [960]	train's rmsle: 0.825253	valid's rmsle: 1.02496
# [980]	train's rmsle: 0.82327	valid's rmsle: 1.0254
# [1000]	train's rmsle: 0.821485	valid's rmsle: 1.02566
# [1020]	train's rmsle: 0.819755	valid's rmsle: 1.02572
# [1040]	train's rmsle: 0.818116	valid's rmsle: 1.02559
# [1060]	train's rmsle: 0.816418	valid's rmsle: 1.02588
# [1080]	train's rmsle: 0.814692	valid's rmsle: 1.02618
# [1100]	train's rmsle: 0.813133	valid's rmsle: 1.0262
# [1120]	train's rmsle: 0.81152	valid's rmsle: 1.02638
# [1140]	train's rmsle: 0.80993	valid's rmsle: 1.02656
# [1160]	train's rmsle: 0.808509	valid's rmsle: 1.02686
# [1180]	train's rmsle: 0.807041	valid's rmsle: 1.02699
# [1200]	train's rmsle: 0.805571	valid's rmsle: 1.02713
# [1220]	train's rmsle: 0.804101	valid's rmsle: 1.02729
# [1240]	train's rmsle: 0.802639	valid's rmsle: 1.02739
# [1260]	train's rmsle: 0.801057	valid's rmsle: 1.02756
# [1280]	train's rmsle: 0.799712	valid's rmsle: 1.02754
# [1300]	train's rmsle: 0.798353	valid's rmsle: 1.02747
# [1320]	train's rmsle: 0.796899	valid's rmsle: 1.02771
# [1340]	train's rmsle: 0.795529	valid's rmsle: 1.02804
# [1360]	train's rmsle: 0.793733	valid's rmsle: 1.028
# [1380]	train's rmsle: 0.79236	valid's rmsle: 1.02818
# [1400]	train's rmsle: 0.79095	valid's rmsle: 1.02854
# [1420]	train's rmsle: 0.78951	valid's rmsle: 1.02876
# [1440]	train's rmsle: 0.788234	valid's rmsle: 1.02908
# [1460]	train's rmsle: 0.78688	valid's rmsle: 1.02924
# [1480]	train's rmsle: 0.785589	valid's rmsle: 1.0295
# [1500]	train's rmsle: 0.7842	valid's rmsle: 1.02989
# [1520]	train's rmsle: 0.782954	valid's rmsle: 1.03017
# [1540]	train's rmsle: 0.781706	valid's rmsle: 1.03033
# [1560]	train's rmsle: 0.780401	valid's rmsle: 1.03041
# [1580]	train's rmsle: 0.779155	valid's rmsle: 1.03058
# [1600]	train's rmsle: 0.777775	valid's rmsle: 1.03087
# [1620]	train's rmsle: 0.776475	valid's rmsle: 1.03109
# [1640]	train's rmsle: 0.775437	valid's rmsle: 1.03118
# [1660]	train's rmsle: 0.774135	valid's rmsle: 1.03136
# [1680]	train's rmsle: 0.772909	valid's rmsle: 1.03145
# [1700]	train's rmsle: 0.771565	valid's rmsle: 1.0315
# [1720]	train's rmsle: 0.77038	valid's rmsle: 1.03139
# [1740]	train's rmsle: 0.769111	valid's rmsle: 1.03158
# [1760]	train's rmsle: 0.767938	valid's rmsle: 1.03173
# Early stopping, best iteration is:
# [779]	train's rmsle: 0.842955	valid's rmsle: 1.0244
# train fold=3 11.244[s]
# Fold 2 RMSLE: 1.0244
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003070 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 969
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 37
# [LightGBM] [Info] Start training from score 3.116040
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.30965	valid's rmsle: 1.23128
# [40]	train's rmsle: 1.22864	valid's rmsle: 1.17249
# [60]	train's rmsle: 1.16637	valid's rmsle: 1.12975
# [80]	train's rmsle: 1.11786	valid's rmsle: 1.09909
# [100]	train's rmsle: 1.08026	valid's rmsle: 1.0765
# [120]	train's rmsle: 1.05066	valid's rmsle: 1.05951
# [140]	train's rmsle: 1.0266	valid's rmsle: 1.0473
# [160]	train's rmsle: 1.00765	valid's rmsle: 1.03906
# [180]	train's rmsle: 0.991222	valid's rmsle: 1.03274
# [200]	train's rmsle: 0.977139	valid's rmsle: 1.02777
# [220]	train's rmsle: 0.965624	valid's rmsle: 1.0238
# [240]	train's rmsle: 0.955856	valid's rmsle: 1.02116
# [260]	train's rmsle: 0.947495	valid's rmsle: 1.01908
# [280]	train's rmsle: 0.939734	valid's rmsle: 1.01717
# [300]	train's rmsle: 0.933115	valid's rmsle: 1.01553
# [320]	train's rmsle: 0.926881	valid's rmsle: 1.01442
# [340]	train's rmsle: 0.921243	valid's rmsle: 1.0136
# [360]	train's rmsle: 0.916178	valid's rmsle: 1.01297
# [380]	train's rmsle: 0.911475	valid's rmsle: 1.01272
# [400]	train's rmsle: 0.907239	valid's rmsle: 1.01206
# [420]	train's rmsle: 0.903223	valid's rmsle: 1.01151
# [440]	train's rmsle: 0.899626	valid's rmsle: 1.01116
# [460]	train's rmsle: 0.896029	valid's rmsle: 1.01049
# [480]	train's rmsle: 0.892534	valid's rmsle: 1.00978
# [500]	train's rmsle: 0.889127	valid's rmsle: 1.00918
# [520]	train's rmsle: 0.885844	valid's rmsle: 1.00853
# [540]	train's rmsle: 0.882793	valid's rmsle: 1.00813
# [560]	train's rmsle: 0.880082	valid's rmsle: 1.00792
# [580]	train's rmsle: 0.877662	valid's rmsle: 1.00751
# [600]	train's rmsle: 0.875218	valid's rmsle: 1.00701
# [620]	train's rmsle: 0.872664	valid's rmsle: 1.00697
# [640]	train's rmsle: 0.870105	valid's rmsle: 1.00673
# [660]	train's rmsle: 0.867707	valid's rmsle: 1.00632
# [680]	train's rmsle: 0.865314	valid's rmsle: 1.00609
# [700]	train's rmsle: 0.863113	valid's rmsle: 1.00582
# [720]	train's rmsle: 0.861005	valid's rmsle: 1.0056
# [740]	train's rmsle: 0.858612	valid's rmsle: 1.00532
# [760]	train's rmsle: 0.856576	valid's rmsle: 1.00521
# [780]	train's rmsle: 0.854554	valid's rmsle: 1.00483
# [800]	train's rmsle: 0.852495	valid's rmsle: 1.00488
# [820]	train's rmsle: 0.850408	valid's rmsle: 1.00461
# [840]	train's rmsle: 0.848465	valid's rmsle: 1.00451
# [860]	train's rmsle: 0.846432	valid's rmsle: 1.00425
# [880]	train's rmsle: 0.844571	valid's rmsle: 1.00426
# [900]	train's rmsle: 0.842717	valid's rmsle: 1.00408
# [920]	train's rmsle: 0.840796	valid's rmsle: 1.00392
# [940]	train's rmsle: 0.839076	valid's rmsle: 1.00381
# [960]	train's rmsle: 0.837399	valid's rmsle: 1.00382
# [980]	train's rmsle: 0.83568	valid's rmsle: 1.00375
# [1000]	train's rmsle: 0.833842	valid's rmsle: 1.00366
# [1020]	train's rmsle: 0.8323	valid's rmsle: 1.0037
# [1040]	train's rmsle: 0.830641	valid's rmsle: 1.00374
# [1060]	train's rmsle: 0.828959	valid's rmsle: 1.00395
# [1080]	train's rmsle: 0.827412	valid's rmsle: 1.0038
# [1100]	train's rmsle: 0.825614	valid's rmsle: 1.00369
# [1120]	train's rmsle: 0.823773	valid's rmsle: 1.00386
# [1140]	train's rmsle: 0.822176	valid's rmsle: 1.00389
# [1160]	train's rmsle: 0.820544	valid's rmsle: 1.00403
# [1180]	train's rmsle: 0.818941	valid's rmsle: 1.00419
# [1200]	train's rmsle: 0.81746	valid's rmsle: 1.0043
# [1220]	train's rmsle: 0.816095	valid's rmsle: 1.00456
# [1240]	train's rmsle: 0.81463	valid's rmsle: 1.00462
# [1260]	train's rmsle: 0.813151	valid's rmsle: 1.0047
# [1280]	train's rmsle: 0.811754	valid's rmsle: 1.00471
# [1300]	train's rmsle: 0.810219	valid's rmsle: 1.00493
# [1320]	train's rmsle: 0.808882	valid's rmsle: 1.00502
# [1340]	train's rmsle: 0.807199	valid's rmsle: 1.00511
# [1360]	train's rmsle: 0.805609	valid's rmsle: 1.00545
# [1380]	train's rmsle: 0.804152	valid's rmsle: 1.00549
# [1400]	train's rmsle: 0.802814	valid's rmsle: 1.00561
# [1420]	train's rmsle: 0.80135	valid's rmsle: 1.00566
# [1440]	train's rmsle: 0.799959	valid's rmsle: 1.0057
# [1460]	train's rmsle: 0.798544	valid's rmsle: 1.00555
# [1480]	train's rmsle: 0.797102	valid's rmsle: 1.0056
# [1500]	train's rmsle: 0.795713	valid's rmsle: 1.00558
# [1520]	train's rmsle: 0.794463	valid's rmsle: 1.00585
# [1540]	train's rmsle: 0.793082	valid's rmsle: 1.00612
# [1560]	train's rmsle: 0.792004	valid's rmsle: 1.00626
# [1580]	train's rmsle: 0.790882	valid's rmsle: 1.00635
# [1600]	train's rmsle: 0.789732	valid's rmsle: 1.00661
# [1620]	train's rmsle: 0.788711	valid's rmsle: 1.00672
# [1640]	train's rmsle: 0.787571	valid's rmsle: 1.00685
# [1660]	train's rmsle: 0.78648	valid's rmsle: 1.00709
# [1680]	train's rmsle: 0.785393	valid's rmsle: 1.00731
# [1700]	train's rmsle: 0.784298	valid's rmsle: 1.00742
# [1720]	train's rmsle: 0.783102	valid's rmsle: 1.00756
# [1740]	train's rmsle: 0.78201	valid's rmsle: 1.0077
# [1760]	train's rmsle: 0.780761	valid's rmsle: 1.00803
# [1780]	train's rmsle: 0.779689	valid's rmsle: 1.00807
# [1800]	train's rmsle: 0.778591	valid's rmsle: 1.00817
# [1820]	train's rmsle: 0.777512	valid's rmsle: 1.00822
# [1840]	train's rmsle: 0.776348	valid's rmsle: 1.00857
# [1860]	train's rmsle: 0.775337	valid's rmsle: 1.00874
# [1880]	train's rmsle: 0.77423	valid's rmsle: 1.00886
# [1900]	train's rmsle: 0.773055	valid's rmsle: 1.00905
# [1920]	train's rmsle: 0.771983	valid's rmsle: 1.00933
# [1940]	train's rmsle: 0.770802	valid's rmsle: 1.00944
# [1960]	train's rmsle: 0.769598	valid's rmsle: 1.00951
# [1980]	train's rmsle: 0.7685	valid's rmsle: 1.00965
# [2000]	train's rmsle: 0.767447	valid's rmsle: 1.00973
# [2020]	train's rmsle: 0.76632	valid's rmsle: 1.01004
# Early stopping, best iteration is:
# [1029]	train's rmsle: 0.831594	valid's rmsle: 1.00363
# train fold=4 12.928[s]
# Fold 3 RMSLE: 1.0036
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003428 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 6688, number of used features: 37
# [LightGBM] [Info] Start training from score 3.021148
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.30824	valid's rmsle: 1.21152
# [40]	train's rmsle: 1.22503	valid's rmsle: 1.14905
# [60]	train's rmsle: 1.16056	valid's rmsle: 1.1047
# [80]	train's rmsle: 1.11048	valid's rmsle: 1.0727
# [100]	train's rmsle: 1.0716	valid's rmsle: 1.05066
# [120]	train's rmsle: 1.04149	valid's rmsle: 1.03524
# [140]	train's rmsle: 1.01711	valid's rmsle: 1.02436
# [160]	train's rmsle: 0.998201	valid's rmsle: 1.01698
# [180]	train's rmsle: 0.982683	valid's rmsle: 1.01247
# [200]	train's rmsle: 0.969918	valid's rmsle: 1.00927
# [220]	train's rmsle: 0.959125	valid's rmsle: 1.00715
# [240]	train's rmsle: 0.94984	valid's rmsle: 1.00594
# [260]	train's rmsle: 0.941807	valid's rmsle: 1.00433
# [280]	train's rmsle: 0.934431	valid's rmsle: 1.00307
# [300]	train's rmsle: 0.92787	valid's rmsle: 1.00256
# [320]	train's rmsle: 0.921896	valid's rmsle: 1.00206
# [340]	train's rmsle: 0.916498	valid's rmsle: 1.00196
# [360]	train's rmsle: 0.911375	valid's rmsle: 1.00105
# [380]	train's rmsle: 0.906726	valid's rmsle: 1.00073
# [400]	train's rmsle: 0.902279	valid's rmsle: 1.00016
# [420]	train's rmsle: 0.898381	valid's rmsle: 0.999569
# [440]	train's rmsle: 0.894748	valid's rmsle: 0.999271
# [460]	train's rmsle: 0.891251	valid's rmsle: 0.99892
# [480]	train's rmsle: 0.888032	valid's rmsle: 0.99864
# [500]	train's rmsle: 0.884919	valid's rmsle: 0.99836
# [520]	train's rmsle: 0.881824	valid's rmsle: 0.998117
# [540]	train's rmsle: 0.878946	valid's rmsle: 0.997765
# [560]	train's rmsle: 0.8761	valid's rmsle: 0.997505
# [580]	train's rmsle: 0.873372	valid's rmsle: 0.997166
# [600]	train's rmsle: 0.870761	valid's rmsle: 0.996866
# [620]	train's rmsle: 0.868383	valid's rmsle: 0.996767
# [640]	train's rmsle: 0.865991	valid's rmsle: 0.99661
# [660]	train's rmsle: 0.863649	valid's rmsle: 0.996388
# [680]	train's rmsle: 0.861333	valid's rmsle: 0.996385
# [700]	train's rmsle: 0.85897	valid's rmsle: 0.996217
# [720]	train's rmsle: 0.856778	valid's rmsle: 0.996007
# [740]	train's rmsle: 0.854695	valid's rmsle: 0.995951
# [760]	train's rmsle: 0.852602	valid's rmsle: 0.995832
# [780]	train's rmsle: 0.85061	valid's rmsle: 0.995684
# [800]	train's rmsle: 0.848654	valid's rmsle: 0.995742
# [820]	train's rmsle: 0.846713	valid's rmsle: 0.995588
# [840]	train's rmsle: 0.844928	valid's rmsle: 0.995619
# [860]	train's rmsle: 0.843069	valid's rmsle: 0.995641
# [880]	train's rmsle: 0.841347	valid's rmsle: 0.995871
# [900]	train's rmsle: 0.839622	valid's rmsle: 0.995913
# [920]	train's rmsle: 0.83777	valid's rmsle: 0.996081
# [940]	train's rmsle: 0.835894	valid's rmsle: 0.995974
# [960]	train's rmsle: 0.834188	valid's rmsle: 0.995762
# [980]	train's rmsle: 0.832473	valid's rmsle: 0.995922
# [1000]	train's rmsle: 0.830735	valid's rmsle: 0.995935
# [1020]	train's rmsle: 0.829049	valid's rmsle: 0.995973
# [1040]	train's rmsle: 0.827417	valid's rmsle: 0.995976
# [1060]	train's rmsle: 0.825666	valid's rmsle: 0.996157
# [1080]	train's rmsle: 0.824124	valid's rmsle: 0.996588
# [1100]	train's rmsle: 0.822765	valid's rmsle: 0.9967
# [1120]	train's rmsle: 0.821219	valid's rmsle: 0.996812
# [1140]	train's rmsle: 0.819691	valid's rmsle: 0.997056
# [1160]	train's rmsle: 0.817968	valid's rmsle: 0.997215
# [1180]	train's rmsle: 0.816316	valid's rmsle: 0.997388
# [1200]	train's rmsle: 0.814821	valid's rmsle: 0.997555
# [1220]	train's rmsle: 0.813388	valid's rmsle: 0.997397
# [1240]	train's rmsle: 0.811815	valid's rmsle: 0.997315
# [1260]	train's rmsle: 0.810387	valid's rmsle: 0.997282
# [1280]	train's rmsle: 0.808863	valid's rmsle: 0.997237
# [1300]	train's rmsle: 0.80753	valid's rmsle: 0.997357
# [1320]	train's rmsle: 0.806288	valid's rmsle: 0.997356
# [1340]	train's rmsle: 0.804975	valid's rmsle: 0.997439
# [1360]	train's rmsle: 0.803613	valid's rmsle: 0.997489
# [1380]	train's rmsle: 0.802239	valid's rmsle: 0.997807
# [1400]	train's rmsle: 0.800819	valid's rmsle: 0.998261
# [1420]	train's rmsle: 0.79964	valid's rmsle: 0.998485
# [1440]	train's rmsle: 0.798413	valid's rmsle: 0.998646
# [1460]	train's rmsle: 0.797148	valid's rmsle: 0.998966
# [1480]	train's rmsle: 0.79609	valid's rmsle: 0.999062
# [1500]	train's rmsle: 0.794931	valid's rmsle: 0.999231
# [1520]	train's rmsle: 0.793685	valid's rmsle: 0.999244
# [1540]	train's rmsle: 0.792549	valid's rmsle: 0.999558
# [1560]	train's rmsle: 0.791376	valid's rmsle: 0.99999
# [1580]	train's rmsle: 0.790221	valid's rmsle: 1.00019
# [1600]	train's rmsle: 0.789123	valid's rmsle: 1.00062
# [1620]	train's rmsle: 0.788017	valid's rmsle: 1.0008
# [1640]	train's rmsle: 0.786838	valid's rmsle: 1.00111
# [1660]	train's rmsle: 0.785747	valid's rmsle: 1.00122
# [1680]	train's rmsle: 0.784793	valid's rmsle: 1.00138
# [1700]	train's rmsle: 0.783756	valid's rmsle: 1.00159
# [1720]	train's rmsle: 0.782574	valid's rmsle: 1.00167
# [1740]	train's rmsle: 0.781447	valid's rmsle: 1.00198
# [1760]	train's rmsle: 0.780361	valid's rmsle: 1.00212
# [1780]	train's rmsle: 0.779255	valid's rmsle: 1.00234
# [1800]	train's rmsle: 0.77811	valid's rmsle: 1.00264
# [1820]	train's rmsle: 0.777042	valid's rmsle: 1.00282
# Early stopping, best iteration is:
# [829]	train's rmsle: 0.845896	valid's rmsle: 0.995474
# train fold=5 10.920[s]
# Fold 4 RMSLE: 0.9955
# FINISHED; whole score: 1.0583
