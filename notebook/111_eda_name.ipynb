# %%
import os
import warnings
warnings.filterwarnings('ignore')
from typing import Any, Dict, List, Tuple
from pathlib import Path
import yaml

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport # profile report を作る用
from matplotlib_venn import venn2 # venn図を作成する用
from tqdm import tqdm
from contextlib import contextmanager
from time import time
from collections import Counter

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_log_error, mean_squared_error
import lightgbm as lgb

from mykaggle.metric.mse import rmsle
from mykaggle.util.ml_logger import MLLogger
from mykaggle.lib.lgbm_util import compute_importances, save_importances
from mykaggle.lib.pandas_util import change_column_name
from mykaggle.util.routine import fix_seed

sns.set_style('darkgrid')

# %%
settings = yaml.safe_load('''
name: '111_eda'
competition: atmacup8
seed: 1019
training:
    num_folds: 5
    num_rounds: 1000
    early_stopping_rounds: 100
    verbose_eval: 20
lgbm_params:
    objective: binary
    learning_rate: 0.05
    max_depth: -1
    num_leaves: 31
    colsample_bytree: .7
    metric: "None"
''')
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fix_seed(settings['seed'])

# %%
datadir = Path('../data/')
ckptdir = Path('../ckpt/') / settings['name']
if not ckptdir.exists():
    ckptdir.mkdir()

# %%
df_train = pd.read_csv(datadir / 'id_train.csv')
df_test = pd.read_csv(datadir / 'id_test.csv')
df_submission = pd.read_csv(datadir / 'atmaCup8_sample-submission.csv')
df_train.shape, df_test.shape
# Out:
# ((8359, 17), (8360, 12))

# %%
df_train.head().T
# Out:
#                                                       0  \
# Name                         LEGO Batman: The Videogame
# Platform                                            Wii
# Year_of_Release                                     NaN
# Genre                                            Action
# Publisher        Warner Bros. Interactive Entertainment
# NA_Sales                                            180
# EU_Sales                                             97
# JP_Sales                                              0
# Other_Sales                                          28
# Global_Sales                                        306
# Critic_Score                                         74
# Critic_Count                                         17
# User_Score                                          7.9
# User_Count                                           22
# Developer                             Traveller's Tales
# Rating                                             E10+
# id                                                    0
#
#                                                            1  \
# Name             LEGO Indiana Jones: The Original Adventures
# Platform                                                 Wii
# Year_of_Release                                          NaN
# Genre                                                 Action
# Publisher                                          LucasArts
# NA_Sales                                                 151
# EU_Sales                                                  61
# JP_Sales                                                   0
# Other_Sales                                               21
# Global_Sales                                             234
# Critic_Score                                              78
# Critic_Count                                              22
# User_Score                                               6.6
# User_Count                                                28
# Developer                                  Traveller's Tales
# Rating                                                  E10+
# id                                                         1
#
#                                                       2       3  \
# Name                         LEGO Batman: The Videogame  Combat
# Platform                                            PSP    2600
# Year_of_Release                                     NaN     NaN
# Genre                                            Action  Action
# Publisher        Warner Bros. Interactive Entertainment   Atari
# NA_Sales                                             56     117
# EU_Sales                                             44       7
# JP_Sales                                              0       0
# Other_Sales                                          27       1
# Global_Sales                                        128     125
# Critic_Score                                         73     NaN
# Critic_Count                                          5     NaN
# User_Score                                          7.4     NaN
# User_Count                                           10     NaN
# Developer                             Traveller's Tales     NaN
# Rating                                             E10+     NaN
# id                                                    2       3
#
#                                                       4
# Name                       LEGO Harry Potter: Years 5-7
# Platform                                            Wii
# Year_of_Release                                     NaN
# Genre                                            Action
# Publisher        Warner Bros. Interactive Entertainment
# NA_Sales                                             69
# EU_Sales                                             42
# JP_Sales                                              0
# Other_Sales                                          12
# Global_Sales                                        124
# Critic_Score                                         76
# Critic_Count                                          8
# User_Score                                          7.8
# User_Count                                           13
# Developer                             Traveller's Tales
# Rating                                             E10+
# id                                                    4

# %%
df_test.head().T
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                          0                            1  \
# Name             Hitman 2: Silent Assassin  Legacy of Kain: Soul Reaver
# Platform                                XB                           PS
# Year_of_Release                        NaN                          NaN
# Genre                               Action                       Action
# Publisher                Eidos Interactive            Eidos Interactive
# Critic_Score                            84                           91
# Critic_Count                            23                           17
# User_Score                               8                            9
# User_Count                              19                          132
# Developer                   Io Interactive             Crystal Dynamics
# Rating                                   M                            T
# id                                    8359                         8360
#
#                                              2                             3  \
# Name             Metal Gear Solid 2: Substance       Silent Hill: Homecoming
# Platform                                    XB                          X360
# Year_of_Release                            NaN                           NaN
# Genre                                   Action                        Action
# Publisher         Konami Digital Entertainment  Konami Digital Entertainment
# Critic_Score                                87                            70
# Critic_Count                                28                            54
# User_Score                                 8.5                           6.9
# User_Count                                  39                           180
# Developer                                 KCEJ            Double Helix Games
# Rating                                       M                             M
# id                                        8361                          8362
#
#                                             4
# Name                  Silent Hill: Homecoming
# Platform                                  PS3
# Year_of_Release                           NaN
# Genre                                  Action
# Publisher        Konami Digital Entertainment
# Critic_Score                               71
# Critic_Count                               41
# User_Score                                6.9
# User_Count                                143
# Developer                  Double Helix Games
# Rating                                      M
# id                                       8363

# %%
df_submission.head()
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Global_Sales
# 0     63.371815
# 1     63.371815
# 2     63.371815
# 3     63.371815
# 4     63.371815

# %%
train = df_train.copy()
test = df_test.copy()
train['is_test'] = False
test['is_test'] = True
whole = pd.concat([train, test])
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train_others = {
    'main': df_train.copy(),
    'another': df_test.copy()
}
test_others = {
    'main': df_test.copy(),
    'another': df_train.copy(),
}

# %% [markdown]
# # Platform x Year_of_Release

# %%
from mykaggle.feature.year_rank5 import YearRank5
year_rank_train = YearRank5(train=True)
year_rank_test = YearRank5(train=False)
train = year_rank_train(train, others=train_others, use_cache=False, save_cache=False)
test = year_rank_test(test, others=test_others, use_cache=False, save_cache=False)
whole = pd.concat([train, test])

# %%
whole.tail()
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                        Name Platform  Year_of_Release  \
# 8355         SD Gundam G Generation Genesis      PSV           2016.0
# 8356         SD Gundam G Generation Genesis      PS4           2016.0
# 8357                  Battle Worlds: Kronos       PC           2016.0
# 8358  Codename: Panzers Complete Collection       PC           2016.0
# 8359                 Imagine: Makeup Artist       DS           2020.0
#
#            Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 8355    Strategy  Namco Bandai Games       NaN       NaN       NaN
# 8356    Strategy  Namco Bandai Games       NaN       NaN       NaN
# 8357    Strategy        Nordic Games       NaN       NaN       NaN
# 8358    Strategy        Nordic Games       NaN       NaN       NaN
# 8359  Simulation             Ubisoft       NaN       NaN       NaN
#
#       Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 8355          NaN           NaN           NaN           NaN        NaN
# 8356          NaN           NaN           NaN           NaN        NaN
# 8357          NaN           NaN          71.0          15.0        7.1
# 8358          NaN           NaN           NaN           NaN        NaN
# 8359          NaN           NaN           NaN           NaN        tbd
#
#       User_Count Developer Rating     id  is_test  year_rank_rate  \
# 8355         NaN       NaN    NaN  16714     True        0.983471
# 8356         NaN       NaN    NaN  16715     True        0.987603
# 8357        71.0  KING Art    NaN  16716     True        0.991736
# 8358         NaN       NaN    NaN  16717     True        0.995868
# 8359         NaN   Ubisoft      E  16718     True        0.000000
#
#       year_rank_plus
# 8355     2016.983471
# 8356     2016.987603
# 8357     2016.991736
# 8358     2016.995868
# 8359     2020.000000

# %%
pf_to_yor = whole.groupby('Platform')['year_rank_plus'].agg(['min', 'max']).reset_index()
pf_to_yor.columns = ['Platform', 'platform_year_rank_min', 'platform_year_rank_max']
# pf_to_yor['publisher_term'] = pf_to_yor.loc[:, 'max'] - pf_to_yor.loc[:, 'min']
train = pd.merge(train, pf_to_yor, how='left', on='Platform')
train['diff_now_and_platform_min'] = train.loc[:, 'year_rank_plus'] - train.loc[:, 'platform_year_rank_min']
train['diff_now_and_platform_max'] = train.loc[:, 'platform_year_rank_max'] - train.loc[:, 'year_rank_plus']
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train.head()
# Out:
#                                           Name Platform  Year_of_Release  \
# 0                   LEGO Batman: The Videogame      Wii              NaN
# 1  LEGO Indiana Jones: The Original Adventures      Wii              NaN
# 2                   LEGO Batman: The Videogame      PSP              NaN
# 3                                       Combat     2600              NaN
# 4                 LEGO Harry Potter: Years 5-7      Wii              NaN
#
#     Genre                               Publisher  NA_Sales  EU_Sales  \
# 0  Action  Warner Bros. Interactive Entertainment       180        97
# 1  Action                               LucasArts       151        61
# 2  Action  Warner Bros. Interactive Entertainment        56        44
# 3  Action                                   Atari       117         7
# 4  Action  Warner Bros. Interactive Entertainment        69        42
#
#    JP_Sales  Other_Sales  Global_Sales  ...          Developer  Rating id  \
# 0         0           28           306  ...  Traveller's Tales    E10+  0
# 1         0           21           234  ...  Traveller's Tales    E10+  1
# 2         0           27           128  ...  Traveller's Tales    E10+  2
# 3         0            1           125  ...                NaN     NaN  3
# 4         0           12           124  ...  Traveller's Tales    E10+  4
#
#    is_test year_rank_rate year_rank_plus  platform_year_rank_min  \
# 0    False            NaN            NaN             2006.000000
# 1    False            NaN            NaN             2006.000000
# 2    False            NaN            NaN             2004.039604
# 3    False            NaN            NaN             1980.000000
# 4    False            NaN            NaN             2006.000000
#
#    platform_year_rank_max  diff_now_and_platform_min  \
# 0             2016.458678                        NaN
# 1             2016.458678                        NaN
# 2             2015.388158                        NaN
# 3             1989.500000                        NaN
# 4             2016.458678                        NaN
#
#    diff_now_and_platform_max
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# # Sales 順で見る

# %%
train['Publisher'].value_counts().head(20)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# THQ                                       715
# Nintendo                                  706
# Sony Computer Entertainment               687
# Sega                                      638
# Take-Two Interactive                      422
# Capcom                                    386
# Atari                                     367
# Tecmo Koei                                348
# Warner Bros. Interactive Entertainment    235
# Square Enix                               234
# Disney Interactive Studios                218
# Microsoft Game Studios                    191
# 505 Games                                 191
# D3Publisher                               184
# Vivendi Games                             164
# Idea Factory                              133
# Nippon Ichi Software                      106
# Majesco Entertainment                      92
# LucasArts                                  90
# Bethesda Softworks                         76
# Name: Publisher, dtype: int64

# %%
test['Publisher'].value_counts().head(20)
# Out:
# Electronic Arts                 1356
# Activision                       985
# Namco Bandai Games               939
# Ubisoft                          933
# Konami Digital Entertainment     834
# Unknown                          201
# Midway Games                     198
# Eidos Interactive                198
# Acclaim Entertainment            186
# Codemasters                      150
# Deep Silver                      121
# Zoo Digital Publishing           104
# Rising Star Games                 87
# Hudson Soft                       81
# 5pb                               62
# Infogrames                        62
# Virgin Interactive                62
# Empire Interactive                53
# PQube                             45
# GT Interactive                    45
# Name: Publisher, dtype: int64

# %%
train.sort_values('Global_Sales', ascending=False).head(20)
# Out:
#                                               Name Platform  Year_of_Release  \
# 3588                                    Wii Sports      Wii           2006.0
# 170                              Super Mario Bros.      NES           1985.0
# 4725                                Mario Kart Wii      Wii           2008.0
# 5593                             Wii Sports Resort      Wii           2009.0
# 594                       Pokemon Red/Pokemon Blue       GB           1996.0
# 214                                         Tetris       GB           1989.0
# 3390                         New Super Mario Bros.       DS           2006.0
# 3331                                      Wii Play      Wii           2006.0
# 5352                     New Super Mario Bros. Wii      Wii           2009.0
# 164                                      Duck Hunt      NES           1984.0
# 3075                                    Nintendogs       DS           2005.0
# 2960                                 Mario Kart DS       DS           2005.0
# 1039                   Pokemon Gold/Pokemon Silver       GB           1999.0
# 4169                                       Wii Fit      Wii           2007.0
# 5943                            Kinect Adventures!     X360           2010.0
# 5594                                  Wii Fit Plus      Wii           2009.0
# 7229                            Grand Theft Auto V      PS3           2013.0
# 2272                 Grand Theft Auto: San Andreas      PS2           2004.0
# 226                              Super Mario World     SNES           1990.0
# 2825  Brain Age: Train Your Brain in Minutes a Day       DS           2005.0
#
#              Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 3588        Sports                Nintendo      4136      2896       377
# 170       Platform                Nintendo      2908       358       681
# 4725        Racing                Nintendo      1568      1276       379
# 5593        Sports                Nintendo      1561      1093       328
# 594   Role-Playing                Nintendo      1127       889      1022
# 214         Puzzle                Nintendo      2320       225       422
# 3390      Platform                Nintendo      1128       914       650
# 3331          Misc                Nintendo      1396       918       293
# 5352      Platform                Nintendo      1444       694       470
# 164        Shooter                Nintendo      2693        63        28
# 3075    Simulation                Nintendo       905      1095       193
# 2960        Racing                Nintendo       971       747       413
# 1039  Role-Playing                Nintendo       900       618       720
# 4169        Sports                Nintendo       892       802       360
# 5943          Misc  Microsoft Game Studios      1500       488        24
# 5594        Sports                Nintendo       901       849       252
# 7229        Action    Take-Two Interactive       702       909        98
# 2272        Action    Take-Two Interactive       943        40        41
# 226       Platform                Nintendo      1278       375       354
# 2825          Misc                Nintendo       474       919       416
#
#       Other_Sales  Global_Sales  ...            Developer  Rating    id  \
# 3588          844          8253  ...             Nintendo       E  3588
# 170            77          4024  ...                  NaN     NaN   170
# 4725          329          3552  ...             Nintendo       E  4725
# 5593          295          3277  ...             Nintendo       E  5593
# 594           100          3137  ...                  NaN     NaN   594
# 214            57          3026  ...                  NaN     NaN   214
# 3390          288          2980  ...             Nintendo       E  3390
# 3331          284          2892  ...             Nintendo       E  3331
# 5352          224          2832  ...             Nintendo       E  5352
# 164            47          2831  ...                  NaN     NaN   164
# 3075          274          2467  ...                  NaN     NaN  3075
# 2960          190          2321  ...             Nintendo       E  2960
# 1039           71          2310  ...                  NaN     NaN  1039
# 4169          215          2270  ...             Nintendo       E  4169
# 5943          169          2181  ...  Good Science Studio       E  5943
# 5594          177          2179  ...             Nintendo       E  5594
# 7229          396          2104  ...       Rockstar North       M  7229
# 2272         1057          2081  ...       Rockstar North       M  2272
# 226            55          2061  ...                  NaN     NaN   226
# 2825          204          2014  ...             Nintendo       E  2825
#
#       is_test year_rank_rate year_rank_plus  platform_year_rank_min  \
# 3588    False       0.864706    2006.864706             2006.000000
# 170     False       0.222222    1985.222222             1983.428571
# 4725    False       0.602721    2008.602721             2006.000000
# 5593    False       0.827586    2009.827586             2006.000000
# 594     False       0.500000    1996.500000             1988.363636
# 214     False       0.285714    1989.285714             1988.363636
# 3390    False       0.476471    2006.476471             1985.111111
# 3331    False       0.360784    2006.360784             2006.000000
# 5352    False       0.481322    2009.481322             2006.000000
# 164     False       0.555556    1984.555556             1983.428571
# 3075    False       0.847134    2005.847134             1985.111111
# 2960    False       0.602972    2005.602972             1985.111111
# 1039    False       0.512987    1999.512987             1988.363636
# 4169    False       0.819200    2007.819200             2006.000000
# 5943    False       0.356589    2010.356589             2005.057325
# 5594    False       0.829023    2009.829023             2006.000000
# 7229    False       0.000000    2013.000000             2006.033333
# 2272    False       0.000000    2004.000000             2000.009662
# 226     False       0.153846    1990.153846             1990.076923
# 2825    False       0.316348    2005.316348             1985.111111
#
#       platform_year_rank_max  diff_now_and_platform_min  \
# 3588             2016.458678                   0.864706
# 170              1994.608108                   1.793651
# 4725             2016.458678                   2.602721
# 5593             2016.458678                   3.827586
# 594              2001.945701                   8.136364
# 214              2001.945701                   0.922078
# 3390             2020.000000                  21.365359
# 3331             2016.458678                   0.360784
# 5352             2016.458678                   3.481322
# 164              1994.608108                   1.126984
# 3075             2020.000000                  20.736023
# 2960             2020.000000                  20.491861
# 1039             2001.945701                  11.149351
# 4169             2016.458678                   1.819200
# 5943             2016.962810                   5.299264
# 5594             2016.458678                   3.829023
# 7229             2016.954545                   6.966667
# 2272             2011.944144                   3.990338
# 226              1999.954545                   0.076923
# 2825             2020.000000                  20.205237
#
#       diff_now_and_platform_max
# 3588                   9.593972
# 170                    9.385886
# 4725                   7.855957
# 5593                   6.631091
# 594                    5.445701
# 214                   12.659987
# 3390                  13.523529
# 3331                  10.097893
# 5352                   6.977356
# 164                   10.052553
# 3075                  14.152866
# 2960                  14.397028
# 1039                   2.432714
# 4169                   8.639478
# 5943                   6.606221
# 5594                   6.629655
# 7229                   3.954545
# 2272                   7.944144
# 226                    9.800699
# 2825                  14.683652
#
# [20 rows x 24 columns]

# %% [markdown]
# # Name を見る

# %%
names = whole.loc[:, 'Name'].values
names

# %%
def preprocess(x: str) -> str:
    x = x.replace(',', '')
    x = x.replace(':', ' ')
    x = x.replace(', ', ' ')
    x = x.replace('!', ' ')
    x = x.replace('\'s', ' ')
    x = x.replace('  ', ' ')

    return x.lower()

whole['processed_name'] = whole.loc[:, 'Name'].astype(str).apply(preprocess)

# %%
pd.DataFrame(whole['processed_name'].unique(), columns=['processed_name'])

# %%
from sklearn.feature_extraction.text import CountVectorizer

vec1 = CountVectorizer()
res1 = vec1.fit_transform(whole['processed_name'].unique())
vec2 = CountVectorizer(ngram_range=(2, 2))
res2 = vec2.fit_transform(whole['processed_name'].unique())
vec3 = CountVectorizer(ngram_range=(2, 4))
res3 = vec3.fit_transform(whole['processed_name'].unique())

# %%
word_1gram_cnt = res1.toarray().sum(axis=0)
word_1gram_cnt.shape

# %%
np.array(vec1.get_feature_names())[word_1gram_cnt > 100].shape, np.array(vec1.get_feature_names())[word_1gram_cnt > 100]

# %%
word_2gram_cnt = res2.toarray().sum(axis=0)
word_2gram_cnt.shape

# %%
Counter(word_1gram_cnt).most_common()

# %%
Counter(word_2gram_cnt).most_common()

# %%
words1 = np.array(vec1.get_feature_names())[word_1gram_cnt > 150]
len(words1), words1

# %%
words2 = np.array(vec2.get_feature_names())[word_2gram_cnt > 100]
len(words2), words2

# %%
word_2_4_gram_cnt = res3.toarray().sum(axis=0)
word_2_4_gram_cnt.shape

# %%
words3 = np.array(vec3.get_feature_names())[word_2_4_gram_cnt > 5]
len(words3), words3

# %%
test = res3.toarray()[:, word_2_4_gram_cnt > 5]

# %%
test.shape

# %%
whole[whole['processed_name'].str.contains('dragon')]

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
pca = PCA(4)
pca_feature = pca.fit_transform(res3.toarray()[:, word_2_4_gram_cnt > 5])

# %%
pca_feature.shape

# %%
TSNE(2)

# %%
from mykaggle.feature.name_tfidf import NameTfidf
name_tfidf = NameTfidf()
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
name_tfidf(train, train_others)
# Out:
#                                                   Name Platform  \
# 0                           LEGO Batman: The Videogame      Wii
# 1          LEGO Indiana Jones: The Original Adventures      Wii
# 2                           LEGO Batman: The Videogame      PSP
# 3                                               Combat     2600
# 4                         LEGO Harry Potter: Years 5-7      Wii
# ...                                                ...      ...
# 8354                                         Stellaris       PC
# 8355                 Total War Attila: Tyrants & Kings       PC
# 8356                  Brothers Conflict: Precious Baby      PSV
# 8357  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 8358  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
#
#       Year_of_Release         Genre                               Publisher  \
# 0                 NaN        Action  Warner Bros. Interactive Entertainment
# 1                 NaN        Action                               LucasArts
# 2                 NaN        Action  Warner Bros. Interactive Entertainment
# 3                 NaN        Action                                   Atari
# 4                 NaN        Action  Warner Bros. Interactive Entertainment
# ...               ...           ...                                     ...
# 8354           2016.0      Strategy                     Paradox Interactive
# 8355           2016.0      Strategy                              Koch Media
# 8356           2017.0        Action                            Idea Factory
# 8357           2017.0  Role-Playing                                    Sega
# 8358           2017.0  Role-Playing                                    Sega
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  ...  \
# 0          180        97         0           28           306  ...
# 1          151        61         0           21           234  ...
# 2           56        44         0           27           128  ...
# 3          117         7         0            1           125  ...
# 4           69        42         0           12           124  ...
# ...        ...       ...       ...          ...           ...  ...
# 8354         0         4         0            0             4  ...
# 8355         0         1         0            0             1  ...
# 8356         0         0         1            0             1  ...
# 8357         0         0         4            0             4  ...
# 8358         0         0         1            0             1  ...
#
#       year_rank_rate  year_rank_plus platform_year_rank_min  \
# 0                NaN             NaN            2006.000000
# 1                NaN             NaN            2006.000000
# 2                NaN             NaN            2004.039604
# 3                NaN             NaN            1980.000000
# 4                NaN             NaN            2006.000000
# ...              ...             ...                    ...
# 8354        0.992308     2016.992308            1985.800000
# 8355        0.996154     2016.996154            1985.800000
# 8356        0.000000     2017.000000            2011.084685
# 8357        0.333333     2017.333333            2013.007547
# 8358        0.666667     2017.666667            2011.084685
#
#       platform_year_rank_max diff_now_and_platform_min  \
# 0                2016.458678                       NaN
# 1                2016.458678                       NaN
# 2                2015.388158                       NaN
# 3                1989.500000                       NaN
# 4                2016.458678                       NaN
# ...                      ...                       ...
# 8354             2016.996154                 31.192308
# 8355             2016.996154                 31.196154
# 8356             2017.666667                  5.915315
# 8357             2017.333333                  4.325786
# 8358             2017.666667                  6.581982
#
#      diff_now_and_platform_max  pca_0_name_tfidf_gt_count_5_3  \
# 0                          NaN                       0.145092
# 1                          NaN                       0.108966
# 2                          NaN                       0.145092
# 3                          NaN                      -0.032967
# 4                          NaN                      -0.019856
# ...                        ...                            ...
# 8354                  0.003846                      -0.031381
# 8355                  0.000000                      -0.014175
# 8356                  0.666667                      -0.032367
# 8357                  0.000000                      -0.031939
# 8358                  0.000000                      -0.031939
#
#       pca_1_name_tfidf_gt_count_5_3  pca_2_name_tfidf_gt_count_5_3  \
# 0                          0.008547                       0.006841
# 1                          0.004712                       0.002260
# 2                          0.008547                       0.006841
# 3                         -0.010672                      -0.010109
# 4                         -0.008365                      -0.005516
# ...                             ...                            ...
# 8354                      -0.008407                      -0.008226
# 8355                      -0.008996                      -0.009340
# 8356                      -0.009348                      -0.009730
# 8357                      -0.010412                       0.004575
# 8358                      -0.010412                       0.004575
#
#       pca_3_name_tfidf_gt_count_5_3
# 0                          0.133784
# 1                          0.103707
# 2                          0.133784
# 3                         -0.005047
# 4                          0.013714
# ...                             ...
# 8354                       0.000110
# 8355                      -0.053256
# 8356                       0.002313
# 8357                       0.016523
# 8358                       0.016523
#
# [8359 rows x 28 columns]
