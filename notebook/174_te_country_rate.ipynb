# %%
import os
import warnings
warnings.filterwarnings('ignore')
from typing import Any, Dict, List, Tuple
from pathlib import Path
import yaml
import json
import pickle
import copy

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport # profile report を作る用
from matplotlib_venn import venn2 # venn図を作成する用
from tqdm import tqdm
from contextlib import contextmanager
from time import time

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_log_error, mean_squared_error
import lightgbm as lgb

from mykaggle.metric.mse import rmse
from mykaggle.util.ml_logger import MLLogger
from mykaggle.lib.lgbm_util import compute_importances, save_importances
from mykaggle.util.routine import fix_seed

sns.set_style('darkgrid')

# %%
seed = 1019

settings = yaml.safe_load(f'''
name: '174_te_country_rate'
competition: atmacup8
description: '地域ごとの TE'
seed: {seed}
training:
    pca_dim: 4
    validation: 'group'
    num_folds: 5
    num_rounds: 10000
    early_stopping_rounds: 1000
    verbose_eval: 20
    sample_weight_division: 0.01  # 10/2/1
    sample_weight_threshold: 1000
feature:
    name_bow_pca_dim: 4
    name_bow_word_th1: 5
    name_bow_word_th2: 3
    name_bow_th1_upper: 130
    name_bow_th2_upper: 100
lgbm_params:
    # seed: {seed}
    objective: regression
    learning_rate: 0.01
    max_depth: -1
    num_leaves: 31
    colsample_bytree: .7
    metric: "None"
''')
print(json.dumps(settings, indent=4))
# Out:
# {
#     "name": "174_te_country_rate",
#     "competition": "atmacup8",
#     "description": "\u5730\u57df\u3054\u3068\u306e TE",
#     "seed": 1019,
#     "training": {
#         "pca_dim": 4,
#         "validation": "group",
#         "num_folds": 5,
#         "num_rounds": 10000,
#         "early_stopping_rounds": 1000,
#         "verbose_eval": 20,
#         "sample_weight_division": 0.01,
#         "sample_weight_threshold": 1000
#     },
#     "feature": {
#         "name_bow_pca_dim": 4,
#         "name_bow_word_th1": 5,
#         "name_bow_word_th2": 3,
#         "name_bow_th1_upper": 130,
#         "name_bow_th2_upper": 100
#     },
#     "lgbm_params": {
#         "objective": "regression",
#         "learning_rate": 0.01,
#         "max_depth": -1,
#         "num_leaves": 31,
#         "colsample_bytree": 0.7,
#         "metric": "None"
#     }
# }
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fix_seed(settings['seed'])

# %%
datadir = Path('../data/')
ckptdir = Path('../ckpt/') / settings['name']
if not ckptdir.exists():
    ckptdir.mkdir()

# %%
df_train = pd.read_csv(datadir / 'country_prob_train.csv')
df_test = pd.read_csv(datadir / 'country_prob_test.csv')
df_submission = pd.read_csv(datadir / 'atmaCup8_sample-submission.csv')
df_train.shape, df_test.shape
# Out:
# ((8359, 21), (8360, 16))

# %%
# target や weight の用意
target_column = 'Global_Sales'
train_target_columns = ['Global_Sales', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']

for c in train_target_columns:
    df_train.loc[:, 'mod_' + c] = df_train.loc[:, c].apply(lambda x: np.log1p(x))
df_train['target'] = df_train.loc[:, f'mod_{target_column}']

# %%
df_base_train = df_train.loc[:, ['id']]
df_base_test = df_test.loc[:, ['id']]

train_others = {
    'main': df_train.copy(),
    'another': df_test.copy()
}
test_others = {
    'main': df_test.copy(),
    'another': df_train.copy(),
}

# %%
from mykaggle.feature.le import LE
from mykaggle.feature.score import Score
from mykaggle.feature.score_tbd import ScoreTBD
from mykaggle.feature.multi_platform import MultiPlatform
from mykaggle.feature.other_platforms import OtherPlatforms
from mykaggle.feature.ce import CE
from mykaggle.feature.original import Original
from mykaggle.feature.platform_to_pub_genre_once import PlatformToPubGenreOnce
from mykaggle.feature.genre_to_all_once import GenreToAllOnce
from mykaggle.feature.dev_to_category import DevToCategory
from mykaggle.feature.pub_to_category import PubToCategory
from mykaggle.feature.pub_count_500 import PubCount500
from mykaggle.feature.dev_to_category_pivot_pca_all import DevToCategoryPivotPCAAll
from mykaggle.feature.pub_to_category_pivot_pca_all import PubToCategoryPivotPCAAll
from mykaggle.feature.name_bow import NameBOW
from mykaggle.feature.has_sales import HasSales

# %%
fhp = settings['feature']

original_train = Original(train=True)
original_test = Original(train=False)
le_train = LE(train=True)
le_test = LE(train=False)
score_train = Score(train=True)
score_test = Score(train=False)
score_tbd_train = ScoreTBD(train=True)
score_tbd_test = ScoreTBD(train=False)
mp_train = MultiPlatform(train=True)
mp_test = MultiPlatform(train=False)
op_train = OtherPlatforms(train=True)
op_test = OtherPlatforms(train=False)
ce_train = CE(train=True)
ce_test = CE(train=False)
dtc_train = DevToCategory(train=True)
dtc_test = DevToCategory(train=False)
ptc_train = PubToCategory(train=True)
ptc_test = PubToCategory(train=False)
dtcpa_train = DevToCategoryPivotPCAAll(train=True, n_components=2)
dtcpa_test = DevToCategoryPivotPCAAll(train=False, n_components=2)
ptcpa_train = PubToCategoryPivotPCAAll(train=True, n_components=settings['training']['pca_dim'])
ptcpa_test = PubToCategoryPivotPCAAll(train=False, n_components=settings['training']['pca_dim'])
pftao_train = PlatformToPubGenreOnce(train=True, n_components=4)
pftao_test = PlatformToPubGenreOnce(train=False, n_components=4)
gtao_train = GenreToAllOnce(train=True, n_components=4)
gtao_test = GenreToAllOnce(train=False, n_components=4)
p500_train = PubCount500(train=True)
p500_test = PubCount500(train=False)
nbow_train = NameBOW(
    True, fhp['name_bow_pca_dim'], fhp['name_bow_word_th1'], fhp['name_bow_word_th2'],
    fhp['name_bow_th1_upper'], fhp['name_bow_th2_upper'],
)
nbow_test = NameBOW(
    False, fhp['name_bow_pca_dim'], fhp['name_bow_word_th1'], fhp['name_bow_word_th2'],
    fhp['name_bow_th1_upper'], fhp['name_bow_th2_upper'],
)
has_sales_train = HasSales(train=True)
has_sales_test = HasSales(train=False)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_f_train = df_base_train.copy()
df_f_test = df_base_test.copy()

df_f_train = original_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = original_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = le_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = le_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_tbd_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_tbd_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = mp_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = mp_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = op_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = op_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ce_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ce_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = dtc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = dtc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = dtcpa_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = dtcpa_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptcpa_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptcpa_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = pftao_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = pftao_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = gtao_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = gtao_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = p500_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = p500_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = nbow_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = nbow_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = has_sales_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = has_sales_test(df_f_test, others=test_others, use_cache=False, save_cache=True)

df_f_train.shape, df_f_test.shape
# Out:
# ((8359, 80), (8360, 80))

# %%
# drop some columns
df_f_train = df_f_train.drop(['le_Developer'], axis=1)
df_f_test = df_f_test.drop(['le_Developer'], axis=1)
df_f_train.shape, df_f_test.shape
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ((8359, 79), (8360, 79))

# %%
pd.set_option('display.max_rows', 500)
df_f_train.head().T
# Out:
#                                                     0           1           2  \
# id                                                  0           1           2
# Year_of_Release                                   NaN         NaN         NaN
# le_Platform                                        26          26          19
# le_Genre                                            0           0           0
# le_Rating                                           2           2           2
# Critic_Score                                     0.74        0.78        0.73
# User_Score                                       0.79        0.66        0.74
# Critic_Count                                       17          22           5
# User_Count                                         22          28          10
# is_tbd                                          False       False       False
# multi_pf_count                                      7           7           7
# other_platform_1                                    0           0           0
# other_platform_2                                    0           0           0
# other_platform_3                                    0           0           0
# other_platform_4                                    0           0           0
# other_platform_5                                    1           1           1
# other_platform_6                                    0           0           0
# other_platform_7                                    0           0           0
# other_platform_8                                    0           0           0
# other_platform_9                                    0           0           0
# other_platform_10                                   0           0           0
# other_platform_11                                   0           0           0
# other_platform_12                                   0           0           0
# other_platform_13                                   0           0           0
# other_platform_14                                   1           1           1
# other_platform_15                                   0           0           0
# other_platform_16                                   0           0           0
# other_platform_17                                   1           1           1
# other_platform_18                                   1           1           1
# other_platform_19                                   0           0           0
# other_platform_20                                   1           1           0
# other_platform_21                                   0           0           0
# other_platform_22                                   0           0           0
# other_platform_23                                   0           0           0
# other_platform_24                                   0           0           0
# other_platform_25                                   0           0           0
# other_platform_26                                   0           0           0
# other_platform_27                                   0           0           1
# other_platform_28                                   0           0           0
# other_platform_29                                   1           1           1
# other_platform_30                                   0           0           0
# other_platform_31                                   0           0           0
# count_id_groupby_Platform                        1320        1320        1209
# count_id_groupby_Genre                           3370        3370        3370
# count_id_groupby_Developer                         77          77          77
# count_id_groupby_Rating                          1420        1420        1420
# count_id_groupby_Year_of_Release                  NaN         NaN         NaN
# count_Publisher_groupby_Developer                  77          77          77
# count_Genre_groupby_Developer                      77          77          77
# count_Platform_groupby_Developer                   77          77          77
# count_Year_of_Release_groupby_Developer            65          65          65
# nunique_Developer_groupby_Publisher                43          24          43
# nunique_Genre_groupby_Publisher                     9           7           9
# nunique_Platform_groupby_Publisher                 13          13          13
# nunique_Year_of_Release_groupby_Publisher          13          16          13
# pca_0_count_id_pivotby_Developer_for_all     -53.3165    -53.3165    -53.3165
# pca_1_count_id_pivotby_Developer_for_all      34.0593     34.0593     34.0593
# pca_0_count_id_pivotby_Publisher_for_all     -93.4437    -24.1551    -93.4437
# pca_1_count_id_pivotby_Publisher_for_all     -10.1414     -4.5064    -10.1414
# pca_2_count_id_pivotby_Publisher_for_all     -93.0377    -15.6888    -93.0377
# pca_3_count_id_pivotby_Publisher_for_all      118.773     38.2216     118.773
# pca_0_count_id_pivotby_Platform_for_all       -112.99     -112.99     75.8556
# pca_1_count_id_pivotby_Platform_for_all      -104.352    -104.352     190.237
# pca_2_count_id_pivotby_Platform_for_all       85.8857     85.8857     7.33126
# pca_3_count_id_pivotby_Platform_for_all        315.77      315.77     236.343
# pca_0_count_id_pivotby_Genre_for_all         -31.0416    -31.0416    -31.0416
# pca_1_count_id_pivotby_Genre_for_all       0.00799946  0.00799946  0.00799946
# pca_2_count_id_pivotby_Genre_for_all          394.197     394.197     394.197
# pca_3_count_id_pivotby_Genre_for_all          273.565     273.565     273.565
# count_over_500_Publisher                        False       False       False
# count_over_100_Publisher                         True       False        True
# pca_0_name_bow_gt_count_5_3                -0.0138475  -0.0160373  -0.0138475
# pca_1_name_bow_gt_count_5_3                -0.0149359  -0.0179894  -0.0149359
# pca_2_name_bow_gt_count_5_3                -0.0134916   -0.017291  -0.0134916
# pca_3_name_bow_gt_count_5_3                -0.0111382  -0.0092502  -0.0111382
# has_jp_sales                                0.0227113   0.0221961   0.0209711
# has_na_sales                                 0.953149    0.950683    0.953247
# has_eu_sales                                  0.93063    0.942255    0.909297
# has_other_sales                              0.952401    0.944289    0.937944
#
#                                                     3           4
# id                                                  3           4
# Year_of_Release                                   NaN         NaN
# le_Platform                                         0          26
# le_Genre                                            0           0
# le_Rating                                           6           2
# Critic_Score                                      NaN        0.76
# User_Score                                        NaN        0.78
# Critic_Count                                      NaN           8
# User_Count                                        NaN          13
# is_tbd                                          False       False
# multi_pf_count                                      1           8
# other_platform_1                                    0           0
# other_platform_2                                    0           0
# other_platform_3                                    0           1
# other_platform_4                                    0           0
# other_platform_5                                    0           1
# other_platform_6                                    0           0
# other_platform_7                                    0           0
# other_platform_8                                    0           0
# other_platform_9                                    0           0
# other_platform_10                                   0           0
# other_platform_11                                   0           0
# other_platform_12                                   0           0
# other_platform_13                                   0           0
# other_platform_14                                   0           1
# other_platform_15                                   0           0
# other_platform_16                                   0           0
# other_platform_17                                   0           0
# other_platform_18                                   0           1
# other_platform_19                                   0           0
# other_platform_20                                   0           1
# other_platform_21                                   0           1
# other_platform_22                                   0           0
# other_platform_23                                   0           0
# other_platform_24                                   0           0
# other_platform_25                                   0           0
# other_platform_26                                   0           0
# other_platform_27                                   0           0
# other_platform_28                                   0           0
# other_platform_29                                   0           1
# other_platform_30                                   0           0
# other_platform_31                                   0           0
# count_id_groupby_Platform                         133        1320
# count_id_groupby_Genre                           3370        3370
# count_id_groupby_Developer                        NaN          77
# count_id_groupby_Rating                           NaN        1420
# count_id_groupby_Year_of_Release                  NaN         NaN
# count_Publisher_groupby_Developer                 NaN          77
# count_Genre_groupby_Developer                     NaN          77
# count_Platform_groupby_Developer                  NaN          77
# count_Year_of_Release_groupby_Developer           NaN          65
# nunique_Developer_groupby_Publisher               125          43
# nunique_Genre_groupby_Publisher                    12           9
# nunique_Platform_groupby_Publisher                 15          13
# nunique_Year_of_Release_groupby_Publisher          23          13
# pca_0_count_id_pivotby_Developer_for_all          NaN    -53.3165
# pca_1_count_id_pivotby_Developer_for_all          NaN     34.0593
# pca_0_count_id_pivotby_Publisher_for_all      28.6665    -93.4437
# pca_1_count_id_pivotby_Publisher_for_all     -13.4132    -10.1414
# pca_2_count_id_pivotby_Publisher_for_all      5.77347    -93.0377
# pca_3_count_id_pivotby_Publisher_for_all      152.939     118.773
# pca_0_count_id_pivotby_Platform_for_all       10.1062     -112.99
# pca_1_count_id_pivotby_Platform_for_all      -17.5137    -104.352
# pca_2_count_id_pivotby_Platform_for_all      -2.63839     85.8857
# pca_3_count_id_pivotby_Platform_for_all      -145.919      315.77
# pca_0_count_id_pivotby_Genre_for_all         -31.0416    -31.0416
# pca_1_count_id_pivotby_Genre_for_all       0.00799946  0.00799946
# pca_2_count_id_pivotby_Genre_for_all          394.197     394.197
# pca_3_count_id_pivotby_Genre_for_all          273.565     273.565
# count_over_500_Publisher                        False       False
# count_over_100_Publisher                         True        True
# pca_0_name_bow_gt_count_5_3                -0.0127762  -0.0143647
# pca_1_name_bow_gt_count_5_3                -0.0141768  -0.0160154
# pca_2_name_bow_gt_count_5_3                -0.0111283  -0.0146226
# pca_3_name_bow_gt_count_5_3                -0.0133785 -0.00906441
# has_jp_sales                                 0.021234   0.0215975
# has_na_sales                                 0.848037    0.951913
# has_eu_sales                                  0.88952    0.922003
# has_other_sales                              0.388019    0.935384

# %%
@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mykaggle.feature.te import TE
from mykaggle.feature.te_other_aggs import TEOtherAggs
from mykaggle.feature.te_year_platform import TEYearPlatform
from mykaggle.feature.te_year_genre import TEYearGenre
from mykaggle.feature.year_rank4 import YearRank4
from mykaggle.feature.platform_time_diff import PlatformTimeDiff
from mykaggle.feature.te_country_rate import TECountryRate


te_train = TE(train=True)
te_test = TE(train=False)
te_oa_train = TEOtherAggs(train=True)
te_oa_test = TEOtherAggs(train=False)
# te_yp_train = TEYearPlatform(train=True)
# te_yp_test = TEYearPlatform(train=False)
# te_yg_train = TEYearGenre(train=True)
# te_yg_test = TEYearGenre(train=False)
year_rank_train = YearRank4(train=True)
year_rank_test = YearRank4(train=False)
ptdiff_train = PlatformTimeDiff(train=True)
ptdiff_test = PlatformTimeDiff(train=False)
tecr_train = TECountryRate(train=True)
tecr_test = TECountryRate(train=False)


def get_oof_feature(
    df_train: pd.DataFrame, df_valid: pd.DataFrame, y_train: np.ndarray,
    df_train_original: pd.DataFrame, df_valid_original: pd.DataFrame
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    df_train.loc[:, 'target'] = y_train.copy()
    _train_others = copy.deepcopy(train_others)
    _test_others = copy.deepcopy(test_others)
    _train_others['main'] = df_train_original.copy().reset_index().drop('index', axis=1)
    _train_others['another'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['main'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['another'] = df_train_original.copy().reset_index().drop('index', axis=1)
    df_train = df_train.reset_index().drop('index', axis=1)
    df_valid = df_valid.reset_index().drop('index', axis=1)
    df_train = te_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = te_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = te_oa_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = te_oa_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_yp_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_yp_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_yg_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_yg_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = year_rank_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = year_rank_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = ptdiff_train(df_train, others=_train_others, use_cache=False, save_cache=True)
    df_valid = ptdiff_test(df_valid, others=_test_others, use_cache=False, save_cache=True)
    df_train = tecr_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = tecr_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    return df_train.drop(['id', 'target'], axis=1), df_valid.drop('id', axis=1)

# %%
def train(
    settings: Dict[str, Any],
    logger: MLLogger,
    df: pd.DataFrame,
    df_original: pd.DataFrame,
    y: np.ndarray,
    ckptdir: Path
) -> Tuple:
    logger.log_params(settings['training'])
    logger.log_params(settings['feature'])
    logger.log_params(settings['lgbm_params'])
    X = df.copy()
    lgbm_params = settings['lgbm_params']
    models = []
    oof_pred = np.zeros_like(y, dtype=np.float)
    importances = pd.DataFrame()
    split_file = f'{settings["training"]["validation"]}_{settings["training"]["num_folds"]}fold.pkl'
    splits = pickle.load(open(datadir / split_file, 'rb'))

    for i, (train_idx, valid_idx) in enumerate(splits): 
        x_train, y_train = X.iloc[train_idx], y[train_idx]
        x_valid, y_valid = X.iloc[valid_idx], y[valid_idx]
        x_train, x_valid = get_oof_feature(
            x_train, x_valid, y_train,
            df_original.iloc[train_idx], df_original.iloc[valid_idx]
        )
        train_data = lgb.Dataset(x_train.values, label=y_train)
        valid_data = lgb.Dataset(x_valid.values, label=y_valid)

        with timer(prefix='train fold={} '.format(i + 1)):
            clf = lgb.train(
                lgbm_params,
                train_data, 
                num_boost_round=settings['training']['num_rounds'],
                valid_names=['train', 'valid'],
                valid_sets=[train_data, valid_data],  
                early_stopping_rounds=settings['training']['early_stopping_rounds'],
                feval=rmse,
                verbose_eval=settings['training']['verbose_eval']
            )
        pred_i = clf.predict(x_valid.values)
        oof_pred[valid_idx] = pred_i
        models.append(clf)
        importances = compute_importances(importances, x_train.columns, models[i], fold=i)
        fold_score = mean_squared_error(y_valid, pred_i) ** 0.5
        logger.log_metric(f'rmsle_fold_{i}', fold_score)
        print(f'Fold {i} RMSLE: {fold_score:.4f}')
        clf.save_model(str(ckptdir / f'model.txt'))
        logger.log_artifact(str(ckptdir / f'model.txt'), artifact_path=f'{i}')

    score = mean_squared_error(y, oof_pred) ** 0.5
    logger.log_metric(f'RMSLE', score)
    print('FINISHED; whole score: {:.4f}'.format(score))
    save_importances(importances, ckptdir)
    return oof_pred, models, score, importances

# %%
def visualize_oof(
    y_true: np.ndarray, y_pred: np.ndarray
) -> None:
    plt.figure(figsize=(5, 5))
    plt.plot([-100, 5000], [-100, 5000], color='black')
    plt.scatter(y_true, y_pred, alpha=0.2)
    plt.xlim(-100, 4000)
    plt.ylim(-100, 4000)
    plt.xlabel('True')
    plt.ylabel('Pred')


def predict(
    models: List[lgb.Booster],
    df_test: pd.DataFrame,
    df_train: pd.DataFrame,
    df_test_original: pd.DataFrame
) -> np.ndarray:
    '''
    fold 分のモデルと test の特徴 dataframe を受け取って、予測したものを返します。
    :param models: kfold 分のモデル
    :param test_df: test dataset の特徴
    :return: 予測
    '''
    _, test = get_oof_feature(
        df_train.copy(), df_test.copy(), df_train['target'].values, df_train.copy(), df_test_original.copy()
    )
    preds = np.array([model.predict(test) for model in models])
    preds = np.expm1(preds)
    preds = np.mean(preds, axis=0)
    return preds

    
def submit(preds: np.ndarray, ckptdir: Path) -> pd.DataFrame:
    '''
    test data の prediction を受け取って submission ファイルを作成します。
    :param preds: test data の予測
    :param ckptdir: 保存場所
    :return: submission df
    '''
    sub_df = pd.DataFrame({ target_column: preds })
    sub_df.to_csv(ckptdir / f'{settings["name"]}.csv', index=False)
    return sub_df

# %%
logger = MLLogger('cfiken', ckptdir)

# %%
with logger.start(experiment_name=settings['competition'], run_name=settings['name']):
    oof, models, cv, importances = train(
        settings,
        logger,
        df_f_train,
        df_train,
        df_train.loc[:, 'target'].values,
        ckptdir
    )
    preds = predict(models, df_f_test, df_train, df_test)
    sub_df = submit(preds, ckptdir)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005336 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5707
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 93
# [LightGBM] [Info] Start training from score 3.008886
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.26196	valid's rmsle: 1.16643
# [40]	train's rmsle: 1.13627	valid's rmsle: 1.07415
# [60]	train's rmsle: 1.03786	valid's rmsle: 1.00379
# [80]	train's rmsle: 0.959732	valid's rmsle: 0.950818
# [100]	train's rmsle: 0.897637	valid's rmsle: 0.909397
# [120]	train's rmsle: 0.849954	valid's rmsle: 0.880416
# [140]	train's rmsle: 0.810198	valid's rmsle: 0.855843
# [160]	train's rmsle: 0.779101	valid's rmsle: 0.837919
# [180]	train's rmsle: 0.753359	valid's rmsle: 0.822035
# [200]	train's rmsle: 0.731338	valid's rmsle: 0.808961
# [220]	train's rmsle: 0.712847	valid's rmsle: 0.797102
# [240]	train's rmsle: 0.696795	valid's rmsle: 0.787829
# [260]	train's rmsle: 0.682588	valid's rmsle: 0.780163
# [280]	train's rmsle: 0.669361	valid's rmsle: 0.774248
# [300]	train's rmsle: 0.657683	valid's rmsle: 0.768445
# [320]	train's rmsle: 0.64628	valid's rmsle: 0.762967
# [340]	train's rmsle: 0.63574	valid's rmsle: 0.758935
# [360]	train's rmsle: 0.62658	valid's rmsle: 0.75516
# [380]	train's rmsle: 0.618151	valid's rmsle: 0.75251
# [400]	train's rmsle: 0.610311	valid's rmsle: 0.749998
# [420]	train's rmsle: 0.602344	valid's rmsle: 0.74758
# [440]	train's rmsle: 0.595187	valid's rmsle: 0.745769
# [460]	train's rmsle: 0.587923	valid's rmsle: 0.743048
# [480]	train's rmsle: 0.58171	valid's rmsle: 0.741943
# [500]	train's rmsle: 0.575429	valid's rmsle: 0.740505
# [520]	train's rmsle: 0.568913	valid's rmsle: 0.739138
# [540]	train's rmsle: 0.56276	valid's rmsle: 0.73754
# [560]	train's rmsle: 0.556321	valid's rmsle: 0.735703
# [580]	train's rmsle: 0.550904	valid's rmsle: 0.734886
# [600]	train's rmsle: 0.545131	valid's rmsle: 0.733515
# [620]	train's rmsle: 0.539926	valid's rmsle: 0.732372
# [640]	train's rmsle: 0.535033	valid's rmsle: 0.732044
# [660]	train's rmsle: 0.530162	valid's rmsle: 0.731201
# [680]	train's rmsle: 0.525285	valid's rmsle: 0.730235
# [700]	train's rmsle: 0.520677	valid's rmsle: 0.729531
# [720]	train's rmsle: 0.516073	valid's rmsle: 0.729434
# [740]	train's rmsle: 0.511435	valid's rmsle: 0.728947
# [760]	train's rmsle: 0.506609	valid's rmsle: 0.728182
# [780]	train's rmsle: 0.502212	valid's rmsle: 0.727647
# [800]	train's rmsle: 0.498314	valid's rmsle: 0.727401
# [820]	train's rmsle: 0.49413	valid's rmsle: 0.726871
# [840]	train's rmsle: 0.490007	valid's rmsle: 0.726077
# [860]	train's rmsle: 0.485909	valid's rmsle: 0.725774
# [880]	train's rmsle: 0.481922	valid's rmsle: 0.72524
# [900]	train's rmsle: 0.478233	valid's rmsle: 0.724671
# [920]	train's rmsle: 0.474654	valid's rmsle: 0.72436
# [940]	train's rmsle: 0.470898	valid's rmsle: 0.724118
# [960]	train's rmsle: 0.467175	valid's rmsle: 0.723967
# [980]	train's rmsle: 0.463664	valid's rmsle: 0.723721
# [1000]	train's rmsle: 0.460449	valid's rmsle: 0.723572
# [1020]	train's rmsle: 0.456822	valid's rmsle: 0.723574
# [1040]	train's rmsle: 0.453466	valid's rmsle: 0.723675
# [1060]	train's rmsle: 0.449935	valid's rmsle: 0.72365
# [1080]	train's rmsle: 0.446578	valid's rmsle: 0.72373
# [1100]	train's rmsle: 0.443381	valid's rmsle: 0.723452
# [1120]	train's rmsle: 0.440196	valid's rmsle: 0.723384
# [1140]	train's rmsle: 0.436878	valid's rmsle: 0.723257
# [1160]	train's rmsle: 0.433681	valid's rmsle: 0.72307
# [1180]	train's rmsle: 0.430608	valid's rmsle: 0.723002
# [1200]	train's rmsle: 0.427627	valid's rmsle: 0.723186
# [1220]	train's rmsle: 0.424701	valid's rmsle: 0.722866
# [1240]	train's rmsle: 0.421941	valid's rmsle: 0.722968
# [1260]	train's rmsle: 0.41903	valid's rmsle: 0.722844
# [1280]	train's rmsle: 0.415988	valid's rmsle: 0.722991
# [1300]	train's rmsle: 0.413216	valid's rmsle: 0.722999
# [1320]	train's rmsle: 0.410532	valid's rmsle: 0.723208
# [1340]	train's rmsle: 0.407843	valid's rmsle: 0.723298
# [1360]	train's rmsle: 0.405119	valid's rmsle: 0.72326
# [1380]	train's rmsle: 0.402441	valid's rmsle: 0.723152
# [1400]	train's rmsle: 0.399908	valid's rmsle: 0.723103
# [1420]	train's rmsle: 0.397462	valid's rmsle: 0.722902
# [1440]	train's rmsle: 0.394811	valid's rmsle: 0.722936
# [1460]	train's rmsle: 0.392326	valid's rmsle: 0.722808
# [1480]	train's rmsle: 0.389974	valid's rmsle: 0.722715
# [1500]	train's rmsle: 0.387528	valid's rmsle: 0.722694
# [1520]	train's rmsle: 0.385074	valid's rmsle: 0.722892
# [1540]	train's rmsle: 0.382861	valid's rmsle: 0.722852
# [1560]	train's rmsle: 0.380558	valid's rmsle: 0.722758
# [1580]	train's rmsle: 0.378339	valid's rmsle: 0.72275
# [1600]	train's rmsle: 0.375933	valid's rmsle: 0.722963
# [1620]	train's rmsle: 0.373761	valid's rmsle: 0.723155
# [1640]	train's rmsle: 0.371526	valid's rmsle: 0.723316
# [1660]	train's rmsle: 0.36935	valid's rmsle: 0.723099
# [1680]	train's rmsle: 0.367192	valid's rmsle: 0.723082
# [1700]	train's rmsle: 0.365115	valid's rmsle: 0.722774
# [1720]	train's rmsle: 0.363091	valid's rmsle: 0.722601
# [1740]	train's rmsle: 0.360945	valid's rmsle: 0.722447
# [1760]	train's rmsle: 0.35891	valid's rmsle: 0.722508
# [1780]	train's rmsle: 0.356846	valid's rmsle: 0.722449
# [1800]	train's rmsle: 0.354748	valid's rmsle: 0.722625
# [1820]	train's rmsle: 0.352748	valid's rmsle: 0.722485
# [1840]	train's rmsle: 0.350706	valid's rmsle: 0.722728
# [1860]	train's rmsle: 0.348907	valid's rmsle: 0.722705
# [1880]	train's rmsle: 0.346893	valid's rmsle: 0.722529
# [1900]	train's rmsle: 0.344899	valid's rmsle: 0.722768
# [1920]	train's rmsle: 0.343066	valid's rmsle: 0.72257
# [1940]	train's rmsle: 0.341088	valid's rmsle: 0.722738
# [1960]	train's rmsle: 0.339163	valid's rmsle: 0.722682
# [1980]	train's rmsle: 0.337341	valid's rmsle: 0.722553
# [2000]	train's rmsle: 0.335372	valid's rmsle: 0.72266
# [2020]	train's rmsle: 0.333606	valid's rmsle: 0.722884
# [2040]	train's rmsle: 0.331687	valid's rmsle: 0.723116
# [2060]	train's rmsle: 0.329984	valid's rmsle: 0.723209
# [2080]	train's rmsle: 0.328076	valid's rmsle: 0.723418
# [2100]	train's rmsle: 0.326385	valid's rmsle: 0.723624
# [2120]	train's rmsle: 0.324484	valid's rmsle: 0.723809
# [2140]	train's rmsle: 0.322819	valid's rmsle: 0.723822
# [2160]	train's rmsle: 0.321061	valid's rmsle: 0.72401
# [2180]	train's rmsle: 0.319267	valid's rmsle: 0.724093
# [2200]	train's rmsle: 0.317629	valid's rmsle: 0.724093
# [2220]	train's rmsle: 0.31591	valid's rmsle: 0.724237
# [2240]	train's rmsle: 0.314364	valid's rmsle: 0.724382
# [2260]	train's rmsle: 0.312872	valid's rmsle: 0.724085
# [2280]	train's rmsle: 0.311342	valid's rmsle: 0.724328
# [2300]	train's rmsle: 0.30983	valid's rmsle: 0.724274
# [2320]	train's rmsle: 0.308334	valid's rmsle: 0.724345
# [2340]	train's rmsle: 0.306738	valid's rmsle: 0.72429
# [2360]	train's rmsle: 0.305237	valid's rmsle: 0.724391
# [2380]	train's rmsle: 0.30373	valid's rmsle: 0.724293
# [2400]	train's rmsle: 0.30208	valid's rmsle: 0.724409
# [2420]	train's rmsle: 0.300542	valid's rmsle: 0.724432
# [2440]	train's rmsle: 0.299062	valid's rmsle: 0.724567
# [2460]	train's rmsle: 0.29762	valid's rmsle: 0.724574
# [2480]	train's rmsle: 0.296243	valid's rmsle: 0.724705
# [2500]	train's rmsle: 0.294722	valid's rmsle: 0.724677
# [2520]	train's rmsle: 0.293234	valid's rmsle: 0.724746
# [2540]	train's rmsle: 0.291603	valid's rmsle: 0.725006
# [2560]	train's rmsle: 0.289931	valid's rmsle: 0.72504
# [2580]	train's rmsle: 0.288476	valid's rmsle: 0.725171
# [2600]	train's rmsle: 0.287107	valid's rmsle: 0.725306
# [2620]	train's rmsle: 0.285615	valid's rmsle: 0.725368
# [2640]	train's rmsle: 0.284343	valid's rmsle: 0.725469
# [2660]	train's rmsle: 0.28284	valid's rmsle: 0.725489
# [2680]	train's rmsle: 0.281499	valid's rmsle: 0.725371
# [2700]	train's rmsle: 0.28026	valid's rmsle: 0.725425
# [2720]	train's rmsle: 0.278849	valid's rmsle: 0.725563
# [2740]	train's rmsle: 0.277565	valid's rmsle: 0.725546
# [2760]	train's rmsle: 0.276336	valid's rmsle: 0.725467
# Early stopping, best iteration is:
# [1770]	train's rmsle: 0.357836	valid's rmsle: 0.722391
# train fold=1 18.165[s]
# Fold 0 RMSLE: 0.7224
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006002 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5693
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 93
# [LightGBM] [Info] Start training from score 2.941452
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.17858	valid's rmsle: 1.51992
# [40]	train's rmsle: 1.0644	valid's rmsle: 1.40558
# [60]	train's rmsle: 0.975138	valid's rmsle: 1.31525
# [80]	train's rmsle: 0.904201	valid's rmsle: 1.24585
# [100]	train's rmsle: 0.847593	valid's rmsle: 1.18505
# [120]	train's rmsle: 0.803618	valid's rmsle: 1.14308
# [140]	train's rmsle: 0.768039	valid's rmsle: 1.10797
# [160]	train's rmsle: 0.739121	valid's rmsle: 1.07844
# [180]	train's rmsle: 0.714946	valid's rmsle: 1.05465
# [200]	train's rmsle: 0.694153	valid's rmsle: 1.03737
# [220]	train's rmsle: 0.676968	valid's rmsle: 1.01837
# [240]	train's rmsle: 0.660848	valid's rmsle: 1.00473
# [260]	train's rmsle: 0.646802	valid's rmsle: 0.992578
# [280]	train's rmsle: 0.634696	valid's rmsle: 0.982395
# [300]	train's rmsle: 0.624081	valid's rmsle: 0.974197
# [320]	train's rmsle: 0.613858	valid's rmsle: 0.966726
# [340]	train's rmsle: 0.604185	valid's rmsle: 0.95966
# [360]	train's rmsle: 0.595884	valid's rmsle: 0.954155
# [380]	train's rmsle: 0.587443	valid's rmsle: 0.947897
# [400]	train's rmsle: 0.579688	valid's rmsle: 0.942058
# [420]	train's rmsle: 0.572662	valid's rmsle: 0.937997
# [440]	train's rmsle: 0.565958	valid's rmsle: 0.934406
# [460]	train's rmsle: 0.558549	valid's rmsle: 0.931692
# [480]	train's rmsle: 0.551811	valid's rmsle: 0.928819
# [500]	train's rmsle: 0.54521	valid's rmsle: 0.926303
# [520]	train's rmsle: 0.539442	valid's rmsle: 0.923175
# [540]	train's rmsle: 0.534121	valid's rmsle: 0.922069
# [560]	train's rmsle: 0.528331	valid's rmsle: 0.920344
# [580]	train's rmsle: 0.523541	valid's rmsle: 0.918071
# [600]	train's rmsle: 0.518655	valid's rmsle: 0.916809
# [620]	train's rmsle: 0.514108	valid's rmsle: 0.915738
# [640]	train's rmsle: 0.509454	valid's rmsle: 0.914143
# [660]	train's rmsle: 0.504732	valid's rmsle: 0.913223
# [680]	train's rmsle: 0.500648	valid's rmsle: 0.912107
# [700]	train's rmsle: 0.496581	valid's rmsle: 0.910491
# [720]	train's rmsle: 0.492695	valid's rmsle: 0.909864
# [740]	train's rmsle: 0.48872	valid's rmsle: 0.908948
# [760]	train's rmsle: 0.484665	valid's rmsle: 0.908468
# [780]	train's rmsle: 0.480905	valid's rmsle: 0.90749
# [800]	train's rmsle: 0.477551	valid's rmsle: 0.906791
# [820]	train's rmsle: 0.473941	valid's rmsle: 0.906411
# [840]	train's rmsle: 0.470105	valid's rmsle: 0.905913
# [860]	train's rmsle: 0.466181	valid's rmsle: 0.905545
# [880]	train's rmsle: 0.462873	valid's rmsle: 0.904989
# [900]	train's rmsle: 0.459711	valid's rmsle: 0.904642
# [920]	train's rmsle: 0.456081	valid's rmsle: 0.904366
# [940]	train's rmsle: 0.452364	valid's rmsle: 0.903931
# [960]	train's rmsle: 0.449191	valid's rmsle: 0.90357
# [980]	train's rmsle: 0.445876	valid's rmsle: 0.903289
# [1000]	train's rmsle: 0.442773	valid's rmsle: 0.903112
# [1020]	train's rmsle: 0.439279	valid's rmsle: 0.903007
# [1040]	train's rmsle: 0.435935	valid's rmsle: 0.902577
# [1060]	train's rmsle: 0.433125	valid's rmsle: 0.90286
# [1080]	train's rmsle: 0.430224	valid's rmsle: 0.902741
# [1100]	train's rmsle: 0.42728	valid's rmsle: 0.902564
# [1120]	train's rmsle: 0.424818	valid's rmsle: 0.902452
# [1140]	train's rmsle: 0.421984	valid's rmsle: 0.902174
# [1160]	train's rmsle: 0.419132	valid's rmsle: 0.90249
# [1180]	train's rmsle: 0.416176	valid's rmsle: 0.90194
# [1200]	train's rmsle: 0.413453	valid's rmsle: 0.90187
# [1220]	train's rmsle: 0.410816	valid's rmsle: 0.901538
# [1240]	train's rmsle: 0.40833	valid's rmsle: 0.901229
# [1260]	train's rmsle: 0.405856	valid's rmsle: 0.901095
# [1280]	train's rmsle: 0.403231	valid's rmsle: 0.900917
# [1300]	train's rmsle: 0.400699	valid's rmsle: 0.900786
# [1320]	train's rmsle: 0.398223	valid's rmsle: 0.900833
# [1340]	train's rmsle: 0.395747	valid's rmsle: 0.900801
# [1360]	train's rmsle: 0.393127	valid's rmsle: 0.900887
# [1380]	train's rmsle: 0.390561	valid's rmsle: 0.90097
# [1400]	train's rmsle: 0.388338	valid's rmsle: 0.900631
# [1420]	train's rmsle: 0.386249	valid's rmsle: 0.900689
# [1440]	train's rmsle: 0.384056	valid's rmsle: 0.900699
# [1460]	train's rmsle: 0.381711	valid's rmsle: 0.900752
# [1480]	train's rmsle: 0.379454	valid's rmsle: 0.900718
# [1500]	train's rmsle: 0.377057	valid's rmsle: 0.900676
# [1520]	train's rmsle: 0.374998	valid's rmsle: 0.900871
# [1540]	train's rmsle: 0.372938	valid's rmsle: 0.901023
# [1560]	train's rmsle: 0.370715	valid's rmsle: 0.900608
# [1580]	train's rmsle: 0.368462	valid's rmsle: 0.900903
# [1600]	train's rmsle: 0.366322	valid's rmsle: 0.901052
# [1620]	train's rmsle: 0.364242	valid's rmsle: 0.900703
# [1640]	train's rmsle: 0.362246	valid's rmsle: 0.900789
# [1660]	train's rmsle: 0.360014	valid's rmsle: 0.900771
# [1680]	train's rmsle: 0.35771	valid's rmsle: 0.901071
# [1700]	train's rmsle: 0.355435	valid's rmsle: 0.901207
# [1720]	train's rmsle: 0.35325	valid's rmsle: 0.901341
# [1740]	train's rmsle: 0.351192	valid's rmsle: 0.901409
# [1760]	train's rmsle: 0.349163	valid's rmsle: 0.90129
# [1780]	train's rmsle: 0.347109	valid's rmsle: 0.901722
# [1800]	train's rmsle: 0.345113	valid's rmsle: 0.901898
# [1820]	train's rmsle: 0.343069	valid's rmsle: 0.901995
# [1840]	train's rmsle: 0.341064	valid's rmsle: 0.901812
# [1860]	train's rmsle: 0.338989	valid's rmsle: 0.901822
# [1880]	train's rmsle: 0.337285	valid's rmsle: 0.901794
# [1900]	train's rmsle: 0.335535	valid's rmsle: 0.902201
# [1920]	train's rmsle: 0.333699	valid's rmsle: 0.902181
# [1940]	train's rmsle: 0.331978	valid's rmsle: 0.902413
# [1960]	train's rmsle: 0.329825	valid's rmsle: 0.90277
# [1980]	train's rmsle: 0.328224	valid's rmsle: 0.902802
# [2000]	train's rmsle: 0.326443	valid's rmsle: 0.903017
# [2020]	train's rmsle: 0.324761	valid's rmsle: 0.903262
# [2040]	train's rmsle: 0.322829	valid's rmsle: 0.903322
# [2060]	train's rmsle: 0.321119	valid's rmsle: 0.903612
# [2080]	train's rmsle: 0.319403	valid's rmsle: 0.903841
# [2100]	train's rmsle: 0.317944	valid's rmsle: 0.903887
# [2120]	train's rmsle: 0.316139	valid's rmsle: 0.904003
# [2140]	train's rmsle: 0.31455	valid's rmsle: 0.903968
# [2160]	train's rmsle: 0.31293	valid's rmsle: 0.904125
# [2180]	train's rmsle: 0.311224	valid's rmsle: 0.904289
# [2200]	train's rmsle: 0.309577	valid's rmsle: 0.904451
# [2220]	train's rmsle: 0.307922	valid's rmsle: 0.904421
# [2240]	train's rmsle: 0.306045	valid's rmsle: 0.904583
# [2260]	train's rmsle: 0.304513	valid's rmsle: 0.904957
# [2280]	train's rmsle: 0.303057	valid's rmsle: 0.905
# [2300]	train's rmsle: 0.301444	valid's rmsle: 0.90529
# [2320]	train's rmsle: 0.299783	valid's rmsle: 0.905638
# [2340]	train's rmsle: 0.298257	valid's rmsle: 0.905796
# [2360]	train's rmsle: 0.296868	valid's rmsle: 0.906119
# [2380]	train's rmsle: 0.295314	valid's rmsle: 0.906231
# [2400]	train's rmsle: 0.293718	valid's rmsle: 0.906302
# [2420]	train's rmsle: 0.292238	valid's rmsle: 0.90631
# [2440]	train's rmsle: 0.290626	valid's rmsle: 0.906657
# [2460]	train's rmsle: 0.289234	valid's rmsle: 0.906462
# [2480]	train's rmsle: 0.287826	valid's rmsle: 0.906581
# [2500]	train's rmsle: 0.286417	valid's rmsle: 0.906744
# Early stopping, best iteration is:
# [1507]	train's rmsle: 0.376329	valid's rmsle: 0.900596
# train fold=2 15.026[s]
# Fold 1 RMSLE: 0.9006
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005679 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5739
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 94
# [LightGBM] [Info] Start training from score 3.100235
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.2386	valid's rmsle: 1.29158
# [40]	train's rmsle: 1.12093	valid's rmsle: 1.17638
# [60]	train's rmsle: 1.027	valid's rmsle: 1.08862
# [80]	train's rmsle: 0.952508	valid's rmsle: 1.01779
# [100]	train's rmsle: 0.892755	valid's rmsle: 0.963273
# [120]	train's rmsle: 0.845705	valid's rmsle: 0.923697
# [140]	train's rmsle: 0.807677	valid's rmsle: 0.890665
# [160]	train's rmsle: 0.776403	valid's rmsle: 0.866031
# [180]	train's rmsle: 0.749958	valid's rmsle: 0.846737
# [200]	train's rmsle: 0.727832	valid's rmsle: 0.830962
# [220]	train's rmsle: 0.708758	valid's rmsle: 0.817954
# [240]	train's rmsle: 0.691935	valid's rmsle: 0.806835
# [260]	train's rmsle: 0.676808	valid's rmsle: 0.798688
# [280]	train's rmsle: 0.663089	valid's rmsle: 0.791767
# [300]	train's rmsle: 0.651101	valid's rmsle: 0.786466
# [320]	train's rmsle: 0.640328	valid's rmsle: 0.782759
# [340]	train's rmsle: 0.629655	valid's rmsle: 0.778809
# [360]	train's rmsle: 0.620366	valid's rmsle: 0.776257
# [380]	train's rmsle: 0.611124	valid's rmsle: 0.773094
# [400]	train's rmsle: 0.602335	valid's rmsle: 0.769379
# [420]	train's rmsle: 0.59439	valid's rmsle: 0.766923
# [440]	train's rmsle: 0.587122	valid's rmsle: 0.765431
# [460]	train's rmsle: 0.579899	valid's rmsle: 0.764577
# [480]	train's rmsle: 0.572968	valid's rmsle: 0.763512
# [500]	train's rmsle: 0.566399	valid's rmsle: 0.762577
# [520]	train's rmsle: 0.560341	valid's rmsle: 0.761672
# [540]	train's rmsle: 0.554742	valid's rmsle: 0.761005
# [560]	train's rmsle: 0.549037	valid's rmsle: 0.759668
# [580]	train's rmsle: 0.543426	valid's rmsle: 0.758302
# [600]	train's rmsle: 0.537831	valid's rmsle: 0.757978
# [620]	train's rmsle: 0.532816	valid's rmsle: 0.757563
# [640]	train's rmsle: 0.527845	valid's rmsle: 0.756386
# [660]	train's rmsle: 0.52336	valid's rmsle: 0.755916
# [680]	train's rmsle: 0.518897	valid's rmsle: 0.755543
# [700]	train's rmsle: 0.514189	valid's rmsle: 0.754997
# [720]	train's rmsle: 0.509831	valid's rmsle: 0.75493
# [740]	train's rmsle: 0.50531	valid's rmsle: 0.754522
# [760]	train's rmsle: 0.501276	valid's rmsle: 0.753927
# [780]	train's rmsle: 0.497195	valid's rmsle: 0.753524
# [800]	train's rmsle: 0.493422	valid's rmsle: 0.753152
# [820]	train's rmsle: 0.489162	valid's rmsle: 0.753275
# [840]	train's rmsle: 0.485238	valid's rmsle: 0.753197
# [860]	train's rmsle: 0.481546	valid's rmsle: 0.753477
# [880]	train's rmsle: 0.477955	valid's rmsle: 0.753849
# [900]	train's rmsle: 0.474199	valid's rmsle: 0.753791
# [920]	train's rmsle: 0.470529	valid's rmsle: 0.753772
# [940]	train's rmsle: 0.466997	valid's rmsle: 0.75391
# [960]	train's rmsle: 0.463537	valid's rmsle: 0.75369
# [980]	train's rmsle: 0.460147	valid's rmsle: 0.753548
# [1000]	train's rmsle: 0.456582	valid's rmsle: 0.753432
# [1020]	train's rmsle: 0.453421	valid's rmsle: 0.753905
# [1040]	train's rmsle: 0.450291	valid's rmsle: 0.754331
# [1060]	train's rmsle: 0.446924	valid's rmsle: 0.754285
# [1080]	train's rmsle: 0.443927	valid's rmsle: 0.754262
# [1100]	train's rmsle: 0.440957	valid's rmsle: 0.754156
# [1120]	train's rmsle: 0.438198	valid's rmsle: 0.754149
# [1140]	train's rmsle: 0.435249	valid's rmsle: 0.753391
# [1160]	train's rmsle: 0.432318	valid's rmsle: 0.753496
# [1180]	train's rmsle: 0.429451	valid's rmsle: 0.753815
# [1200]	train's rmsle: 0.426395	valid's rmsle: 0.754069
# [1220]	train's rmsle: 0.423597	valid's rmsle: 0.754091
# [1240]	train's rmsle: 0.420783	valid's rmsle: 0.754214
# [1260]	train's rmsle: 0.417991	valid's rmsle: 0.754144
# [1280]	train's rmsle: 0.415263	valid's rmsle: 0.754303
# [1300]	train's rmsle: 0.412279	valid's rmsle: 0.754447
# [1320]	train's rmsle: 0.409766	valid's rmsle: 0.754502
# [1340]	train's rmsle: 0.407051	valid's rmsle: 0.754391
# [1360]	train's rmsle: 0.404459	valid's rmsle: 0.75437
# [1380]	train's rmsle: 0.401873	valid's rmsle: 0.75465
# [1400]	train's rmsle: 0.399399	valid's rmsle: 0.754891
# [1420]	train's rmsle: 0.396744	valid's rmsle: 0.755081
# [1440]	train's rmsle: 0.394445	valid's rmsle: 0.75526
# [1460]	train's rmsle: 0.392043	valid's rmsle: 0.755272
# [1480]	train's rmsle: 0.389793	valid's rmsle: 0.755155
# [1500]	train's rmsle: 0.387329	valid's rmsle: 0.755649
# [1520]	train's rmsle: 0.385002	valid's rmsle: 0.75604
# [1540]	train's rmsle: 0.382443	valid's rmsle: 0.756236
# [1560]	train's rmsle: 0.380183	valid's rmsle: 0.756496
# [1580]	train's rmsle: 0.377849	valid's rmsle: 0.756455
# [1600]	train's rmsle: 0.375584	valid's rmsle: 0.756714
# [1620]	train's rmsle: 0.373559	valid's rmsle: 0.75695
# [1640]	train's rmsle: 0.371307	valid's rmsle: 0.757319
# [1660]	train's rmsle: 0.369109	valid's rmsle: 0.757384
# [1680]	train's rmsle: 0.366841	valid's rmsle: 0.756919
# [1700]	train's rmsle: 0.364658	valid's rmsle: 0.756785
# [1720]	train's rmsle: 0.36231	valid's rmsle: 0.7568
# [1740]	train's rmsle: 0.360358	valid's rmsle: 0.757178
# [1760]	train's rmsle: 0.358097	valid's rmsle: 0.757644
# [1780]	train's rmsle: 0.355866	valid's rmsle: 0.758029
# [1800]	train's rmsle: 0.353756	valid's rmsle: 0.758259
# [1820]	train's rmsle: 0.35159	valid's rmsle: 0.758347
# Early stopping, best iteration is:
# [826]	train's rmsle: 0.48802	valid's rmsle: 0.753053
# train fold=3 12.017[s]
# Fold 2 RMSLE: 0.7531
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006040 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5689
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 93
# [LightGBM] [Info] Start training from score 3.116040
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.25889	valid's rmsle: 1.18068
# [40]	train's rmsle: 1.13476	valid's rmsle: 1.07892
# [60]	train's rmsle: 1.03625	valid's rmsle: 1.00083
# [80]	train's rmsle: 0.957941	valid's rmsle: 0.940682
# [100]	train's rmsle: 0.895573	valid's rmsle: 0.895522
# [120]	train's rmsle: 0.847136	valid's rmsle: 0.867436
# [140]	train's rmsle: 0.80806	valid's rmsle: 0.844564
# [160]	train's rmsle: 0.777023	valid's rmsle: 0.829158
# [180]	train's rmsle: 0.750682	valid's rmsle: 0.81632
# [200]	train's rmsle: 0.728391	valid's rmsle: 0.806685
# [220]	train's rmsle: 0.709162	valid's rmsle: 0.798701
# [240]	train's rmsle: 0.692751	valid's rmsle: 0.793712
# [260]	train's rmsle: 0.67797	valid's rmsle: 0.78802
# [280]	train's rmsle: 0.664922	valid's rmsle: 0.783727
# [300]	train's rmsle: 0.653084	valid's rmsle: 0.779869
# [320]	train's rmsle: 0.641932	valid's rmsle: 0.776056
# [340]	train's rmsle: 0.631547	valid's rmsle: 0.77281
# [360]	train's rmsle: 0.622199	valid's rmsle: 0.770886
# [380]	train's rmsle: 0.613529	valid's rmsle: 0.768442
# [400]	train's rmsle: 0.605395	valid's rmsle: 0.766161
# [420]	train's rmsle: 0.598098	valid's rmsle: 0.764363
# [440]	train's rmsle: 0.591108	valid's rmsle: 0.763166
# [460]	train's rmsle: 0.584319	valid's rmsle: 0.761769
# [480]	train's rmsle: 0.578238	valid's rmsle: 0.760226
# [500]	train's rmsle: 0.571913	valid's rmsle: 0.758471
# [520]	train's rmsle: 0.565873	valid's rmsle: 0.757111
# [540]	train's rmsle: 0.560319	valid's rmsle: 0.755665
# [560]	train's rmsle: 0.554996	valid's rmsle: 0.754318
# [580]	train's rmsle: 0.549987	valid's rmsle: 0.75321
# [600]	train's rmsle: 0.545015	valid's rmsle: 0.752164
# [620]	train's rmsle: 0.540169	valid's rmsle: 0.751288
# [640]	train's rmsle: 0.534906	valid's rmsle: 0.75048
# [660]	train's rmsle: 0.52985	valid's rmsle: 0.750121
# [680]	train's rmsle: 0.525171	valid's rmsle: 0.74975
# [700]	train's rmsle: 0.520388	valid's rmsle: 0.749155
# [720]	train's rmsle: 0.515497	valid's rmsle: 0.749036
# [740]	train's rmsle: 0.510988	valid's rmsle: 0.748925
# [760]	train's rmsle: 0.506569	valid's rmsle: 0.748694
# [780]	train's rmsle: 0.502363	valid's rmsle: 0.748203
# [800]	train's rmsle: 0.498304	valid's rmsle: 0.747832
# [820]	train's rmsle: 0.494174	valid's rmsle: 0.74741
# [840]	train's rmsle: 0.490092	valid's rmsle: 0.747163
# [860]	train's rmsle: 0.486417	valid's rmsle: 0.746973
# [880]	train's rmsle: 0.482692	valid's rmsle: 0.746878
# [900]	train's rmsle: 0.47888	valid's rmsle: 0.746796
# [920]	train's rmsle: 0.47518	valid's rmsle: 0.746395
# [940]	train's rmsle: 0.471611	valid's rmsle: 0.746672
# [960]	train's rmsle: 0.468047	valid's rmsle: 0.746441
# [980]	train's rmsle: 0.464561	valid's rmsle: 0.74653
# [1000]	train's rmsle: 0.461244	valid's rmsle: 0.746273
# [1020]	train's rmsle: 0.457939	valid's rmsle: 0.746338
# [1040]	train's rmsle: 0.454629	valid's rmsle: 0.746006
# [1060]	train's rmsle: 0.451275	valid's rmsle: 0.745787
# [1080]	train's rmsle: 0.447838	valid's rmsle: 0.745582
# [1100]	train's rmsle: 0.444299	valid's rmsle: 0.745352
# [1120]	train's rmsle: 0.44126	valid's rmsle: 0.745232
# [1140]	train's rmsle: 0.437909	valid's rmsle: 0.744836
# [1160]	train's rmsle: 0.434834	valid's rmsle: 0.744663
# [1180]	train's rmsle: 0.431999	valid's rmsle: 0.744709
# [1200]	train's rmsle: 0.429251	valid's rmsle: 0.744878
# [1220]	train's rmsle: 0.426329	valid's rmsle: 0.744812
# [1240]	train's rmsle: 0.423408	valid's rmsle: 0.744494
# [1260]	train's rmsle: 0.420571	valid's rmsle: 0.744339
# [1280]	train's rmsle: 0.417774	valid's rmsle: 0.74435
# [1300]	train's rmsle: 0.415096	valid's rmsle: 0.744395
# [1320]	train's rmsle: 0.412614	valid's rmsle: 0.744584
# [1340]	train's rmsle: 0.409948	valid's rmsle: 0.744562
# [1360]	train's rmsle: 0.407264	valid's rmsle: 0.744783
# [1380]	train's rmsle: 0.404657	valid's rmsle: 0.744571
# [1400]	train's rmsle: 0.401648	valid's rmsle: 0.744718
# [1420]	train's rmsle: 0.398992	valid's rmsle: 0.744832
# [1440]	train's rmsle: 0.396704	valid's rmsle: 0.745044
# [1460]	train's rmsle: 0.394026	valid's rmsle: 0.745197
# [1480]	train's rmsle: 0.391593	valid's rmsle: 0.745277
# [1500]	train's rmsle: 0.38894	valid's rmsle: 0.745398
# [1520]	train's rmsle: 0.386466	valid's rmsle: 0.745494
# [1540]	train's rmsle: 0.383989	valid's rmsle: 0.745706
# [1560]	train's rmsle: 0.381755	valid's rmsle: 0.745869
# [1580]	train's rmsle: 0.379468	valid's rmsle: 0.745993
# [1600]	train's rmsle: 0.376954	valid's rmsle: 0.746107
# [1620]	train's rmsle: 0.374629	valid's rmsle: 0.746245
# [1640]	train's rmsle: 0.372369	valid's rmsle: 0.74657
# [1660]	train's rmsle: 0.370102	valid's rmsle: 0.746978
# [1680]	train's rmsle: 0.367714	valid's rmsle: 0.746886
# [1700]	train's rmsle: 0.36561	valid's rmsle: 0.746927
# [1720]	train's rmsle: 0.363333	valid's rmsle: 0.747443
# [1740]	train's rmsle: 0.361282	valid's rmsle: 0.747632
# [1760]	train's rmsle: 0.359209	valid's rmsle: 0.747905
# [1780]	train's rmsle: 0.357433	valid's rmsle: 0.748063
# [1800]	train's rmsle: 0.355496	valid's rmsle: 0.748049
# [1820]	train's rmsle: 0.353208	valid's rmsle: 0.748042
# [1840]	train's rmsle: 0.351313	valid's rmsle: 0.748061
# [1860]	train's rmsle: 0.349221	valid's rmsle: 0.74831
# [1880]	train's rmsle: 0.347287	valid's rmsle: 0.748575
# [1900]	train's rmsle: 0.345405	valid's rmsle: 0.748928
# [1920]	train's rmsle: 0.343571	valid's rmsle: 0.749113
# [1940]	train's rmsle: 0.341713	valid's rmsle: 0.749652
# [1960]	train's rmsle: 0.339841	valid's rmsle: 0.749838
# [1980]	train's rmsle: 0.33801	valid's rmsle: 0.749987
# [2000]	train's rmsle: 0.336088	valid's rmsle: 0.750157
# [2020]	train's rmsle: 0.334322	valid's rmsle: 0.750353
# [2040]	train's rmsle: 0.332432	valid's rmsle: 0.750645
# [2060]	train's rmsle: 0.330539	valid's rmsle: 0.750914
# [2080]	train's rmsle: 0.328672	valid's rmsle: 0.750973
# [2100]	train's rmsle: 0.326809	valid's rmsle: 0.75155
# [2120]	train's rmsle: 0.324932	valid's rmsle: 0.751715
# [2140]	train's rmsle: 0.323339	valid's rmsle: 0.752174
# [2160]	train's rmsle: 0.32163	valid's rmsle: 0.752438
# [2180]	train's rmsle: 0.319863	valid's rmsle: 0.752852
# [2200]	train's rmsle: 0.318281	valid's rmsle: 0.753194
# [2220]	train's rmsle: 0.316647	valid's rmsle: 0.753482
# [2240]	train's rmsle: 0.31491	valid's rmsle: 0.753778
# [2260]	train's rmsle: 0.313214	valid's rmsle: 0.753964
# [2280]	train's rmsle: 0.311602	valid's rmsle: 0.754144
# Early stopping, best iteration is:
# [1295]	train's rmsle: 0.415857	valid's rmsle: 0.74423
# train fold=4 13.834[s]
# Fold 3 RMSLE: 0.7442
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005721 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5699
# [LightGBM] [Info] Number of data points in the train set: 6688, number of used features: 93
# [LightGBM] [Info] Start training from score 3.021148
# Training until validation scores don't improve for 1000 rounds
# [20]	train's rmsle: 1.26036	valid's rmsle: 1.17358
# [40]	train's rmsle: 1.13577	valid's rmsle: 1.0775
# [60]	train's rmsle: 1.03774	valid's rmsle: 1.00104
# [80]	train's rmsle: 0.959984	valid's rmsle: 0.942164
# [100]	train's rmsle: 0.897797	valid's rmsle: 0.896008
# [120]	train's rmsle: 0.850102	valid's rmsle: 0.865096
# [140]	train's rmsle: 0.811048	valid's rmsle: 0.839574
# [160]	train's rmsle: 0.779873	valid's rmsle: 0.820252
# [180]	train's rmsle: 0.753761	valid's rmsle: 0.804046
# [200]	train's rmsle: 0.732161	valid's rmsle: 0.791351
# [220]	train's rmsle: 0.713944	valid's rmsle: 0.781885
# [240]	train's rmsle: 0.697618	valid's rmsle: 0.774581
# [260]	train's rmsle: 0.683031	valid's rmsle: 0.767522
# [280]	train's rmsle: 0.670324	valid's rmsle: 0.761442
# [300]	train's rmsle: 0.658989	valid's rmsle: 0.755897
# [320]	train's rmsle: 0.648336	valid's rmsle: 0.751827
# [340]	train's rmsle: 0.638519	valid's rmsle: 0.74859
# [360]	train's rmsle: 0.629426	valid's rmsle: 0.745841
# [380]	train's rmsle: 0.620407	valid's rmsle: 0.74378
# [400]	train's rmsle: 0.611934	valid's rmsle: 0.74217
# [420]	train's rmsle: 0.604505	valid's rmsle: 0.740028
# [440]	train's rmsle: 0.59688	valid's rmsle: 0.738722
# [460]	train's rmsle: 0.589798	valid's rmsle: 0.737064
# [480]	train's rmsle: 0.583375	valid's rmsle: 0.73572
# [500]	train's rmsle: 0.577027	valid's rmsle: 0.734371
# [520]	train's rmsle: 0.570993	valid's rmsle: 0.733815
# [540]	train's rmsle: 0.565366	valid's rmsle: 0.73302
# [560]	train's rmsle: 0.559431	valid's rmsle: 0.732228
# [580]	train's rmsle: 0.554428	valid's rmsle: 0.731467
# [600]	train's rmsle: 0.549603	valid's rmsle: 0.730646
# [620]	train's rmsle: 0.544667	valid's rmsle: 0.730025
# [640]	train's rmsle: 0.539803	valid's rmsle: 0.729921
# [660]	train's rmsle: 0.534833	valid's rmsle: 0.729643
# [680]	train's rmsle: 0.530394	valid's rmsle: 0.729215
# [700]	train's rmsle: 0.52574	valid's rmsle: 0.72882
# [720]	train's rmsle: 0.521197	valid's rmsle: 0.728627
# [740]	train's rmsle: 0.516796	valid's rmsle: 0.728541
# [760]	train's rmsle: 0.512596	valid's rmsle: 0.728545
# [780]	train's rmsle: 0.508446	valid's rmsle: 0.728274
# [800]	train's rmsle: 0.504477	valid's rmsle: 0.728234
# [820]	train's rmsle: 0.500459	valid's rmsle: 0.728162
# [840]	train's rmsle: 0.496541	valid's rmsle: 0.728023
# [860]	train's rmsle: 0.492234	valid's rmsle: 0.727727
# [880]	train's rmsle: 0.488397	valid's rmsle: 0.727684
# [900]	train's rmsle: 0.484859	valid's rmsle: 0.727389
# [920]	train's rmsle: 0.481416	valid's rmsle: 0.727393
# [940]	train's rmsle: 0.47794	valid's rmsle: 0.7276
# [960]	train's rmsle: 0.474213	valid's rmsle: 0.727665
# [980]	train's rmsle: 0.470857	valid's rmsle: 0.727585
# [1000]	train's rmsle: 0.467372	valid's rmsle: 0.727553
# [1020]	train's rmsle: 0.463893	valid's rmsle: 0.727621
# [1040]	train's rmsle: 0.460355	valid's rmsle: 0.727943
# [1060]	train's rmsle: 0.457235	valid's rmsle: 0.728243
# [1080]	train's rmsle: 0.453994	valid's rmsle: 0.728624
# [1100]	train's rmsle: 0.450932	valid's rmsle: 0.728964
# [1120]	train's rmsle: 0.447749	valid's rmsle: 0.729054
# [1140]	train's rmsle: 0.44461	valid's rmsle: 0.729118
# [1160]	train's rmsle: 0.441548	valid's rmsle: 0.729178
# [1180]	train's rmsle: 0.438693	valid's rmsle: 0.729175
# [1200]	train's rmsle: 0.435736	valid's rmsle: 0.72921
# [1220]	train's rmsle: 0.432743	valid's rmsle: 0.729329
# [1240]	train's rmsle: 0.429984	valid's rmsle: 0.729453
# [1260]	train's rmsle: 0.427175	valid's rmsle: 0.729632
# [1280]	train's rmsle: 0.424534	valid's rmsle: 0.729834
# [1300]	train's rmsle: 0.421656	valid's rmsle: 0.730263
# [1320]	train's rmsle: 0.418916	valid's rmsle: 0.73022
# [1340]	train's rmsle: 0.416267	valid's rmsle: 0.73052
# [1360]	train's rmsle: 0.413473	valid's rmsle: 0.73056
# [1380]	train's rmsle: 0.410725	valid's rmsle: 0.731065
# [1400]	train's rmsle: 0.408111	valid's rmsle: 0.73096
# [1420]	train's rmsle: 0.405406	valid's rmsle: 0.731137
# [1440]	train's rmsle: 0.402905	valid's rmsle: 0.731316
# [1460]	train's rmsle: 0.40031	valid's rmsle: 0.731497
# [1480]	train's rmsle: 0.398003	valid's rmsle: 0.731764
# [1500]	train's rmsle: 0.395442	valid's rmsle: 0.732004
# [1520]	train's rmsle: 0.392862	valid's rmsle: 0.732245
# [1540]	train's rmsle: 0.390448	valid's rmsle: 0.732532
# [1560]	train's rmsle: 0.387906	valid's rmsle: 0.733077
# [1580]	train's rmsle: 0.385479	valid's rmsle: 0.733497
# [1600]	train's rmsle: 0.38302	valid's rmsle: 0.734035
# [1620]	train's rmsle: 0.380504	valid's rmsle: 0.734121
# [1640]	train's rmsle: 0.378262	valid's rmsle: 0.734486
# [1660]	train's rmsle: 0.376018	valid's rmsle: 0.734787
# [1680]	train's rmsle: 0.373922	valid's rmsle: 0.7349
# [1700]	train's rmsle: 0.371585	valid's rmsle: 0.734944
# [1720]	train's rmsle: 0.369524	valid's rmsle: 0.735288
# [1740]	train's rmsle: 0.367497	valid's rmsle: 0.735492
# [1760]	train's rmsle: 0.365183	valid's rmsle: 0.735795
# [1780]	train's rmsle: 0.3633	valid's rmsle: 0.7358
# [1800]	train's rmsle: 0.361342	valid's rmsle: 0.735878
# [1820]	train's rmsle: 0.359339	valid's rmsle: 0.736109
# [1840]	train's rmsle: 0.357185	valid's rmsle: 0.736412
# [1860]	train's rmsle: 0.355042	valid's rmsle: 0.736924
# [1880]	train's rmsle: 0.352984	valid's rmsle: 0.736945
# [1900]	train's rmsle: 0.35079	valid's rmsle: 0.73754
# Early stopping, best iteration is:
# [911]	train's rmsle: 0.482899	valid's rmsle: 0.727268
# train fold=5 11.575[s]
# Fold 4 RMSLE: 0.7273
# FINISHED; whole score: 0.7724

# %%
visualize_oof(np.expm1(df_train.loc[:, 'target'].values), np.expm1(oof))
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
