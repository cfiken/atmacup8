# %%
import os
import warnings
warnings.filterwarnings('ignore')
from typing import Any, Dict, List, Tuple
from pathlib import Path
import yaml
import json
import pickle
import copy

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport # profile report を作る用
from matplotlib_venn import venn2 # venn図を作成する用
from tqdm import tqdm
from contextlib import contextmanager
from time import time

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc
import lightgbm as lgb

from mykaggle.metric.mse import rmse
from mykaggle.util.ml_logger import MLLogger
from mykaggle.lib.lgbm_util import compute_importances, save_importances
from mykaggle.util.routine import fix_seed

sns.set_style('darkgrid')

# %%
seed = 1019

settings = yaml.safe_load(f'''
name: '262_has_jp_sales'
competition: atmacup8
description: ''
seed: {seed}
training:
    pca_dim: 4
    validation: 'group'
    num_folds: 5
    num_rounds: 10000
    early_stopping_rounds: 1000
    verbose_eval: 20
    sample_weight_division: 0.01  # 10/2/1
    sample_weight_threshold: 1000
feature:
    name_bow_pca_dim: 4
    name_bow_word_th1: 5
    name_bow_word_th2: 3
    name_bow_th1_upper: 130
    name_bow_th2_upper: 100
lgbm_params:
    # seed: {seed}
    objective: binary
    learning_rate: 0.01
    max_depth: -1
    num_leaves: 31
    colsample_bytree: .7
    metric: auc
''')
print(json.dumps(settings, indent=4))
# Out:
# {
#     "name": "262_has_jp_sales",
#     "competition": "atmacup8",
#     "description": "",
#     "seed": 1019,
#     "training": {
#         "pca_dim": 4,
#         "validation": "group",
#         "num_folds": 5,
#         "num_rounds": 10000,
#         "early_stopping_rounds": 1000,
#         "verbose_eval": 20,
#         "sample_weight_division": 0.01,
#         "sample_weight_threshold": 1000
#     },
#     "feature": {
#         "name_bow_pca_dim": 4,
#         "name_bow_word_th1": 5,
#         "name_bow_word_th2": 3,
#         "name_bow_th1_upper": 130,
#         "name_bow_th2_upper": 100
#     },
#     "lgbm_params": {
#         "objective": "binary",
#         "learning_rate": 0.01,
#         "max_depth": -1,
#         "num_leaves": 31,
#         "colsample_bytree": 0.7,
#         "metric": "auc"
#     }
# }
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fix_seed(settings['seed'])

# %%
datadir = Path('../data/')
ckptdir = Path('../ckpt/') / settings['name']
if not ckptdir.exists():
    ckptdir.mkdir()

# %%
df_train = pd.read_csv(datadir / 'id_train.csv')
df_test = pd.read_csv(datadir / 'id_test_unknown.csv')
df_submission = pd.read_csv(datadir / 'atmaCup8_sample-submission.csv')
df_train.shape, df_test.shape
# Out:
# ((8359, 17), (8360, 12))

# %%
# target や weight の用意
target_column = 'has_jp_sales'
train_target_columns = [target_column] + ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']

# for c in train_target_columns:
#     df_train.loc[:, 'mod_' + c] = df_train.loc[:, c].apply(lambda x: np.log1p(x))
df_train_original = pd.read_csv(datadir / 'country_train.csv')
df_train['target'] = df_train_original.loc[:, target_column]

# %%
df_base_train = df_train.loc[:, ['id']]
df_base_test = df_test.loc[:, ['id']]

train_others = {
    'main': df_train.copy(),
    'another': df_test.copy()
}
test_others = {
    'main': df_test.copy(),
    'another': df_train.copy(),
}

# %%
from mykaggle.feature.le import LE
from mykaggle.feature.score_nan import ScoreNaN
from mykaggle.feature.score_tbd import ScoreTBD
from mykaggle.feature.multi_platform import MultiPlatform
from mykaggle.feature.other_platforms import OtherPlatforms
from mykaggle.feature.ce import CE
# from mykaggle.feature.original import Original
from mykaggle.feature.year_nan import YearNaN
from mykaggle.feature.platform_to_pub_genre_once import PlatformToPubGenreOnce
from mykaggle.feature.genre_to_all_once import GenreToAllOnce
from mykaggle.feature.dev_to_category import DevToCategory
from mykaggle.feature.pub_to_category import PubToCategory
from mykaggle.feature.pub_count_500 import PubCount500
from mykaggle.feature.dev_to_category_pivot_pca_all import DevToCategoryPivotPCAAll
from mykaggle.feature.pub_to_category_pivot_pca_all import PubToCategoryPivotPCAAll
from mykaggle.feature.name_bow2 import NameBOW2
from mykaggle.feature.has_sales import HasSales
from mykaggle.feature.name_series_count import NameSeriesCount
from mykaggle.feature.platform_to_scores import PlatformToScores
from mykaggle.feature.platform_to_scores_diff import PlatformToScoresDiff
from mykaggle.feature.year_to_scores import YearToScores
from mykaggle.feature.year_to_scores_diff import YearToScoresDiff
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %%
fhp = settings['feature']

yearnan_train = YearNaN(train=True)
yearnan_test = YearNaN(train=False)
le_train = LE(train=True)
le_test = LE(train=False)
score_train = ScoreNaN(train=True)
score_test = ScoreNaN(train=False)
score_tbd_train = ScoreTBD(train=True)
score_tbd_test = ScoreTBD(train=False)
mp_train = MultiPlatform(train=True)
mp_test = MultiPlatform(train=False)
op_train = OtherPlatforms(train=True)
op_test = OtherPlatforms(train=False)
ce_train = CE(train=True)
ce_test = CE(train=False)
dtc_train = DevToCategory(train=True)
dtc_test = DevToCategory(train=False)
ptc_train = PubToCategory(train=True)
ptc_test = PubToCategory(train=False)
dtcpa_train = DevToCategoryPivotPCAAll(train=True, n_components=2)
dtcpa_test = DevToCategoryPivotPCAAll(train=False, n_components=2)
ptcpa_train = PubToCategoryPivotPCAAll(train=True, n_components=settings['training']['pca_dim'])
ptcpa_test = PubToCategoryPivotPCAAll(train=False, n_components=settings['training']['pca_dim'])
pftao_train = PlatformToPubGenreOnce(train=True, n_components=4)
pftao_test = PlatformToPubGenreOnce(train=False, n_components=4)
gtao_train = GenreToAllOnce(train=True, n_components=4)
gtao_test = GenreToAllOnce(train=False, n_components=4)
p500_train = PubCount500(train=True)
p500_test = PubCount500(train=False)
nbow_train = NameBOW2(
    True, fhp['name_bow_pca_dim'], fhp['name_bow_word_th1'], fhp['name_bow_word_th2'],
    fhp['name_bow_th1_upper'], fhp['name_bow_th2_upper'],
)
nbow_test = NameBOW2(
    False, fhp['name_bow_pca_dim'], fhp['name_bow_word_th1'], fhp['name_bow_word_th2'],
    fhp['name_bow_th1_upper'], fhp['name_bow_th2_upper'],
)
# has_sales_train = HasSales(train=True)
# has_sales_test = HasSales(train=False)
nsc_train = NameSeriesCount(train=True)
nsc_test = NameSeriesCount(train=False)
ptscore_train = PlatformToScores(train=True)
ptscore_test = PlatformToScores(train=False)
ptscored_train = PlatformToScoresDiff(train=True)
ptscored_test = PlatformToScoresDiff(train=False)
yscore_train = YearToScores(train=True)
yscore_test = YearToScores(train=False)
yscored_train = YearToScoresDiff(train=True)
yscored_test = YearToScoresDiff(train=False)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_f_train = df_base_train.copy()
df_f_test = df_base_test.copy()

df_f_train = yearnan_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = yearnan_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = le_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = le_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_tbd_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_tbd_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = mp_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = mp_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = op_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = op_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ce_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ce_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = dtc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = dtc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = dtcpa_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = dtcpa_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptcpa_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptcpa_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = pftao_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = pftao_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = gtao_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = gtao_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = p500_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = p500_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = nbow_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = nbow_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
# df_f_train = has_sales_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
# df_f_test = has_sales_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = nsc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = nsc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptscore_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptscore_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptscored_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptscored_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = yscore_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = yscore_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = yscored_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = yscored_test(df_f_test, others=test_others, use_cache=False, save_cache=True)

df_f_train.shape, df_f_test.shape
# Out:
# ((8359, 127), (8360, 127))

# %%
# drop some columns
df_f_train = df_f_train.drop(['le_Developer'], axis=1)
df_f_test = df_f_test.drop(['le_Developer'], axis=1)
df_f_train.shape, df_f_test.shape
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ((8359, 126), (8360, 126))

# %%
pd.set_option('display.max_rows', 500)
df_f_train.head().T
# Out:
#                                                              0           1  \
# id                                                           0           1
# Year_of_Release                                           2009        2009
# le_Platform                                                 26          26
# le_Genre                                                     0           0
# le_Rating                                                    2           2
# Critic_Score                                              0.74        0.78
# User_Score                                                0.79        0.66
# Critic_Count                                                17          22
# User_Count                                                  22          28
# is_tbd                                                   False       False
# multi_pf_count                                               7           7
# other_platform_1                                             0           0
# other_platform_2                                             0           0
# other_platform_3                                             0           0
# other_platform_4                                             0           0
# other_platform_5                                             1           1
# other_platform_6                                             0           0
# other_platform_7                                             0           0
# other_platform_8                                             0           0
# other_platform_9                                             0           0
# other_platform_10                                            0           0
# other_platform_11                                            0           0
# other_platform_12                                            0           0
# other_platform_13                                            0           0
# other_platform_14                                            1           1
# other_platform_15                                            0           0
# other_platform_16                                            0           0
# other_platform_17                                            1           1
# other_platform_18                                            1           1
# other_platform_19                                            0           0
# other_platform_20                                            1           1
# other_platform_21                                            0           0
# other_platform_22                                            0           0
# other_platform_23                                            0           0
# other_platform_24                                            0           0
# other_platform_25                                            0           0
# other_platform_26                                            0           0
# other_platform_27                                            0           0
# other_platform_28                                            0           0
# other_platform_29                                            1           1
# other_platform_30                                            0           0
# other_platform_31                                            0           0
# count_id_groupby_Platform                                 1320        1320
# count_id_groupby_Genre                                    3370        3370
# count_id_groupby_Developer                                  77          77
# count_id_groupby_Rating                                   1420        1420
# count_id_groupby_Year_of_Release                           NaN         NaN
# count_Publisher_groupby_Developer                           77          77
# count_Genre_groupby_Developer                               77          77
# count_Platform_groupby_Developer                            77          77
# count_Year_of_Release_groupby_Developer                     65          65
# nunique_Developer_groupby_Publisher                         43          24
# nunique_Genre_groupby_Publisher                              9           7
# nunique_Platform_groupby_Publisher                          13          13
# nunique_Year_of_Release_groupby_Publisher                   13          16
# pca_0_count_id_pivotby_Developer_for_all              -53.3165    -53.3165
# pca_1_count_id_pivotby_Developer_for_all               34.0593     34.0593
# pca_0_count_id_pivotby_Publisher_for_all              -93.7891    -23.6107
# pca_1_count_id_pivotby_Publisher_for_all              -8.43031    -4.03868
# pca_2_count_id_pivotby_Publisher_for_all              -93.2896    -15.6729
# pca_3_count_id_pivotby_Publisher_for_all               118.894     38.1077
# pca_0_count_id_pivotby_Platform_for_all               -111.249    -111.249
# pca_1_count_id_pivotby_Platform_for_all               -104.843    -104.843
# pca_2_count_id_pivotby_Platform_for_all                86.7072     86.7072
# pca_3_count_id_pivotby_Platform_for_all                315.714     315.714
# pca_0_count_id_pivotby_Genre_for_all                   -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192     272.192
# count_over_500_Publisher                                 False       False
# count_over_100_Publisher                                  True       False
# pca_0_name_bow_gt_count_5_3                         -0.0145961  -0.0173708
# pca_1_name_bow_gt_count_5_3                         -0.0134632  -0.0177323
# pca_2_name_bow_gt_count_5_3                        -0.00905627  0.00231316
# pca_3_name_bow_gt_count_5_3                         -0.0172936  -0.0192902
# num_word_series_1                                            1           1
# num_word_series_2                                      3.14286           1
# num_word_series_3                                            1     1.85714
# mean_User_Score_groupby_Platform                      0.674268    0.674268
# max_User_Score_groupby_Platform                           0.93        0.93
# min_User_Score_groupby_Platform                           0.02        0.02
# mean_User_Count_groupby_Platform                       53.1232     53.1232
# max_User_Count_groupby_Platform                           2147        2147
# min_User_Count_groupby_Platform                              4           4
# mean_Critic_Score_groupby_Platform                    0.628239    0.628239
# max_Critic_Score_groupby_Platform                         0.97        0.97
# min_Critic_Score_groupby_Platform                         0.19        0.19
# mean_Critic_Count_groupby_Platform                     21.2479     21.2479
# max_Critic_Count_groupby_Platform                           87          87
# min_Critic_Count_groupby_Platform                            4           4
# diff_User_Score_mean_User_Score_groupby_Platform      0.115732  -0.0142679
# diff_User_Score_max_User_Score_groupby_Platform          -0.14       -0.27
# diff_User_Score_min_User_Score_groupby_Platform           0.77        0.64
# diff_User_Count_mean_User_Count_groupby_Platform      -31.1232    -25.1232
# diff_User_Count_max_User_Count_groupby_Platform          -2125       -2119
# diff_User_Count_min_User_Count_groupby_Platform             18          24
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...    0.111761    0.151761
# diff_Critic_Score_max_Critic_Score_groupby_Plat...       -0.23       -0.19
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.55        0.59
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...    -4.24786    0.752137
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -70         -65
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          13          18
# mean_User_Score_groupby_Year_of_Release                    NaN         NaN
# max_User_Score_groupby_Year_of_Release                     NaN         NaN
# min_User_Score_groupby_Year_of_Release                     NaN         NaN
# mean_User_Count_groupby_Year_of_Release                    NaN         NaN
# max_User_Count_groupby_Year_of_Release                     NaN         NaN
# min_User_Count_groupby_Year_of_Release                     NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN         NaN
#
#                                                              2           3  \
# id                                                           2           3
# Year_of_Release                                           2006        1981
# le_Platform                                                 19           0
# le_Genre                                                     0           0
# le_Rating                                                    2           6
# Critic_Score                                              0.73         NaN
# User_Score                                                0.74         NaN
# Critic_Count                                                 5         NaN
# User_Count                                                  10         NaN
# is_tbd                                                   False       False
# multi_pf_count                                               7           1
# other_platform_1                                             0           0
# other_platform_2                                             0           0
# other_platform_3                                             0           0
# other_platform_4                                             0           0
# other_platform_5                                             1           0
# other_platform_6                                             0           0
# other_platform_7                                             0           0
# other_platform_8                                             0           0
# other_platform_9                                             0           0
# other_platform_10                                            0           0
# other_platform_11                                            0           0
# other_platform_12                                            0           0
# other_platform_13                                            0           0
# other_platform_14                                            1           0
# other_platform_15                                            0           0
# other_platform_16                                            0           0
# other_platform_17                                            1           0
# other_platform_18                                            1           0
# other_platform_19                                            0           0
# other_platform_20                                            0           0
# other_platform_21                                            0           0
# other_platform_22                                            0           0
# other_platform_23                                            0           0
# other_platform_24                                            0           0
# other_platform_25                                            0           0
# other_platform_26                                            0           0
# other_platform_27                                            1           0
# other_platform_28                                            0           0
# other_platform_29                                            1           0
# other_platform_30                                            0           0
# other_platform_31                                            0           0
# count_id_groupby_Platform                                 1209         133
# count_id_groupby_Genre                                    3370        3370
# count_id_groupby_Developer                                  77         NaN
# count_id_groupby_Rating                                   1420         NaN
# count_id_groupby_Year_of_Release                           NaN         NaN
# count_Publisher_groupby_Developer                           77         NaN
# count_Genre_groupby_Developer                               77         NaN
# count_Platform_groupby_Developer                            77         NaN
# count_Year_of_Release_groupby_Developer                     65         NaN
# nunique_Developer_groupby_Publisher                         43         127
# nunique_Genre_groupby_Publisher                              9          12
# nunique_Platform_groupby_Publisher                          13          15
# nunique_Year_of_Release_groupby_Publisher                   13          23
# pca_0_count_id_pivotby_Developer_for_all              -53.3165         NaN
# pca_1_count_id_pivotby_Developer_for_all               34.0593         NaN
# pca_0_count_id_pivotby_Publisher_for_all              -93.7891     30.9391
# pca_1_count_id_pivotby_Publisher_for_all              -8.43031    -13.7852
# pca_2_count_id_pivotby_Publisher_for_all              -93.2896     4.53849
# pca_3_count_id_pivotby_Publisher_for_all               118.894      154.97
# pca_0_count_id_pivotby_Platform_for_all                74.2622     10.2364
# pca_1_count_id_pivotby_Platform_for_all                 191.25    -17.3691
# pca_2_count_id_pivotby_Platform_for_all                6.18492    -2.75132
# pca_3_count_id_pivotby_Platform_for_all                236.698     -146.18
# pca_0_count_id_pivotby_Genre_for_all                   -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192     272.192
# count_over_500_Publisher                                 False       False
# count_over_100_Publisher                                  True        True
# pca_0_name_bow_gt_count_5_3                         -0.0145961  -0.0140941
# pca_1_name_bow_gt_count_5_3                         -0.0134632  -0.0106854
# pca_2_name_bow_gt_count_5_3                        -0.00905627 -0.00930718
# pca_3_name_bow_gt_count_5_3                         -0.0172936  -0.0152041
# num_word_series_1                                            1           1
# num_word_series_2                                      3.14286           1
# num_word_series_3                                            1           1
# mean_User_Score_groupby_Platform                      0.722827         NaN
# max_User_Score_groupby_Platform                           0.97         NaN
# min_User_Score_groupby_Platform                           0.06         NaN
# mean_User_Count_groupby_Platform                       30.4228         NaN
# max_User_Count_groupby_Platform                            565         NaN
# min_User_Count_groupby_Platform                              4         NaN
# mean_Critic_Score_groupby_Platform                    0.674242         NaN
# max_Critic_Score_groupby_Platform                         0.91         NaN
# min_Critic_Score_groupby_Platform                         0.28         NaN
# mean_Critic_Count_groupby_Platform                     23.3983         NaN
# max_Critic_Count_groupby_Platform                           79         NaN
# min_Critic_Count_groupby_Platform                            4         NaN
# diff_User_Score_mean_User_Score_groupby_Platform     0.0171734         NaN
# diff_User_Score_max_User_Score_groupby_Platform          -0.23         NaN
# diff_User_Score_min_User_Score_groupby_Platform           0.68         NaN
# diff_User_Count_mean_User_Count_groupby_Platform      -20.4228         NaN
# diff_User_Count_max_User_Count_groupby_Platform           -555         NaN
# diff_User_Count_min_User_Count_groupby_Platform              6         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...   0.0557576         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Plat...       -0.18         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.45         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...    -18.3983         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -74         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Plat...           1         NaN
# mean_User_Score_groupby_Year_of_Release                    NaN         NaN
# max_User_Score_groupby_Year_of_Release                     NaN         NaN
# min_User_Score_groupby_Year_of_Release                     NaN         NaN
# mean_User_Count_groupby_Year_of_Release                    NaN         NaN
# max_User_Count_groupby_Year_of_Release                     NaN         NaN
# min_User_Count_groupby_Year_of_Release                     NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN         NaN
#
#                                                             4
# id                                                          4
# Year_of_Release                                          2009
# le_Platform                                                26
# le_Genre                                                    0
# le_Rating                                                   2
# Critic_Score                                             0.76
# User_Score                                               0.78
# Critic_Count                                                8
# User_Count                                                 13
# is_tbd                                                  False
# multi_pf_count                                              8
# other_platform_1                                            0
# other_platform_2                                            0
# other_platform_3                                            1
# other_platform_4                                            0
# other_platform_5                                            1
# other_platform_6                                            0
# other_platform_7                                            0
# other_platform_8                                            0
# other_platform_9                                            0
# other_platform_10                                           0
# other_platform_11                                           0
# other_platform_12                                           0
# other_platform_13                                           0
# other_platform_14                                           1
# other_platform_15                                           0
# other_platform_16                                           0
# other_platform_17                                           0
# other_platform_18                                           1
# other_platform_19                                           0
# other_platform_20                                           1
# other_platform_21                                           1
# other_platform_22                                           0
# other_platform_23                                           0
# other_platform_24                                           0
# other_platform_25                                           0
# other_platform_26                                           0
# other_platform_27                                           0
# other_platform_28                                           0
# other_platform_29                                           1
# other_platform_30                                           0
# other_platform_31                                           0
# count_id_groupby_Platform                                1320
# count_id_groupby_Genre                                   3370
# count_id_groupby_Developer                                 77
# count_id_groupby_Rating                                  1420
# count_id_groupby_Year_of_Release                          NaN
# count_Publisher_groupby_Developer                          77
# count_Genre_groupby_Developer                              77
# count_Platform_groupby_Developer                           77
# count_Year_of_Release_groupby_Developer                    65
# nunique_Developer_groupby_Publisher                        43
# nunique_Genre_groupby_Publisher                             9
# nunique_Platform_groupby_Publisher                         13
# nunique_Year_of_Release_groupby_Publisher                  13
# pca_0_count_id_pivotby_Developer_for_all             -53.3165
# pca_1_count_id_pivotby_Developer_for_all              34.0593
# pca_0_count_id_pivotby_Publisher_for_all             -93.7891
# pca_1_count_id_pivotby_Publisher_for_all             -8.43031
# pca_2_count_id_pivotby_Publisher_for_all             -93.2896
# pca_3_count_id_pivotby_Publisher_for_all              118.894
# pca_0_count_id_pivotby_Platform_for_all              -111.249
# pca_1_count_id_pivotby_Platform_for_all              -104.843
# pca_2_count_id_pivotby_Platform_for_all               86.7072
# pca_3_count_id_pivotby_Platform_for_all               315.714
# pca_0_count_id_pivotby_Genre_for_all                  -32.595
# pca_1_count_id_pivotby_Genre_for_all                  1.16093
# pca_2_count_id_pivotby_Genre_for_all                  396.248
# pca_3_count_id_pivotby_Genre_for_all                  272.192
# count_over_500_Publisher                                False
# count_over_100_Publisher                                 True
# pca_0_name_bow_gt_count_5_3                        -0.0153978
# pca_1_name_bow_gt_count_5_3                        -0.0141588
# pca_2_name_bow_gt_count_5_3                        -0.0100863
# pca_3_name_bow_gt_count_5_3                         -0.019106
# num_word_series_1                                           1
# num_word_series_2                                           1
# num_word_series_3                                       1.875
# mean_User_Score_groupby_Platform                     0.674268
# max_User_Score_groupby_Platform                          0.93
# min_User_Score_groupby_Platform                          0.02
# mean_User_Count_groupby_Platform                      53.1232
# max_User_Count_groupby_Platform                          2147
# min_User_Count_groupby_Platform                             4
# mean_Critic_Score_groupby_Platform                   0.628239
# max_Critic_Score_groupby_Platform                        0.97
# min_Critic_Score_groupby_Platform                        0.19
# mean_Critic_Count_groupby_Platform                    21.2479
# max_Critic_Count_groupby_Platform                          87
# min_Critic_Count_groupby_Platform                           4
# diff_User_Score_mean_User_Score_groupby_Platform     0.105732
# diff_User_Score_max_User_Score_groupby_Platform         -0.15
# diff_User_Score_min_User_Score_groupby_Platform          0.76
# diff_User_Count_mean_User_Count_groupby_Platform     -40.1232
# diff_User_Count_max_User_Count_groupby_Platform         -2134
# diff_User_Count_min_User_Count_groupby_Platform             9
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...   0.131761
# diff_Critic_Score_max_Critic_Score_groupby_Plat...      -0.21
# diff_Critic_Score_min_Critic_Score_groupby_Plat...       0.57
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...   -13.2479
# diff_Critic_Count_max_Critic_Count_groupby_Plat...        -79
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          4
# mean_User_Score_groupby_Year_of_Release                   NaN
# max_User_Score_groupby_Year_of_Release                    NaN
# min_User_Score_groupby_Year_of_Release                    NaN
# mean_User_Count_groupby_Year_of_Release                   NaN
# max_User_Count_groupby_Year_of_Release                    NaN
# min_User_Count_groupby_Year_of_Release                    NaN
# mean_Critic_Score_groupby_Year_of_Release                 NaN
# max_Critic_Score_groupby_Year_of_Release                  NaN
# min_Critic_Score_groupby_Year_of_Release                  NaN
# mean_Critic_Count_groupby_Year_of_Release                 NaN
# max_Critic_Count_groupby_Year_of_Release                  NaN
# min_Critic_Count_groupby_Year_of_Release                  NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...        NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...        NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...        NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...        NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...        NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...        NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...        NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...        NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...        NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...        NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...        NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...        NaN

# %%
@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mykaggle.feature.te import TE
from mykaggle.feature.te_other_aggs import TEOtherAggs
from mykaggle.feature.te_year_platform import TEYearPlatform
from mykaggle.feature.te_year_genre import TEYearGenre
from mykaggle.feature.year_rank6 import YearRank6
from mykaggle.feature.platform_time_diff import PlatformTimeDiff
from mykaggle.feature.platform_to_region_has_sales import PlatformToRegionHasSales
from mykaggle.feature.platform_to_region_sales import PlatformToRegionSales


te_train = TE(train=True)
te_test = TE(train=False)
# te_oa_train = TEOtherAggs(train=True)
# te_oa_test = TEOtherAggs(train=False)
# te_yp_train = TEYearPlatform(train=True)
# te_yp_test = TEYearPlatform(train=False)
# te_yg_train = TEYearGenre(train=True)
# te_yg_test = TEYearGenre(train=False)
year_rank_train = YearRank6(train=True)
year_rank_test = YearRank6(train=False)
ptdiff_train = PlatformTimeDiff(train=True)
ptdiff_test = PlatformTimeDiff(train=False)
# ptrhs_train = PlatformToRegionHasSales(train=True)
# ptrhs_test = PlatformToRegionHasSales(train=False)
# ptrs_train = PlatformToRegionSales(train=True)
# ptrs_test = PlatformToRegionSales(train=False)


def get_oof_feature(
    df_train: pd.DataFrame, df_valid: pd.DataFrame, y_train: np.ndarray,
    df_train_original: pd.DataFrame, df_valid_original: pd.DataFrame
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    df_train.loc[:, 'target'] = y_train.copy()
    _train_others = copy.deepcopy(train_others)
    _test_others = copy.deepcopy(test_others)
    _train_others['main'] = df_train_original.copy().reset_index().drop('index', axis=1)
    _train_others['another'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['main'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['another'] = df_train_original.copy().reset_index().drop('index', axis=1)
    df_train = df_train.reset_index().drop('index', axis=1)
    df_valid = df_valid.reset_index().drop('index', axis=1)
    df_train = te_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = te_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_oa_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_oa_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_yp_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_yp_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_yg_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_yg_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = year_rank_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = year_rank_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = ptdiff_train(df_train, others=_train_others, use_cache=False, save_cache=True)
    df_valid = ptdiff_test(df_valid, others=_test_others, use_cache=False, save_cache=True)
#     df_train = ptrhs_train(df_train, others=_train_others, use_cache=False, save_cache=True)
#     df_valid = ptrhs_test(df_valid, others=_test_others, use_cache=False, save_cache=True)
#     df_train = ptrs_train(df_train, others=_train_others, use_cache=False, save_cache=True)
#     df_valid = ptrs_test(df_valid, others=_test_others, use_cache=False, save_cache=True)
    return df_train.drop(['id', 'target'], axis=1), df_valid.drop('id', axis=1)

# %%
def train(
    settings: Dict[str, Any],
    logger: MLLogger,
    df: pd.DataFrame,
    df_original: pd.DataFrame,
    y: np.ndarray,
    ckptdir: Path
) -> Tuple:
    logger.log_params(settings['training'])
    logger.log_params(settings['feature'])
    logger.log_params(settings['lgbm_params'])
    X = df.copy()
    lgbm_params = settings['lgbm_params']
    models = []
    oof_pred = np.zeros_like(y, dtype=np.float)
    importances = pd.DataFrame()
    split_file = f'{settings["training"]["validation"]}_{settings["training"]["num_folds"]}fold.pkl'
    splits = pickle.load(open(datadir / split_file, 'rb'))

    for i, (train_idx, valid_idx) in enumerate(splits): 
        x_train, y_train = X.iloc[train_idx], y[train_idx]
        x_valid, y_valid = X.iloc[valid_idx], y[valid_idx]
        x_train, x_valid = get_oof_feature(
            x_train, x_valid, y_train,
            df_original.iloc[train_idx], df_original.iloc[valid_idx]
        )
        train_data = lgb.Dataset(x_train.values, label=y_train)
        valid_data = lgb.Dataset(x_valid.values, label=y_valid)

        with timer(prefix='train fold={} '.format(i + 1)):
            clf = lgb.train(
                lgbm_params,
                train_data, 
                num_boost_round=settings['training']['num_rounds'],
                valid_names=['train', 'valid'],
                valid_sets=[train_data, valid_data],  
                early_stopping_rounds=settings['training']['early_stopping_rounds'],
#                 feval=rmse,
                verbose_eval=settings['training']['verbose_eval']
            )
        pred_i = clf.predict(x_valid.values)
        oof_pred[valid_idx] = pred_i
        models.append(clf)
        importances = compute_importances(importances, x_train.columns, models[i], fold=i)
        fpr, tpr, thresholds = roc_curve(y_valid, pred_i)
        fold_score = auc(fpr, tpr)
        logger.log_metric(f'rmsle_fold_{i}', fold_score)
        print(f'Fold {i} AUC: {fold_score:.4f}')
        clf.save_model(str(ckptdir / f'model.txt'))
        logger.log_artifact(str(ckptdir / f'model.txt'), artifact_path=f'{i}')

    fpr, tpr, thresholds = roc_curve(y, oof_pred)
    score = auc(fpr, tpr)
    logger.log_metric(f'AUC', score)
    print('FINISHED; whole score: {:.4f}'.format(score))
    save_importances(importances, ckptdir)
    return oof_pred, models, score, importances

# %%
def visualize_oof(
    y_true: np.ndarray, y_pred: np.ndarray
) -> None:
    plt.figure(figsize=(5, 5))
    plt.plot([-100, 5000], [-100, 5000], color='black')
    plt.scatter(y_true, y_pred, alpha=0.2)
    plt.xlim(-100, 4000)
    plt.ylim(-100, 4000)
    plt.xlabel('True')
    plt.ylabel('Pred')


def predict(
    models: List[lgb.Booster],
    df_test: pd.DataFrame,
    df_train: pd.DataFrame,
    df_test_original: pd.DataFrame
) -> np.ndarray:
    '''
    fold 分のモデルと test の特徴 dataframe を受け取って、予測したものを返します。
    :param models: kfold 分のモデル
    :param test_df: test dataset の特徴
    :return: 予測
    '''
    _, test = get_oof_feature(
        df_train.copy(), df_test.copy(), df_train['target'].values, df_train.copy(), df_test_original.copy()
    )
    preds = np.array([model.predict(test) for model in models])
#     preds = np.expm1(preds)
    preds = np.mean(preds, axis=0)
    return preds

    
def submit(preds: np.ndarray, ckptdir: Path) -> pd.DataFrame:
    '''
    test data の prediction を受け取って submission ファイルを作成します。
    :param preds: test data の予測
    :param ckptdir: 保存場所
    :return: submission df
    '''
    sub_df = pd.DataFrame({ target_column: preds })
    sub_df.to_csv(ckptdir / f'{settings["name"]}.csv', index=False)
    return sub_df

# %%
logger = MLLogger('cfiken', ckptdir)

# %%
with logger.start(experiment_name=settings['competition'], run_name=settings['name']):
    oof, models, cv, importances = train(
        settings,
        logger,
        df_f_train,
        df_train,
        df_train.loc[:, 'target'].values,
        ckptdir
    )
    preds = predict(models, df_f_test, df_train, df_test)
    sub_df = submit(preds, ckptdir)
# Out:
# [LightGBM] [Info] Number of positive: 3079, number of negative: 3608
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.018061 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9558
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.460446 -> initscore=-0.158549
# [LightGBM] [Info] Start training from score -0.158549
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.949653	valid's auc: 0.910904
# [40]	train's auc: 0.951935	valid's auc: 0.907731
# [60]	train's auc: 0.955003	valid's auc: 0.914039
# [80]	train's auc: 0.957628	valid's auc: 0.916412
# [100]	train's auc: 0.960513	valid's auc: 0.920839
# [120]	train's auc: 0.962921	valid's auc: 0.92375
# [140]	train's auc: 0.965102	valid's auc: 0.925165
# [160]	train's auc: 0.967041	valid's auc: 0.927299
# [180]	train's auc: 0.968737	valid's auc: 0.928151
# [200]	train's auc: 0.970349	valid's auc: 0.928292
# [220]	train's auc: 0.971846	valid's auc: 0.929123
# [240]	train's auc: 0.973451	valid's auc: 0.929242
# [260]	train's auc: 0.975073	valid's auc: 0.930181
# [280]	train's auc: 0.976491	valid's auc: 0.931472
# [300]	train's auc: 0.977858	valid's auc: 0.932549
# [320]	train's auc: 0.979172	valid's auc: 0.933278
# [340]	train's auc: 0.980424	valid's auc: 0.933726
# [360]	train's auc: 0.981639	valid's auc: 0.933939
# [380]	train's auc: 0.982649	valid's auc: 0.934343
# [400]	train's auc: 0.9837	valid's auc: 0.934762
# [420]	train's auc: 0.984711	valid's auc: 0.934888
# [440]	train's auc: 0.985607	valid's auc: 0.934836
# [460]	train's auc: 0.986516	valid's auc: 0.934602
# [480]	train's auc: 0.987277	valid's auc: 0.934944
# [500]	train's auc: 0.988057	valid's auc: 0.93484
# [520]	train's auc: 0.988761	valid's auc: 0.934413
# [540]	train's auc: 0.98947	valid's auc: 0.934055
# [560]	train's auc: 0.990119	valid's auc: 0.933569
# [580]	train's auc: 0.990718	valid's auc: 0.93351
# [600]	train's auc: 0.991312	valid's auc: 0.933292
# [620]	train's auc: 0.991886	valid's auc: 0.933235
# [640]	train's auc: 0.992416	valid's auc: 0.933119
# [660]	train's auc: 0.992887	valid's auc: 0.932692
# [680]	train's auc: 0.993356	valid's auc: 0.932669
# [700]	train's auc: 0.993801	valid's auc: 0.931869
# [720]	train's auc: 0.994196	valid's auc: 0.931333
# [740]	train's auc: 0.994595	valid's auc: 0.931174
# [760]	train's auc: 0.994953	valid's auc: 0.930823
# [780]	train's auc: 0.995309	valid's auc: 0.930832
# [800]	train's auc: 0.995644	valid's auc: 0.930612
# [820]	train's auc: 0.995948	valid's auc: 0.930486
# [840]	train's auc: 0.996235	valid's auc: 0.930185
# [860]	train's auc: 0.996492	valid's auc: 0.93006
# [880]	train's auc: 0.99674	valid's auc: 0.92936
# [900]	train's auc: 0.996958	valid's auc: 0.929293
# [920]	train's auc: 0.997168	valid's auc: 0.929529
# [940]	train's auc: 0.997349	valid's auc: 0.929339
# [960]	train's auc: 0.997529	valid's auc: 0.929123
# [980]	train's auc: 0.997689	valid's auc: 0.929326
# [1000]	train's auc: 0.997832	valid's auc: 0.929443
# [1020]	train's auc: 0.997961	valid's auc: 0.92916
# [1040]	train's auc: 0.998092	valid's auc: 0.929058
# [1060]	train's auc: 0.998219	valid's auc: 0.928709
# [1080]	train's auc: 0.998335	valid's auc: 0.928884
# [1100]	train's auc: 0.998443	valid's auc: 0.928817
# [1120]	train's auc: 0.998553	valid's auc: 0.928686
# [1140]	train's auc: 0.998646	valid's auc: 0.928358
# [1160]	train's auc: 0.99873	valid's auc: 0.928057
# [1180]	train's auc: 0.998814	valid's auc: 0.928274
# [1200]	train's auc: 0.998886	valid's auc: 0.928021
# [1220]	train's auc: 0.998968	valid's auc: 0.927711
# [1240]	train's auc: 0.999048	valid's auc: 0.927526
# [1260]	train's auc: 0.999122	valid's auc: 0.927231
# [1280]	train's auc: 0.999177	valid's auc: 0.92696
# [1300]	train's auc: 0.999237	valid's auc: 0.927018
# [1320]	train's auc: 0.999287	valid's auc: 0.926766
# [1340]	train's auc: 0.999331	valid's auc: 0.926256
# [1360]	train's auc: 0.999382	valid's auc: 0.926373
# [1380]	train's auc: 0.999427	valid's auc: 0.926345
# [1400]	train's auc: 0.999464	valid's auc: 0.926237
# [1420]	train's auc: 0.999495	valid's auc: 0.926445
# [1440]	train's auc: 0.999524	valid's auc: 0.926489
# [1460]	train's auc: 0.999559	valid's auc: 0.926544
# Early stopping, best iteration is:
# [478]	train's auc: 0.987206	valid's auc: 0.93503
# train fold=1 13.503[s]
# Fold 0 AUC: 0.9350
# [LightGBM] [Info] Number of positive: 2516, number of negative: 4171
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009694 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9565
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.376252 -> initscore=-0.505485
# [LightGBM] [Info] Start training from score -0.505485
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.956202	valid's auc: 0.826243
# [40]	train's auc: 0.959917	valid's auc: 0.831105
# [60]	train's auc: 0.962225	valid's auc: 0.843234
# [80]	train's auc: 0.963791	valid's auc: 0.84725
# [100]	train's auc: 0.965442	valid's auc: 0.847448
# [120]	train's auc: 0.966788	valid's auc: 0.847054
# [140]	train's auc: 0.968616	valid's auc: 0.843703
# [160]	train's auc: 0.970122	valid's auc: 0.84178
# [180]	train's auc: 0.971704	valid's auc: 0.841038
# [200]	train's auc: 0.973514	valid's auc: 0.843449
# [220]	train's auc: 0.975124	valid's auc: 0.845035
# [240]	train's auc: 0.976501	valid's auc: 0.844615
# [260]	train's auc: 0.977834	valid's auc: 0.845282
# [280]	train's auc: 0.97907	valid's auc: 0.845832
# [300]	train's auc: 0.98035	valid's auc: 0.847236
# [320]	train's auc: 0.981535	valid's auc: 0.84883
# [340]	train's auc: 0.982739	valid's auc: 0.85091
# [360]	train's auc: 0.98378	valid's auc: 0.851706
# [380]	train's auc: 0.984809	valid's auc: 0.852533
# [400]	train's auc: 0.98571	valid's auc: 0.854562
# [420]	train's auc: 0.986703	valid's auc: 0.856408
# [440]	train's auc: 0.987556	valid's auc: 0.857512
# [460]	train's auc: 0.988427	valid's auc: 0.859145
# [480]	train's auc: 0.989157	valid's auc: 0.859973
# [500]	train's auc: 0.989894	valid's auc: 0.860683
# [520]	train's auc: 0.990556	valid's auc: 0.86054
# [540]	train's auc: 0.991167	valid's auc: 0.860511
# [560]	train's auc: 0.991746	valid's auc: 0.861201
# [580]	train's auc: 0.992301	valid's auc: 0.861763
# [600]	train's auc: 0.992786	valid's auc: 0.862889
# [620]	train's auc: 0.993257	valid's auc: 0.863247
# [640]	train's auc: 0.993643	valid's auc: 0.864451
# [660]	train's auc: 0.994042	valid's auc: 0.865062
# [680]	train's auc: 0.994413	valid's auc: 0.86532
# [700]	train's auc: 0.994798	valid's auc: 0.865149
# [720]	train's auc: 0.995178	valid's auc: 0.865671
# [740]	train's auc: 0.995495	valid's auc: 0.866102
# [760]	train's auc: 0.995795	valid's auc: 0.866243
# [780]	train's auc: 0.996111	valid's auc: 0.866405
# [800]	train's auc: 0.996353	valid's auc: 0.867091
# [820]	train's auc: 0.996628	valid's auc: 0.866908
# [840]	train's auc: 0.996846	valid's auc: 0.866577
# [860]	train's auc: 0.997058	valid's auc: 0.86697
# [880]	train's auc: 0.997242	valid's auc: 0.866798
# [900]	train's auc: 0.997425	valid's auc: 0.866669
# [920]	train's auc: 0.99759	valid's auc: 0.866838
# [940]	train's auc: 0.997749	valid's auc: 0.866935
# [960]	train's auc: 0.997911	valid's auc: 0.866448
# [980]	train's auc: 0.998058	valid's auc: 0.86692
# [1000]	train's auc: 0.998195	valid's auc: 0.867029
# [1020]	train's auc: 0.998315	valid's auc: 0.866642
# [1040]	train's auc: 0.998434	valid's auc: 0.867081
# [1060]	train's auc: 0.998543	valid's auc: 0.867272
# [1080]	train's auc: 0.99864	valid's auc: 0.867273
# [1100]	train's auc: 0.998752	valid's auc: 0.867211
# [1120]	train's auc: 0.998834	valid's auc: 0.867085
# [1140]	train's auc: 0.998917	valid's auc: 0.867202
# [1160]	train's auc: 0.998983	valid's auc: 0.866756
# [1180]	train's auc: 0.999055	valid's auc: 0.866153
# [1200]	train's auc: 0.999121	valid's auc: 0.865904
# [1220]	train's auc: 0.999171	valid's auc: 0.865747
# [1240]	train's auc: 0.999228	valid's auc: 0.865484
# [1260]	train's auc: 0.999284	valid's auc: 0.864941
# [1280]	train's auc: 0.999336	valid's auc: 0.865188
# [1300]	train's auc: 0.999374	valid's auc: 0.86522
# [1320]	train's auc: 0.999415	valid's auc: 0.865436
# [1340]	train's auc: 0.99945	valid's auc: 0.865287
# [1360]	train's auc: 0.999486	valid's auc: 0.86539
# [1380]	train's auc: 0.999524	valid's auc: 0.86532
# [1400]	train's auc: 0.999562	valid's auc: 0.865314
# [1420]	train's auc: 0.999591	valid's auc: 0.865211
# [1440]	train's auc: 0.999614	valid's auc: 0.865542
# [1460]	train's auc: 0.999646	valid's auc: 0.865414
# [1480]	train's auc: 0.999668	valid's auc: 0.865739
# [1500]	train's auc: 0.999691	valid's auc: 0.865399
# [1520]	train's auc: 0.999715	valid's auc: 0.865316
# [1540]	train's auc: 0.999733	valid's auc: 0.865417
# [1560]	train's auc: 0.999751	valid's auc: 0.865448
# [1580]	train's auc: 0.999765	valid's auc: 0.865308
# [1600]	train's auc: 0.999779	valid's auc: 0.864989
# [1620]	train's auc: 0.99979	valid's auc: 0.864728
# [1640]	train's auc: 0.999804	valid's auc: 0.864264
# [1660]	train's auc: 0.999817	valid's auc: 0.864097
# [1680]	train's auc: 0.999828	valid's auc: 0.863724
# [1700]	train's auc: 0.999843	valid's auc: 0.863151
# [1720]	train's auc: 0.999857	valid's auc: 0.863408
# [1740]	train's auc: 0.999869	valid's auc: 0.863602
# [1760]	train's auc: 0.999877	valid's auc: 0.863478
# [1780]	train's auc: 0.999888	valid's auc: 0.863376
# [1800]	train's auc: 0.999894	valid's auc: 0.863198
# [1820]	train's auc: 0.999899	valid's auc: 0.86291
# [1840]	train's auc: 0.999905	valid's auc: 0.863009
# [1860]	train's auc: 0.999912	valid's auc: 0.862886
# [1880]	train's auc: 0.999917	valid's auc: 0.862745
# [1900]	train's auc: 0.999922	valid's auc: 0.86249
# [1920]	train's auc: 0.999926	valid's auc: 0.86225
# [1940]	train's auc: 0.999933	valid's auc: 0.862374
# [1960]	train's auc: 0.999937	valid's auc: 0.862386
# [1980]	train's auc: 0.999942	valid's auc: 0.862396
# [2000]	train's auc: 0.999947	valid's auc: 0.862767
# [2020]	train's auc: 0.999949	valid's auc: 0.862816
# [2040]	train's auc: 0.999952	valid's auc: 0.862682
# Early stopping, best iteration is:
# [1058]	train's auc: 0.998532	valid's auc: 0.867375
# train fold=2 18.143[s]
# Fold 1 AUC: 0.8674
# [LightGBM] [Info] Number of positive: 2743, number of negative: 3944
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017790 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9606
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 121
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.410199 -> initscore=-0.363143
# [LightGBM] [Info] Start training from score -0.363143
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.960765	valid's auc: 0.877394
# [40]	train's auc: 0.963254	valid's auc: 0.882795
# [60]	train's auc: 0.964951	valid's auc: 0.887467
# [80]	train's auc: 0.967682	valid's auc: 0.890594
# [100]	train's auc: 0.969282	valid's auc: 0.891458
# [120]	train's auc: 0.970647	valid's auc: 0.893224
# [140]	train's auc: 0.972491	valid's auc: 0.894557
# [160]	train's auc: 0.974413	valid's auc: 0.895723
# [180]	train's auc: 0.975823	valid's auc: 0.896598
# [200]	train's auc: 0.977121	valid's auc: 0.897583
# [220]	train's auc: 0.978444	valid's auc: 0.897825
# [240]	train's auc: 0.979701	valid's auc: 0.897503
# [260]	train's auc: 0.980938	valid's auc: 0.898486
# [280]	train's auc: 0.982049	valid's auc: 0.898693
# [300]	train's auc: 0.983067	valid's auc: 0.89856
# [320]	train's auc: 0.984151	valid's auc: 0.898816
# [340]	train's auc: 0.985149	valid's auc: 0.89944
# [360]	train's auc: 0.986092	valid's auc: 0.900263
# [380]	train's auc: 0.986964	valid's auc: 0.900799
# [400]	train's auc: 0.987822	valid's auc: 0.901821
# [420]	train's auc: 0.98871	valid's auc: 0.902559
# [440]	train's auc: 0.989451	valid's auc: 0.903238
# [460]	train's auc: 0.990188	valid's auc: 0.904209
# [480]	train's auc: 0.990887	valid's auc: 0.904332
# [500]	train's auc: 0.991547	valid's auc: 0.90458
# [520]	train's auc: 0.992143	valid's auc: 0.90454
# [540]	train's auc: 0.99271	valid's auc: 0.904636
# [560]	train's auc: 0.993214	valid's auc: 0.90466
# [580]	train's auc: 0.993682	valid's auc: 0.904355
# [600]	train's auc: 0.994124	valid's auc: 0.904249
# [620]	train's auc: 0.99452	valid's auc: 0.903831
# [640]	train's auc: 0.994937	valid's auc: 0.903724
# [660]	train's auc: 0.995284	valid's auc: 0.903572
# [680]	train's auc: 0.99562	valid's auc: 0.902999
# [700]	train's auc: 0.995942	valid's auc: 0.902675
# [720]	train's auc: 0.996219	valid's auc: 0.902247
# [740]	train's auc: 0.996499	valid's auc: 0.901826
# [760]	train's auc: 0.996744	valid's auc: 0.901201
# [780]	train's auc: 0.996982	valid's auc: 0.901138
# [800]	train's auc: 0.997211	valid's auc: 0.90115
# [820]	train's auc: 0.997426	valid's auc: 0.901117
# [840]	train's auc: 0.997623	valid's auc: 0.901094
# [860]	train's auc: 0.997807	valid's auc: 0.900802
# [880]	train's auc: 0.997989	valid's auc: 0.901028
# [900]	train's auc: 0.998166	valid's auc: 0.900683
# [920]	train's auc: 0.998307	valid's auc: 0.900809
# [940]	train's auc: 0.998432	valid's auc: 0.900505
# [960]	train's auc: 0.998579	valid's auc: 0.900647
# [980]	train's auc: 0.998705	valid's auc: 0.900293
# [1000]	train's auc: 0.998827	valid's auc: 0.900242
# [1020]	train's auc: 0.998937	valid's auc: 0.900064
# [1040]	train's auc: 0.999032	valid's auc: 0.900051
# [1060]	train's auc: 0.999118	valid's auc: 0.899931
# [1080]	train's auc: 0.999196	valid's auc: 0.899495
# [1100]	train's auc: 0.999269	valid's auc: 0.89906
# [1120]	train's auc: 0.999332	valid's auc: 0.898779
# [1140]	train's auc: 0.999393	valid's auc: 0.89866
# [1160]	train's auc: 0.999437	valid's auc: 0.898212
# [1180]	train's auc: 0.999485	valid's auc: 0.897507
# [1200]	train's auc: 0.999528	valid's auc: 0.897499
# [1220]	train's auc: 0.999571	valid's auc: 0.897234
# [1240]	train's auc: 0.999611	valid's auc: 0.897063
# [1260]	train's auc: 0.999646	valid's auc: 0.896748
# [1280]	train's auc: 0.99968	valid's auc: 0.896692
# [1300]	train's auc: 0.999708	valid's auc: 0.896463
# [1320]	train's auc: 0.999736	valid's auc: 0.896536
# [1340]	train's auc: 0.999757	valid's auc: 0.896601
# [1360]	train's auc: 0.999778	valid's auc: 0.89621
# [1380]	train's auc: 0.9998	valid's auc: 0.895736
# [1400]	train's auc: 0.999822	valid's auc: 0.895874
# [1420]	train's auc: 0.999839	valid's auc: 0.895764
# [1440]	train's auc: 0.999857	valid's auc: 0.895605
# [1460]	train's auc: 0.999872	valid's auc: 0.895229
# [1480]	train's auc: 0.999882	valid's auc: 0.894862
# [1500]	train's auc: 0.999895	valid's auc: 0.894978
# Early stopping, best iteration is:
# [509]	train's auc: 0.991808	valid's auc: 0.904781
# train fold=3 13.764[s]
# Fold 2 AUC: 0.9048
# [LightGBM] [Info] Number of positive: 2825, number of negative: 3862
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019476 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9578
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.422461 -> initscore=-0.312677
# [LightGBM] [Info] Start training from score -0.312677
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.954492	valid's auc: 0.912418
# [40]	train's auc: 0.957632	valid's auc: 0.914888
# [60]	train's auc: 0.960186	valid's auc: 0.917629
# [80]	train's auc: 0.961621	valid's auc: 0.919597
# [100]	train's auc: 0.963551	valid's auc: 0.923537
# [120]	train's auc: 0.964961	valid's auc: 0.925251
# [140]	train's auc: 0.967037	valid's auc: 0.927205
# [160]	train's auc: 0.968911	valid's auc: 0.93136
# [180]	train's auc: 0.970514	valid's auc: 0.93316
# [200]	train's auc: 0.972048	valid's auc: 0.93522
# [220]	train's auc: 0.973456	valid's auc: 0.936961
# [240]	train's auc: 0.974831	valid's auc: 0.938298
# [260]	train's auc: 0.976221	valid's auc: 0.939762
# [280]	train's auc: 0.977471	valid's auc: 0.940599
# [300]	train's auc: 0.978605	valid's auc: 0.941661
# [320]	train's auc: 0.979778	valid's auc: 0.942536
# [340]	train's auc: 0.980988	valid's auc: 0.943476
# [360]	train's auc: 0.982106	valid's auc: 0.944038
# [380]	train's auc: 0.983195	valid's auc: 0.944564
# [400]	train's auc: 0.984238	valid's auc: 0.945094
# [420]	train's auc: 0.985215	valid's auc: 0.945449
# [440]	train's auc: 0.986104	valid's auc: 0.945661
# [460]	train's auc: 0.986897	valid's auc: 0.946022
# [480]	train's auc: 0.987635	valid's auc: 0.94602
# [500]	train's auc: 0.988382	valid's auc: 0.946329
# [520]	train's auc: 0.989099	valid's auc: 0.946637
# [540]	train's auc: 0.989734	valid's auc: 0.946921
# [560]	train's auc: 0.990361	valid's auc: 0.947036
# [580]	train's auc: 0.990909	valid's auc: 0.947233
# [600]	train's auc: 0.991421	valid's auc: 0.947298
# [620]	train's auc: 0.991927	valid's auc: 0.947326
# [640]	train's auc: 0.992391	valid's auc: 0.947308
# [660]	train's auc: 0.99283	valid's auc: 0.947377
# [680]	train's auc: 0.993258	valid's auc: 0.947346
# [700]	train's auc: 0.993677	valid's auc: 0.947316
# [720]	train's auc: 0.994091	valid's auc: 0.94723
# [740]	train's auc: 0.994445	valid's auc: 0.947257
# [760]	train's auc: 0.994805	valid's auc: 0.947358
# [780]	train's auc: 0.995141	valid's auc: 0.947336
# [800]	train's auc: 0.995424	valid's auc: 0.947339
# [820]	train's auc: 0.995721	valid's auc: 0.947412
# [840]	train's auc: 0.995997	valid's auc: 0.94726
# [860]	train's auc: 0.996263	valid's auc: 0.947206
# [880]	train's auc: 0.996486	valid's auc: 0.947276
# [900]	train's auc: 0.996708	valid's auc: 0.947253
# [920]	train's auc: 0.996934	valid's auc: 0.947128
# [940]	train's auc: 0.997125	valid's auc: 0.947112
# [960]	train's auc: 0.997313	valid's auc: 0.947027
# [980]	train's auc: 0.997504	valid's auc: 0.946902
# [1000]	train's auc: 0.997678	valid's auc: 0.946899
# [1020]	train's auc: 0.997809	valid's auc: 0.946956
# [1040]	train's auc: 0.997965	valid's auc: 0.946869
# [1060]	train's auc: 0.998099	valid's auc: 0.946984
# [1080]	train's auc: 0.998224	valid's auc: 0.946824
# [1100]	train's auc: 0.998327	valid's auc: 0.946879
# [1120]	train's auc: 0.998446	valid's auc: 0.946969
# [1140]	train's auc: 0.998541	valid's auc: 0.946933
# [1160]	train's auc: 0.998641	valid's auc: 0.946797
# [1180]	train's auc: 0.998742	valid's auc: 0.946837
# [1200]	train's auc: 0.998817	valid's auc: 0.946803
# [1220]	train's auc: 0.998901	valid's auc: 0.946695
# [1240]	train's auc: 0.998968	valid's auc: 0.946663
# [1260]	train's auc: 0.99903	valid's auc: 0.946739
# [1280]	train's auc: 0.999091	valid's auc: 0.946591
# [1300]	train's auc: 0.999152	valid's auc: 0.946541
# [1320]	train's auc: 0.999206	valid's auc: 0.946455
# [1340]	train's auc: 0.999259	valid's auc: 0.946492
# [1360]	train's auc: 0.999306	valid's auc: 0.946425
# [1380]	train's auc: 0.999349	valid's auc: 0.946449
# [1400]	train's auc: 0.999392	valid's auc: 0.946371
# [1420]	train's auc: 0.999433	valid's auc: 0.946351
# [1440]	train's auc: 0.999466	valid's auc: 0.946169
# [1460]	train's auc: 0.999511	valid's auc: 0.946171
# [1480]	train's auc: 0.999545	valid's auc: 0.946262
# [1500]	train's auc: 0.999576	valid's auc: 0.946183
# [1520]	train's auc: 0.999595	valid's auc: 0.946075
# [1540]	train's auc: 0.999621	valid's auc: 0.946008
# [1560]	train's auc: 0.999643	valid's auc: 0.945909
# [1580]	train's auc: 0.999668	valid's auc: 0.945848
# [1600]	train's auc: 0.999692	valid's auc: 0.945851
# Early stopping, best iteration is:
# [614]	train's auc: 0.991796	valid's auc: 0.947426
# train fold=4 14.306[s]
# Fold 3 AUC: 0.9474
# [LightGBM] [Info] Number of positive: 3045, number of negative: 3643
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008432 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9527
# [LightGBM] [Info] Number of data points in the train set: 6688, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.455293 -> initscore=-0.179307
# [LightGBM] [Info] Start training from score -0.179307
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.951513	valid's auc: 0.926803
# [40]	train's auc: 0.95568	valid's auc: 0.935519
# [60]	train's auc: 0.958645	valid's auc: 0.93584
# [80]	train's auc: 0.960602	valid's auc: 0.936939
# [100]	train's auc: 0.962976	valid's auc: 0.937707
# [120]	train's auc: 0.965216	valid's auc: 0.93863
# [140]	train's auc: 0.967304	valid's auc: 0.940028
# [160]	train's auc: 0.968887	valid's auc: 0.940799
# [180]	train's auc: 0.970414	valid's auc: 0.941096
# [200]	train's auc: 0.97178	valid's auc: 0.941921
# [220]	train's auc: 0.973155	valid's auc: 0.942596
# [240]	train's auc: 0.974555	valid's auc: 0.943237
# [260]	train's auc: 0.975971	valid's auc: 0.943991
# [280]	train's auc: 0.977219	valid's auc: 0.945016
# [300]	train's auc: 0.978558	valid's auc: 0.945842
# [320]	train's auc: 0.979907	valid's auc: 0.946533
# [340]	train's auc: 0.981163	valid's auc: 0.946907
# [360]	train's auc: 0.982279	valid's auc: 0.94718
# [380]	train's auc: 0.983275	valid's auc: 0.947248
# [400]	train's auc: 0.984399	valid's auc: 0.947204
# [420]	train's auc: 0.985398	valid's auc: 0.94724
# [440]	train's auc: 0.986276	valid's auc: 0.947055
# [460]	train's auc: 0.987101	valid's auc: 0.946582
# [480]	train's auc: 0.987872	valid's auc: 0.946231
# [500]	train's auc: 0.988624	valid's auc: 0.945808
# [520]	train's auc: 0.989292	valid's auc: 0.945225
# [540]	train's auc: 0.98995	valid's auc: 0.944749
# [560]	train's auc: 0.990551	valid's auc: 0.944396
# [580]	train's auc: 0.991138	valid's auc: 0.943947
# [600]	train's auc: 0.991654	valid's auc: 0.943734
# [620]	train's auc: 0.992189	valid's auc: 0.943566
# [640]	train's auc: 0.992668	valid's auc: 0.943285
# [660]	train's auc: 0.993121	valid's auc: 0.942698
# [680]	train's auc: 0.99358	valid's auc: 0.942461
# [700]	train's auc: 0.993978	valid's auc: 0.94209
# [720]	train's auc: 0.994339	valid's auc: 0.94189
# [740]	train's auc: 0.994677	valid's auc: 0.941683
# [760]	train's auc: 0.995024	valid's auc: 0.941582
# [780]	train's auc: 0.995352	valid's auc: 0.94126
# [800]	train's auc: 0.995651	valid's auc: 0.941182
# [820]	train's auc: 0.995922	valid's auc: 0.94098
# [840]	train's auc: 0.996185	valid's auc: 0.94079
# [860]	train's auc: 0.996432	valid's auc: 0.940584
# [880]	train's auc: 0.996666	valid's auc: 0.940423
# [900]	train's auc: 0.996914	valid's auc: 0.940067
# [920]	train's auc: 0.997123	valid's auc: 0.939814
# [940]	train's auc: 0.99733	valid's auc: 0.939252
# [960]	train's auc: 0.99751	valid's auc: 0.938994
# [980]	train's auc: 0.997678	valid's auc: 0.938881
# [1000]	train's auc: 0.997838	valid's auc: 0.93864
# [1020]	train's auc: 0.997974	valid's auc: 0.938565
# [1040]	train's auc: 0.998097	valid's auc: 0.938425
# [1060]	train's auc: 0.998212	valid's auc: 0.938076
# [1080]	train's auc: 0.998344	valid's auc: 0.937737
# [1100]	train's auc: 0.998431	valid's auc: 0.937528
# [1120]	train's auc: 0.998545	valid's auc: 0.937206
# [1140]	train's auc: 0.998642	valid's auc: 0.936988
# [1160]	train's auc: 0.998723	valid's auc: 0.93683
# [1180]	train's auc: 0.998814	valid's auc: 0.936674
# [1200]	train's auc: 0.998878	valid's auc: 0.936652
# [1220]	train's auc: 0.998952	valid's auc: 0.936673
# [1240]	train's auc: 0.999026	valid's auc: 0.936834
# [1260]	train's auc: 0.999089	valid's auc: 0.937066
# [1280]	train's auc: 0.999148	valid's auc: 0.937034
# [1300]	train's auc: 0.999208	valid's auc: 0.936905
# [1320]	train's auc: 0.999276	valid's auc: 0.936642
# [1340]	train's auc: 0.999328	valid's auc: 0.936498
# [1360]	train's auc: 0.999371	valid's auc: 0.936563
# [1380]	train's auc: 0.999417	valid's auc: 0.936502
# Early stopping, best iteration is:
# [391]	train's auc: 0.983876	valid's auc: 0.9474
# train fold=5 12.344[s]
# Fold 4 AUC: 0.9474
# FINISHED; whole score: 0.8961
# (660, 4)

# %%
visualize_oof(np.expm1(df_train.loc[:, 'target'].values), np.expm1(oof))
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train_preds = predict(models, df_f_train, df_train, df_train)
sub_df = pd.DataFrame({ target_column: train_preds })
sub_df.to_csv(ckptdir / f'train_{settings["name"]}.csv', index=False)
sub_df = pd.DataFrame({ target_column: oof })
sub_df.to_csv(ckptdir / f'oof_{settings["name"]}.csv', index=False)
