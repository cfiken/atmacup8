# %%
import os
import warnings
warnings.filterwarnings('ignore')
from typing import Any, Dict, List, Tuple
from pathlib import Path
import yaml
import json
import pickle
import copy

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport # profile report を作る用
from matplotlib_venn import venn2 # venn図を作成する用
from tqdm import tqdm
from contextlib import contextmanager
from time import time

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc
import lightgbm as lgb

from mykaggle.metric.mse import rmse
from mykaggle.util.ml_logger import MLLogger
from mykaggle.lib.lgbm_util import compute_importances, save_importances
from mykaggle.util.routine import fix_seed

sns.set_style('darkgrid')

# %%
seed = 1019

settings = yaml.safe_load(f'''
name: '261_has_jp_sales'
competition: atmacup8
description: ''
seed: {seed}
training:
    pca_dim: 4
    validation: 'group'
    num_folds: 5
    num_rounds: 10000
    early_stopping_rounds: 1000
    verbose_eval: 20
    sample_weight_division: 0.01  # 10/2/1
    sample_weight_threshold: 1000
feature:
    name_bow_pca_dim: 4
    name_bow_word_th1: 5
    name_bow_word_th2: 3
    name_bow_th1_upper: 130
    name_bow_th2_upper: 100
lgbm_params:
    # seed: {seed}
    objective: binary
    learning_rate: 0.01
    max_depth: -1
    num_leaves: 31
    colsample_bytree: .7
    metric: auc
''')
print(json.dumps(settings, indent=4))
# Out:
# {
#     "name": "261_has_jp_sales",
#     "competition": "atmacup8",
#     "description": "",
#     "seed": 1019,
#     "training": {
#         "pca_dim": 4,
#         "validation": "group",
#         "num_folds": 5,
#         "num_rounds": 10000,
#         "early_stopping_rounds": 1000,
#         "verbose_eval": 20,
#         "sample_weight_division": 0.01,
#         "sample_weight_threshold": 1000
#     },
#     "feature": {
#         "name_bow_pca_dim": 4,
#         "name_bow_word_th1": 5,
#         "name_bow_word_th2": 3,
#         "name_bow_th1_upper": 130,
#         "name_bow_th2_upper": 100
#     },
#     "lgbm_params": {
#         "objective": "binary",
#         "learning_rate": 0.01,
#         "max_depth": -1,
#         "num_leaves": 31,
#         "colsample_bytree": 0.7,
#         "metric": "auc"
#     }
# }
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fix_seed(settings['seed'])

# %%
datadir = Path('../data/')
ckptdir = Path('../ckpt/') / settings['name']
if not ckptdir.exists():
    ckptdir.mkdir()

# %%
df_train = pd.read_csv(datadir / 'id_train.csv')
df_test = pd.read_csv(datadir / 'id_test_unknown.csv')
df_submission = pd.read_csv(datadir / 'atmaCup8_sample-submission.csv')
df_train.shape, df_test.shape
# Out:
# ((8359, 17), (8360, 12))

# %%
# target や weight の用意
target_column = 'has_jp_sales'
train_target_columns = [target_column] + ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']

# for c in train_target_columns:
#     df_train.loc[:, 'mod_' + c] = df_train.loc[:, c].apply(lambda x: np.log1p(x))
df_train_original = pd.read_csv(datadir / 'country_train.csv')
df_train['target'] = df_train_original.loc[:, target_column]

# %%
df_base_train = df_train.loc[:, ['id']]
df_base_test = df_test.loc[:, ['id']]

train_others = {
    'main': df_train.copy(),
    'another': df_test.copy()
}
test_others = {
    'main': df_test.copy(),
    'another': df_train.copy(),
}

# %%
from mykaggle.feature.le import LE
from mykaggle.feature.score import Score
from mykaggle.feature.score_tbd import ScoreTBD
from mykaggle.feature.multi_platform import MultiPlatform
from mykaggle.feature.other_platforms import OtherPlatforms
from mykaggle.feature.ce import CE
# from mykaggle.feature.original import Original
from mykaggle.feature.year_nan import YearNaN
from mykaggle.feature.platform_to_pub_genre_once import PlatformToPubGenreOnce
from mykaggle.feature.genre_to_all_once import GenreToAllOnce
from mykaggle.feature.dev_to_category import DevToCategory
from mykaggle.feature.pub_to_category import PubToCategory
from mykaggle.feature.pub_count_500 import PubCount500
from mykaggle.feature.dev_to_category_pivot_pca_all import DevToCategoryPivotPCAAll
from mykaggle.feature.pub_to_category_pivot_pca_all import PubToCategoryPivotPCAAll
from mykaggle.feature.name_bow2 import NameBOW2
from mykaggle.feature.has_sales import HasSales
from mykaggle.feature.name_series_count import NameSeriesCount
from mykaggle.feature.platform_to_scores import PlatformToScores
from mykaggle.feature.platform_to_scores_diff import PlatformToScoresDiff
from mykaggle.feature.year_to_scores import YearToScores
from mykaggle.feature.year_to_scores_diff import YearToScoresDiff
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %%
fhp = settings['feature']

yearnan_train = YearNaN(train=True)
yearnan_test = YearNaN(train=False)
le_train = LE(train=True)
le_test = LE(train=False)
score_train = Score(train=True)
score_test = Score(train=False)
score_tbd_train = ScoreTBD(train=True)
score_tbd_test = ScoreTBD(train=False)
mp_train = MultiPlatform(train=True)
mp_test = MultiPlatform(train=False)
op_train = OtherPlatforms(train=True)
op_test = OtherPlatforms(train=False)
ce_train = CE(train=True)
ce_test = CE(train=False)
dtc_train = DevToCategory(train=True)
dtc_test = DevToCategory(train=False)
ptc_train = PubToCategory(train=True)
ptc_test = PubToCategory(train=False)
dtcpa_train = DevToCategoryPivotPCAAll(train=True, n_components=2)
dtcpa_test = DevToCategoryPivotPCAAll(train=False, n_components=2)
ptcpa_train = PubToCategoryPivotPCAAll(train=True, n_components=settings['training']['pca_dim'])
ptcpa_test = PubToCategoryPivotPCAAll(train=False, n_components=settings['training']['pca_dim'])
pftao_train = PlatformToPubGenreOnce(train=True, n_components=4)
pftao_test = PlatformToPubGenreOnce(train=False, n_components=4)
gtao_train = GenreToAllOnce(train=True, n_components=4)
gtao_test = GenreToAllOnce(train=False, n_components=4)
p500_train = PubCount500(train=True)
p500_test = PubCount500(train=False)
nbow_train = NameBOW2(
    True, fhp['name_bow_pca_dim'], fhp['name_bow_word_th1'], fhp['name_bow_word_th2'],
    fhp['name_bow_th1_upper'], fhp['name_bow_th2_upper'],
)
nbow_test = NameBOW2(
    False, fhp['name_bow_pca_dim'], fhp['name_bow_word_th1'], fhp['name_bow_word_th2'],
    fhp['name_bow_th1_upper'], fhp['name_bow_th2_upper'],
)
# has_sales_train = HasSales(train=True)
# has_sales_test = HasSales(train=False)
nsc_train = NameSeriesCount(train=True)
nsc_test = NameSeriesCount(train=False)
ptscore_train = PlatformToScores(train=True)
ptscore_test = PlatformToScores(train=False)
ptscored_train = PlatformToScoresDiff(train=True)
ptscored_test = PlatformToScoresDiff(train=False)
yscore_train = YearToScores(train=True)
yscore_test = YearToScores(train=False)
yscored_train = YearToScoresDiff(train=True)
yscored_test = YearToScoresDiff(train=False)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_f_train = df_base_train.copy()
df_f_test = df_base_test.copy()

df_f_train = yearnan_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = yearnan_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = le_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = le_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_tbd_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_tbd_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = mp_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = mp_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = op_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = op_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ce_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ce_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = dtc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = dtc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = dtcpa_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = dtcpa_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptcpa_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptcpa_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = pftao_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = pftao_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = gtao_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = gtao_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = p500_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = p500_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = nbow_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = nbow_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
# df_f_train = has_sales_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
# df_f_test = has_sales_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = nsc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = nsc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptscore_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptscore_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ptscored_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ptscored_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = yscore_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = yscore_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = yscored_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = yscored_test(df_f_test, others=test_others, use_cache=False, save_cache=True)

df_f_train.shape, df_f_test.shape
# Out:
# ((8359, 127), (8360, 127))

# %%
# drop some columns
df_f_train = df_f_train.drop(['le_Developer'], axis=1)
df_f_test = df_f_test.drop(['le_Developer'], axis=1)
df_f_train.shape, df_f_test.shape
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ((8359, 126), (8360, 126))

# %%
pd.set_option('display.max_rows', 500)
df_f_train.head().T
# Out:
#                                                              0           1  \
# id                                                           0           1
# Year_of_Release                                           2009        2009
# le_Platform                                                 26          26
# le_Genre                                                     0           0
# le_Rating                                                    2           2
# Critic_Score                                              0.74        0.78
# User_Score                                                0.79        0.66
# Critic_Count                                                17          22
# User_Count                                                  22          28
# is_tbd                                                   False       False
# multi_pf_count                                               7           7
# other_platform_1                                             0           0
# other_platform_2                                             0           0
# other_platform_3                                             0           0
# other_platform_4                                             0           0
# other_platform_5                                             1           1
# other_platform_6                                             0           0
# other_platform_7                                             0           0
# other_platform_8                                             0           0
# other_platform_9                                             0           0
# other_platform_10                                            0           0
# other_platform_11                                            0           0
# other_platform_12                                            0           0
# other_platform_13                                            0           0
# other_platform_14                                            1           1
# other_platform_15                                            0           0
# other_platform_16                                            0           0
# other_platform_17                                            1           1
# other_platform_18                                            1           1
# other_platform_19                                            0           0
# other_platform_20                                            1           1
# other_platform_21                                            0           0
# other_platform_22                                            0           0
# other_platform_23                                            0           0
# other_platform_24                                            0           0
# other_platform_25                                            0           0
# other_platform_26                                            0           0
# other_platform_27                                            0           0
# other_platform_28                                            0           0
# other_platform_29                                            1           1
# other_platform_30                                            0           0
# other_platform_31                                            0           0
# count_id_groupby_Platform                                 1320        1320
# count_id_groupby_Genre                                    3370        3370
# count_id_groupby_Developer                                  77          77
# count_id_groupby_Rating                                   1420        1420
# count_id_groupby_Year_of_Release                           NaN         NaN
# count_Publisher_groupby_Developer                           77          77
# count_Genre_groupby_Developer                               77          77
# count_Platform_groupby_Developer                            77          77
# count_Year_of_Release_groupby_Developer                     65          65
# nunique_Developer_groupby_Publisher                         43          24
# nunique_Genre_groupby_Publisher                              9           7
# nunique_Platform_groupby_Publisher                          13          13
# nunique_Year_of_Release_groupby_Publisher                   13          16
# pca_0_count_id_pivotby_Developer_for_all              -53.3165    -53.3165
# pca_1_count_id_pivotby_Developer_for_all               34.0593     34.0593
# pca_0_count_id_pivotby_Publisher_for_all              -93.7891    -23.6107
# pca_1_count_id_pivotby_Publisher_for_all              -8.43031    -4.03868
# pca_2_count_id_pivotby_Publisher_for_all              -93.2896    -15.6729
# pca_3_count_id_pivotby_Publisher_for_all               118.894     38.1077
# pca_0_count_id_pivotby_Platform_for_all               -111.249    -111.249
# pca_1_count_id_pivotby_Platform_for_all               -104.843    -104.843
# pca_2_count_id_pivotby_Platform_for_all                86.7072     86.7072
# pca_3_count_id_pivotby_Platform_for_all                315.714     315.714
# pca_0_count_id_pivotby_Genre_for_all                   -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192     272.192
# count_over_500_Publisher                                 False       False
# count_over_100_Publisher                                  True       False
# pca_0_name_bow_gt_count_5_3                         -0.0145961  -0.0173708
# pca_1_name_bow_gt_count_5_3                         -0.0134632  -0.0177323
# pca_2_name_bow_gt_count_5_3                        -0.00905627  0.00231316
# pca_3_name_bow_gt_count_5_3                         -0.0172936  -0.0192902
# num_word_series_1                                            1           1
# num_word_series_2                                      3.14286           1
# num_word_series_3                                            1     1.85714
# mean_User_Score_groupby_Platform                      0.674268    0.674268
# max_User_Score_groupby_Platform                           0.93        0.93
# min_User_Score_groupby_Platform                           0.02        0.02
# mean_User_Count_groupby_Platform                       53.1232     53.1232
# max_User_Count_groupby_Platform                           2147        2147
# min_User_Count_groupby_Platform                              4           4
# mean_Critic_Score_groupby_Platform                    0.628239    0.628239
# max_Critic_Score_groupby_Platform                         0.97        0.97
# min_Critic_Score_groupby_Platform                         0.19        0.19
# mean_Critic_Count_groupby_Platform                     21.2479     21.2479
# max_Critic_Count_groupby_Platform                           87          87
# min_Critic_Count_groupby_Platform                            4           4
# diff_User_Score_mean_User_Score_groupby_Platform      0.115732  -0.0142679
# diff_User_Score_max_User_Score_groupby_Platform          -0.14       -0.27
# diff_User_Score_min_User_Score_groupby_Platform           0.77        0.64
# diff_User_Count_mean_User_Count_groupby_Platform      -31.1232    -25.1232
# diff_User_Count_max_User_Count_groupby_Platform          -2125       -2119
# diff_User_Count_min_User_Count_groupby_Platform             18          24
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...    0.111761    0.151761
# diff_Critic_Score_max_Critic_Score_groupby_Plat...       -0.23       -0.19
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.55        0.59
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...    -4.24786    0.752137
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -70         -65
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          13          18
# mean_User_Score_groupby_Year_of_Release                    NaN         NaN
# max_User_Score_groupby_Year_of_Release                     NaN         NaN
# min_User_Score_groupby_Year_of_Release                     NaN         NaN
# mean_User_Count_groupby_Year_of_Release                    NaN         NaN
# max_User_Count_groupby_Year_of_Release                     NaN         NaN
# min_User_Count_groupby_Year_of_Release                     NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN         NaN
#
#                                                              2           3  \
# id                                                           2           3
# Year_of_Release                                           2006        1981
# le_Platform                                                 19           0
# le_Genre                                                     0           0
# le_Rating                                                    2           6
# Critic_Score                                              0.73         NaN
# User_Score                                                0.74         NaN
# Critic_Count                                                 5         NaN
# User_Count                                                  10         NaN
# is_tbd                                                   False       False
# multi_pf_count                                               7           1
# other_platform_1                                             0           0
# other_platform_2                                             0           0
# other_platform_3                                             0           0
# other_platform_4                                             0           0
# other_platform_5                                             1           0
# other_platform_6                                             0           0
# other_platform_7                                             0           0
# other_platform_8                                             0           0
# other_platform_9                                             0           0
# other_platform_10                                            0           0
# other_platform_11                                            0           0
# other_platform_12                                            0           0
# other_platform_13                                            0           0
# other_platform_14                                            1           0
# other_platform_15                                            0           0
# other_platform_16                                            0           0
# other_platform_17                                            1           0
# other_platform_18                                            1           0
# other_platform_19                                            0           0
# other_platform_20                                            0           0
# other_platform_21                                            0           0
# other_platform_22                                            0           0
# other_platform_23                                            0           0
# other_platform_24                                            0           0
# other_platform_25                                            0           0
# other_platform_26                                            0           0
# other_platform_27                                            1           0
# other_platform_28                                            0           0
# other_platform_29                                            1           0
# other_platform_30                                            0           0
# other_platform_31                                            0           0
# count_id_groupby_Platform                                 1209         133
# count_id_groupby_Genre                                    3370        3370
# count_id_groupby_Developer                                  77         NaN
# count_id_groupby_Rating                                   1420         NaN
# count_id_groupby_Year_of_Release                           NaN         NaN
# count_Publisher_groupby_Developer                           77         NaN
# count_Genre_groupby_Developer                               77         NaN
# count_Platform_groupby_Developer                            77         NaN
# count_Year_of_Release_groupby_Developer                     65         NaN
# nunique_Developer_groupby_Publisher                         43         127
# nunique_Genre_groupby_Publisher                              9          12
# nunique_Platform_groupby_Publisher                          13          15
# nunique_Year_of_Release_groupby_Publisher                   13          23
# pca_0_count_id_pivotby_Developer_for_all              -53.3165         NaN
# pca_1_count_id_pivotby_Developer_for_all               34.0593         NaN
# pca_0_count_id_pivotby_Publisher_for_all              -93.7891     30.9391
# pca_1_count_id_pivotby_Publisher_for_all              -8.43031    -13.7852
# pca_2_count_id_pivotby_Publisher_for_all              -93.2896     4.53849
# pca_3_count_id_pivotby_Publisher_for_all               118.894      154.97
# pca_0_count_id_pivotby_Platform_for_all                74.2622     10.2364
# pca_1_count_id_pivotby_Platform_for_all                 191.25    -17.3691
# pca_2_count_id_pivotby_Platform_for_all                6.18492    -2.75132
# pca_3_count_id_pivotby_Platform_for_all                236.698     -146.18
# pca_0_count_id_pivotby_Genre_for_all                   -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192     272.192
# count_over_500_Publisher                                 False       False
# count_over_100_Publisher                                  True        True
# pca_0_name_bow_gt_count_5_3                         -0.0145961  -0.0140941
# pca_1_name_bow_gt_count_5_3                         -0.0134632  -0.0106854
# pca_2_name_bow_gt_count_5_3                        -0.00905627 -0.00930718
# pca_3_name_bow_gt_count_5_3                         -0.0172936  -0.0152041
# num_word_series_1                                            1           1
# num_word_series_2                                      3.14286           1
# num_word_series_3                                            1           1
# mean_User_Score_groupby_Platform                      0.722827         NaN
# max_User_Score_groupby_Platform                           0.97         NaN
# min_User_Score_groupby_Platform                           0.06         NaN
# mean_User_Count_groupby_Platform                       30.4228         NaN
# max_User_Count_groupby_Platform                            565         NaN
# min_User_Count_groupby_Platform                              4         NaN
# mean_Critic_Score_groupby_Platform                    0.674242         NaN
# max_Critic_Score_groupby_Platform                         0.91         NaN
# min_Critic_Score_groupby_Platform                         0.28         NaN
# mean_Critic_Count_groupby_Platform                     23.3983         NaN
# max_Critic_Count_groupby_Platform                           79         NaN
# min_Critic_Count_groupby_Platform                            4         NaN
# diff_User_Score_mean_User_Score_groupby_Platform     0.0171734         NaN
# diff_User_Score_max_User_Score_groupby_Platform          -0.23         NaN
# diff_User_Score_min_User_Score_groupby_Platform           0.68         NaN
# diff_User_Count_mean_User_Count_groupby_Platform      -20.4228         NaN
# diff_User_Count_max_User_Count_groupby_Platform           -555         NaN
# diff_User_Count_min_User_Count_groupby_Platform              6         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...   0.0557576         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Plat...       -0.18         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.45         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...    -18.3983         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -74         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Plat...           1         NaN
# mean_User_Score_groupby_Year_of_Release                    NaN         NaN
# max_User_Score_groupby_Year_of_Release                     NaN         NaN
# min_User_Score_groupby_Year_of_Release                     NaN         NaN
# mean_User_Count_groupby_Year_of_Release                    NaN         NaN
# max_User_Count_groupby_Year_of_Release                     NaN         NaN
# min_User_Count_groupby_Year_of_Release                     NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN         NaN
#
#                                                             4
# id                                                          4
# Year_of_Release                                          2009
# le_Platform                                                26
# le_Genre                                                    0
# le_Rating                                                   2
# Critic_Score                                             0.76
# User_Score                                               0.78
# Critic_Count                                                8
# User_Count                                                 13
# is_tbd                                                  False
# multi_pf_count                                              8
# other_platform_1                                            0
# other_platform_2                                            0
# other_platform_3                                            1
# other_platform_4                                            0
# other_platform_5                                            1
# other_platform_6                                            0
# other_platform_7                                            0
# other_platform_8                                            0
# other_platform_9                                            0
# other_platform_10                                           0
# other_platform_11                                           0
# other_platform_12                                           0
# other_platform_13                                           0
# other_platform_14                                           1
# other_platform_15                                           0
# other_platform_16                                           0
# other_platform_17                                           0
# other_platform_18                                           1
# other_platform_19                                           0
# other_platform_20                                           1
# other_platform_21                                           1
# other_platform_22                                           0
# other_platform_23                                           0
# other_platform_24                                           0
# other_platform_25                                           0
# other_platform_26                                           0
# other_platform_27                                           0
# other_platform_28                                           0
# other_platform_29                                           1
# other_platform_30                                           0
# other_platform_31                                           0
# count_id_groupby_Platform                                1320
# count_id_groupby_Genre                                   3370
# count_id_groupby_Developer                                 77
# count_id_groupby_Rating                                  1420
# count_id_groupby_Year_of_Release                          NaN
# count_Publisher_groupby_Developer                          77
# count_Genre_groupby_Developer                              77
# count_Platform_groupby_Developer                           77
# count_Year_of_Release_groupby_Developer                    65
# nunique_Developer_groupby_Publisher                        43
# nunique_Genre_groupby_Publisher                             9
# nunique_Platform_groupby_Publisher                         13
# nunique_Year_of_Release_groupby_Publisher                  13
# pca_0_count_id_pivotby_Developer_for_all             -53.3165
# pca_1_count_id_pivotby_Developer_for_all              34.0593
# pca_0_count_id_pivotby_Publisher_for_all             -93.7891
# pca_1_count_id_pivotby_Publisher_for_all             -8.43031
# pca_2_count_id_pivotby_Publisher_for_all             -93.2896
# pca_3_count_id_pivotby_Publisher_for_all              118.894
# pca_0_count_id_pivotby_Platform_for_all              -111.249
# pca_1_count_id_pivotby_Platform_for_all              -104.843
# pca_2_count_id_pivotby_Platform_for_all               86.7072
# pca_3_count_id_pivotby_Platform_for_all               315.714
# pca_0_count_id_pivotby_Genre_for_all                  -32.595
# pca_1_count_id_pivotby_Genre_for_all                  1.16093
# pca_2_count_id_pivotby_Genre_for_all                  396.248
# pca_3_count_id_pivotby_Genre_for_all                  272.192
# count_over_500_Publisher                                False
# count_over_100_Publisher                                 True
# pca_0_name_bow_gt_count_5_3                        -0.0153978
# pca_1_name_bow_gt_count_5_3                        -0.0141588
# pca_2_name_bow_gt_count_5_3                        -0.0100863
# pca_3_name_bow_gt_count_5_3                         -0.019106
# num_word_series_1                                           1
# num_word_series_2                                           1
# num_word_series_3                                       1.875
# mean_User_Score_groupby_Platform                     0.674268
# max_User_Score_groupby_Platform                          0.93
# min_User_Score_groupby_Platform                          0.02
# mean_User_Count_groupby_Platform                      53.1232
# max_User_Count_groupby_Platform                          2147
# min_User_Count_groupby_Platform                             4
# mean_Critic_Score_groupby_Platform                   0.628239
# max_Critic_Score_groupby_Platform                        0.97
# min_Critic_Score_groupby_Platform                        0.19
# mean_Critic_Count_groupby_Platform                    21.2479
# max_Critic_Count_groupby_Platform                          87
# min_Critic_Count_groupby_Platform                           4
# diff_User_Score_mean_User_Score_groupby_Platform     0.105732
# diff_User_Score_max_User_Score_groupby_Platform         -0.15
# diff_User_Score_min_User_Score_groupby_Platform          0.76
# diff_User_Count_mean_User_Count_groupby_Platform     -40.1232
# diff_User_Count_max_User_Count_groupby_Platform         -2134
# diff_User_Count_min_User_Count_groupby_Platform             9
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...   0.131761
# diff_Critic_Score_max_Critic_Score_groupby_Plat...      -0.21
# diff_Critic_Score_min_Critic_Score_groupby_Plat...       0.57
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...   -13.2479
# diff_Critic_Count_max_Critic_Count_groupby_Plat...        -79
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          4
# mean_User_Score_groupby_Year_of_Release                   NaN
# max_User_Score_groupby_Year_of_Release                    NaN
# min_User_Score_groupby_Year_of_Release                    NaN
# mean_User_Count_groupby_Year_of_Release                   NaN
# max_User_Count_groupby_Year_of_Release                    NaN
# min_User_Count_groupby_Year_of_Release                    NaN
# mean_Critic_Score_groupby_Year_of_Release                 NaN
# max_Critic_Score_groupby_Year_of_Release                  NaN
# min_Critic_Score_groupby_Year_of_Release                  NaN
# mean_Critic_Count_groupby_Year_of_Release                 NaN
# max_Critic_Count_groupby_Year_of_Release                  NaN
# min_Critic_Count_groupby_Year_of_Release                  NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...        NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...        NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...        NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...        NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...        NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...        NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...        NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...        NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...        NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...        NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...        NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...        NaN

# %%
@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mykaggle.feature.te import TE
from mykaggle.feature.te_other_aggs import TEOtherAggs
from mykaggle.feature.te_year_platform import TEYearPlatform
from mykaggle.feature.te_year_genre import TEYearGenre
from mykaggle.feature.year_rank6 import YearRank6
from mykaggle.feature.platform_time_diff import PlatformTimeDiff
from mykaggle.feature.platform_to_region_has_sales import PlatformToRegionHasSales
from mykaggle.feature.platform_to_region_sales import PlatformToRegionSales


te_train = TE(train=True)
te_test = TE(train=False)
# te_oa_train = TEOtherAggs(train=True)
# te_oa_test = TEOtherAggs(train=False)
# te_yp_train = TEYearPlatform(train=True)
# te_yp_test = TEYearPlatform(train=False)
# te_yg_train = TEYearGenre(train=True)
# te_yg_test = TEYearGenre(train=False)
year_rank_train = YearRank6(train=True)
year_rank_test = YearRank6(train=False)
ptdiff_train = PlatformTimeDiff(train=True)
ptdiff_test = PlatformTimeDiff(train=False)
# ptrhs_train = PlatformToRegionHasSales(train=True)
# ptrhs_test = PlatformToRegionHasSales(train=False)
# ptrs_train = PlatformToRegionSales(train=True)
# ptrs_test = PlatformToRegionSales(train=False)


def get_oof_feature(
    df_train: pd.DataFrame, df_valid: pd.DataFrame, y_train: np.ndarray,
    df_train_original: pd.DataFrame, df_valid_original: pd.DataFrame
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    df_train.loc[:, 'target'] = y_train.copy()
    _train_others = copy.deepcopy(train_others)
    _test_others = copy.deepcopy(test_others)
    _train_others['main'] = df_train_original.copy().reset_index().drop('index', axis=1)
    _train_others['another'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['main'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['another'] = df_train_original.copy().reset_index().drop('index', axis=1)
    df_train = df_train.reset_index().drop('index', axis=1)
    df_valid = df_valid.reset_index().drop('index', axis=1)
    df_train = te_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = te_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_oa_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_oa_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_yp_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_yp_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_yg_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_yg_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = year_rank_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = year_rank_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = ptdiff_train(df_train, others=_train_others, use_cache=False, save_cache=True)
    df_valid = ptdiff_test(df_valid, others=_test_others, use_cache=False, save_cache=True)
#     df_train = ptrhs_train(df_train, others=_train_others, use_cache=False, save_cache=True)
#     df_valid = ptrhs_test(df_valid, others=_test_others, use_cache=False, save_cache=True)
#     df_train = ptrs_train(df_train, others=_train_others, use_cache=False, save_cache=True)
#     df_valid = ptrs_test(df_valid, others=_test_others, use_cache=False, save_cache=True)
    return df_train.drop(['id', 'target'], axis=1), df_valid.drop('id', axis=1)

# %%
def train(
    settings: Dict[str, Any],
    logger: MLLogger,
    df: pd.DataFrame,
    df_original: pd.DataFrame,
    y: np.ndarray,
    ckptdir: Path
) -> Tuple:
    logger.log_params(settings['training'])
    logger.log_params(settings['feature'])
    logger.log_params(settings['lgbm_params'])
    X = df.copy()
    lgbm_params = settings['lgbm_params']
    models = []
    oof_pred = np.zeros_like(y, dtype=np.float)
    importances = pd.DataFrame()
    split_file = f'{settings["training"]["validation"]}_{settings["training"]["num_folds"]}fold.pkl'
    splits = pickle.load(open(datadir / split_file, 'rb'))

    for i, (train_idx, valid_idx) in enumerate(splits): 
        x_train, y_train = X.iloc[train_idx], y[train_idx]
        x_valid, y_valid = X.iloc[valid_idx], y[valid_idx]
        x_train, x_valid = get_oof_feature(
            x_train, x_valid, y_train,
            df_original.iloc[train_idx], df_original.iloc[valid_idx]
        )
        train_data = lgb.Dataset(x_train.values, label=y_train)
        valid_data = lgb.Dataset(x_valid.values, label=y_valid)

        with timer(prefix='train fold={} '.format(i + 1)):
            clf = lgb.train(
                lgbm_params,
                train_data, 
                num_boost_round=settings['training']['num_rounds'],
                valid_names=['train', 'valid'],
                valid_sets=[train_data, valid_data],  
                early_stopping_rounds=settings['training']['early_stopping_rounds'],
#                 feval=rmse,
                verbose_eval=settings['training']['verbose_eval']
            )
        pred_i = clf.predict(x_valid.values)
        oof_pred[valid_idx] = pred_i
        models.append(clf)
        importances = compute_importances(importances, x_train.columns, models[i], fold=i)
        fpr, tpr, thresholds = roc_curve(y_valid, pred_i)
        fold_score = auc(fpr, tpr)
        logger.log_metric(f'rmsle_fold_{i}', fold_score)
        print(f'Fold {i} AUC: {fold_score:.4f}')
        clf.save_model(str(ckptdir / f'model.txt'))
        logger.log_artifact(str(ckptdir / f'model.txt'), artifact_path=f'{i}')

    fpr, tpr, thresholds = roc_curve(y, oof_pred)
    score = auc(fpr, tpr)
    logger.log_metric(f'AUC', score)
    print('FINISHED; whole score: {:.4f}'.format(score))
    save_importances(importances, ckptdir)
    return oof_pred, models, score, importances

# %%
def visualize_oof(
    y_true: np.ndarray, y_pred: np.ndarray
) -> None:
    plt.figure(figsize=(5, 5))
    plt.plot([-100, 5000], [-100, 5000], color='black')
    plt.scatter(y_true, y_pred, alpha=0.2)
    plt.xlim(-100, 4000)
    plt.ylim(-100, 4000)
    plt.xlabel('True')
    plt.ylabel('Pred')


def predict(
    models: List[lgb.Booster],
    df_test: pd.DataFrame,
    df_train: pd.DataFrame,
    df_test_original: pd.DataFrame
) -> np.ndarray:
    '''
    fold 分のモデルと test の特徴 dataframe を受け取って、予測したものを返します。
    :param models: kfold 分のモデル
    :param test_df: test dataset の特徴
    :return: 予測
    '''
    _, test = get_oof_feature(
        df_train.copy(), df_test.copy(), df_train['target'].values, df_train.copy(), df_test_original.copy()
    )
    display(test.head().T)
    preds = np.array([model.predict(test) for model in models])
#     preds = np.expm1(preds)
    preds = np.mean(preds, axis=0)
    return preds

    
def submit(preds: np.ndarray, ckptdir: Path) -> pd.DataFrame:
    '''
    test data の prediction を受け取って submission ファイルを作成します。
    :param preds: test data の予測
    :param ckptdir: 保存場所
    :return: submission df
    '''
    sub_df = pd.DataFrame({ target_column: preds })
    sub_df.to_csv(ckptdir / f'{settings["name"]}.csv', index=False)
    return sub_df

# %%
logger = MLLogger('cfiken', ckptdir)

# %%
with logger.start(experiment_name=settings['competition'], run_name=settings['name']):
    oof, models, cv, importances = train(
        settings,
        logger,
        df_f_train,
        df_train,
        df_train.loc[:, 'target'].values,
        ckptdir
    )
    preds = predict(models, df_f_test, df_train, df_test)
    sub_df = submit(preds, ckptdir)
# Out:
# [LightGBM] [Info] Number of positive: 3079, number of negative: 3608
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014822 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9244
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.460446 -> initscore=-0.158549
# [LightGBM] [Info] Start training from score -0.158549
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.948088	valid's auc: 0.912073
# [40]	train's auc: 0.951261	valid's auc: 0.911824
# [60]	train's auc: 0.95455	valid's auc: 0.915141
# [80]	train's auc: 0.957298	valid's auc: 0.917176
# [100]	train's auc: 0.960331	valid's auc: 0.92188
# [120]	train's auc: 0.962677	valid's auc: 0.924083
# [140]	train's auc: 0.965179	valid's auc: 0.925882
# [160]	train's auc: 0.96701	valid's auc: 0.927944
# [180]	train's auc: 0.968687	valid's auc: 0.928364
# [200]	train's auc: 0.970334	valid's auc: 0.928923
# [220]	train's auc: 0.971798	valid's auc: 0.928602
# [240]	train's auc: 0.973443	valid's auc: 0.928326
# [260]	train's auc: 0.974889	valid's auc: 0.92957
# [280]	train's auc: 0.976413	valid's auc: 0.930917
# [300]	train's auc: 0.97775	valid's auc: 0.932035
# [320]	train's auc: 0.979056	valid's auc: 0.933451
# [340]	train's auc: 0.980269	valid's auc: 0.933599
# [360]	train's auc: 0.981375	valid's auc: 0.934216
# [380]	train's auc: 0.982418	valid's auc: 0.934598
# [400]	train's auc: 0.983439	valid's auc: 0.935009
# [420]	train's auc: 0.984455	valid's auc: 0.935314
# [440]	train's auc: 0.985342	valid's auc: 0.935468
# [460]	train's auc: 0.98621	valid's auc: 0.935485
# [480]	train's auc: 0.987021	valid's auc: 0.935611
# [500]	train's auc: 0.987837	valid's auc: 0.93575
# [520]	train's auc: 0.988575	valid's auc: 0.93563
# [540]	train's auc: 0.989277	valid's auc: 0.935327
# [560]	train's auc: 0.98993	valid's auc: 0.93526
# [580]	train's auc: 0.990558	valid's auc: 0.935066
# [600]	train's auc: 0.991161	valid's auc: 0.934669
# [620]	train's auc: 0.991722	valid's auc: 0.934449
# [640]	train's auc: 0.992264	valid's auc: 0.933884
# [660]	train's auc: 0.992737	valid's auc: 0.933615
# [680]	train's auc: 0.993209	valid's auc: 0.9335
# [700]	train's auc: 0.993642	valid's auc: 0.933026
# [720]	train's auc: 0.994028	valid's auc: 0.932712
# [740]	train's auc: 0.994387	valid's auc: 0.932597
# [760]	train's auc: 0.994748	valid's auc: 0.931985
# [780]	train's auc: 0.995078	valid's auc: 0.931587
# [800]	train's auc: 0.995408	valid's auc: 0.931065
# [820]	train's auc: 0.995711	valid's auc: 0.930691
# [840]	train's auc: 0.995961	valid's auc: 0.93021
# [860]	train's auc: 0.996222	valid's auc: 0.930102
# [880]	train's auc: 0.996475	valid's auc: 0.929919
# [900]	train's auc: 0.996695	valid's auc: 0.929506
# [920]	train's auc: 0.996919	valid's auc: 0.929176
# [940]	train's auc: 0.997111	valid's auc: 0.928808
# [960]	train's auc: 0.997297	valid's auc: 0.928468
# [980]	train's auc: 0.99748	valid's auc: 0.928566
# [1000]	train's auc: 0.997631	valid's auc: 0.928621
# [1020]	train's auc: 0.99778	valid's auc: 0.928062
# [1040]	train's auc: 0.997948	valid's auc: 0.927923
# [1060]	train's auc: 0.998081	valid's auc: 0.927695
# [1080]	train's auc: 0.9982	valid's auc: 0.927228
# [1100]	train's auc: 0.998321	valid's auc: 0.92671
# [1120]	train's auc: 0.998431	valid's auc: 0.926337
# [1140]	train's auc: 0.998542	valid's auc: 0.926091
# [1160]	train's auc: 0.998633	valid's auc: 0.925978
# [1180]	train's auc: 0.998716	valid's auc: 0.925742
# [1200]	train's auc: 0.998797	valid's auc: 0.925666
# [1220]	train's auc: 0.998866	valid's auc: 0.9255
# [1240]	train's auc: 0.998933	valid's auc: 0.92511
# [1260]	train's auc: 0.998997	valid's auc: 0.92502
# [1280]	train's auc: 0.999054	valid's auc: 0.92498
# [1300]	train's auc: 0.999109	valid's auc: 0.924856
# [1320]	train's auc: 0.999171	valid's auc: 0.924881
# [1340]	train's auc: 0.999218	valid's auc: 0.924856
# [1360]	train's auc: 0.99927	valid's auc: 0.92496
# [1380]	train's auc: 0.999315	valid's auc: 0.924893
# [1400]	train's auc: 0.999354	valid's auc: 0.924839
# [1420]	train's auc: 0.999394	valid's auc: 0.92435
# [1440]	train's auc: 0.999431	valid's auc: 0.924246
# [1460]	train's auc: 0.999464	valid's auc: 0.924232
# [1480]	train's auc: 0.999499	valid's auc: 0.923998
# [1500]	train's auc: 0.999532	valid's auc: 0.923668
# [1520]	train's auc: 0.999562	valid's auc: 0.923661
# Early stopping, best iteration is:
# [524]	train's auc: 0.988718	valid's auc: 0.935778
# train fold=1 11.616[s]
# Fold 0 AUC: 0.9358
# [LightGBM] [Info] Number of positive: 2516, number of negative: 4171
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017496 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9250
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.376252 -> initscore=-0.505485
# [LightGBM] [Info] Start training from score -0.505485
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.956226	valid's auc: 0.822438
# [40]	train's auc: 0.960043	valid's auc: 0.827087
# [60]	train's auc: 0.962293	valid's auc: 0.840707
# [80]	train's auc: 0.963796	valid's auc: 0.845396
# [100]	train's auc: 0.965381	valid's auc: 0.84447
# [120]	train's auc: 0.966911	valid's auc: 0.84402
# [140]	train's auc: 0.968612	valid's auc: 0.84219
# [160]	train's auc: 0.970058	valid's auc: 0.840554
# [180]	train's auc: 0.971763	valid's auc: 0.840083
# [200]	train's auc: 0.973403	valid's auc: 0.842047
# [220]	train's auc: 0.974893	valid's auc: 0.842772
# [240]	train's auc: 0.976198	valid's auc: 0.841794
# [260]	train's auc: 0.977624	valid's auc: 0.842321
# [280]	train's auc: 0.978906	valid's auc: 0.841999
# [300]	train's auc: 0.980214	valid's auc: 0.843937
# [320]	train's auc: 0.981434	valid's auc: 0.846111
# [340]	train's auc: 0.982582	valid's auc: 0.848808
# [360]	train's auc: 0.983659	valid's auc: 0.849659
# [380]	train's auc: 0.984633	valid's auc: 0.85087
# [400]	train's auc: 0.985589	valid's auc: 0.853377
# [420]	train's auc: 0.986527	valid's auc: 0.854539
# [440]	train's auc: 0.987381	valid's auc: 0.856398
# [460]	train's auc: 0.988227	valid's auc: 0.857586
# [480]	train's auc: 0.988967	valid's auc: 0.858595
# [500]	train's auc: 0.989731	valid's auc: 0.859439
# [520]	train's auc: 0.990428	valid's auc: 0.859579
# [540]	train's auc: 0.991037	valid's auc: 0.859477
# [560]	train's auc: 0.991628	valid's auc: 0.860553
# [580]	train's auc: 0.992172	valid's auc: 0.860725
# [600]	train's auc: 0.992677	valid's auc: 0.861336
# [620]	train's auc: 0.99315	valid's auc: 0.861398
# [640]	train's auc: 0.993585	valid's auc: 0.862118
# [660]	train's auc: 0.994008	valid's auc: 0.862169
# [680]	train's auc: 0.994395	valid's auc: 0.863476
# [700]	train's auc: 0.994756	valid's auc: 0.863974
# [720]	train's auc: 0.995135	valid's auc: 0.863478
# [740]	train's auc: 0.995452	valid's auc: 0.863748
# [760]	train's auc: 0.995764	valid's auc: 0.864098
# [780]	train's auc: 0.996029	valid's auc: 0.864466
# [800]	train's auc: 0.996277	valid's auc: 0.864076
# [820]	train's auc: 0.996516	valid's auc: 0.864636
# [840]	train's auc: 0.996764	valid's auc: 0.864668
# [860]	train's auc: 0.996977	valid's auc: 0.864651
# [880]	train's auc: 0.997165	valid's auc: 0.865132
# [900]	train's auc: 0.997332	valid's auc: 0.865068
# [920]	train's auc: 0.997503	valid's auc: 0.865414
# [940]	train's auc: 0.997655	valid's auc: 0.86546
# [960]	train's auc: 0.997798	valid's auc: 0.865841
# [980]	train's auc: 0.997956	valid's auc: 0.866613
# [1000]	train's auc: 0.998099	valid's auc: 0.867064
# [1020]	train's auc: 0.998238	valid's auc: 0.867055
# [1040]	train's auc: 0.998361	valid's auc: 0.867401
# [1060]	train's auc: 0.998465	valid's auc: 0.867269
# [1080]	train's auc: 0.998572	valid's auc: 0.867272
# [1100]	train's auc: 0.998669	valid's auc: 0.867641
# [1120]	train's auc: 0.998747	valid's auc: 0.86794
# [1140]	train's auc: 0.998818	valid's auc: 0.868187
# [1160]	train's auc: 0.998904	valid's auc: 0.867785
# [1180]	train's auc: 0.998975	valid's auc: 0.867674
# [1200]	train's auc: 0.999035	valid's auc: 0.86777
# [1220]	train's auc: 0.999097	valid's auc: 0.867651
# [1240]	train's auc: 0.999147	valid's auc: 0.867679
# [1260]	train's auc: 0.999193	valid's auc: 0.868063
# [1280]	train's auc: 0.999241	valid's auc: 0.867909
# [1300]	train's auc: 0.999278	valid's auc: 0.86807
# [1320]	train's auc: 0.999317	valid's auc: 0.867827
# [1340]	train's auc: 0.999356	valid's auc: 0.868038
# [1360]	train's auc: 0.999401	valid's auc: 0.868096
# [1380]	train's auc: 0.999437	valid's auc: 0.868354
# [1400]	train's auc: 0.999466	valid's auc: 0.868298
# [1420]	train's auc: 0.999505	valid's auc: 0.86843
# [1440]	train's auc: 0.999549	valid's auc: 0.868794
# [1460]	train's auc: 0.999577	valid's auc: 0.868859
# [1480]	train's auc: 0.999598	valid's auc: 0.869295
# [1500]	train's auc: 0.999629	valid's auc: 0.86952
# [1520]	train's auc: 0.999651	valid's auc: 0.869643
# [1540]	train's auc: 0.99967	valid's auc: 0.869649
# [1560]	train's auc: 0.999693	valid's auc: 0.869841
# [1580]	train's auc: 0.999714	valid's auc: 0.870137
# [1600]	train's auc: 0.999732	valid's auc: 0.869899
# [1620]	train's auc: 0.999747	valid's auc: 0.870304
# [1640]	train's auc: 0.999766	valid's auc: 0.8706
# [1660]	train's auc: 0.999777	valid's auc: 0.870747
# [1680]	train's auc: 0.999794	valid's auc: 0.870879
# [1700]	train's auc: 0.999807	valid's auc: 0.87093
# [1720]	train's auc: 0.999817	valid's auc: 0.870913
# [1740]	train's auc: 0.999827	valid's auc: 0.871084
# [1760]	train's auc: 0.999837	valid's auc: 0.87123
# [1780]	train's auc: 0.999847	valid's auc: 0.871429
# [1800]	train's auc: 0.999853	valid's auc: 0.871524
# [1820]	train's auc: 0.999861	valid's auc: 0.871452
# [1840]	train's auc: 0.999869	valid's auc: 0.871605
# [1860]	train's auc: 0.999877	valid's auc: 0.871409
# [1880]	train's auc: 0.999882	valid's auc: 0.871034
# [1900]	train's auc: 0.999886	valid's auc: 0.871078
# [1920]	train's auc: 0.99989	valid's auc: 0.871054
# [1940]	train's auc: 0.999895	valid's auc: 0.871285
# [1960]	train's auc: 0.999901	valid's auc: 0.871465
# [1980]	train's auc: 0.999904	valid's auc: 0.871664
# [2000]	train's auc: 0.999907	valid's auc: 0.871766
# [2020]	train's auc: 0.999912	valid's auc: 0.871757
# [2040]	train's auc: 0.99992	valid's auc: 0.871784
# [2060]	train's auc: 0.999923	valid's auc: 0.87193
# [2080]	train's auc: 0.999929	valid's auc: 0.872188
# [2100]	train's auc: 0.999932	valid's auc: 0.87228
# [2120]	train's auc: 0.999935	valid's auc: 0.872377
# [2140]	train's auc: 0.999939	valid's auc: 0.872356
# [2160]	train's auc: 0.999942	valid's auc: 0.872314
# [2180]	train's auc: 0.999947	valid's auc: 0.872069
# [2200]	train's auc: 0.999951	valid's auc: 0.872022
# [2220]	train's auc: 0.999953	valid's auc: 0.872106
# [2240]	train's auc: 0.999955	valid's auc: 0.872194
# [2260]	train's auc: 0.999958	valid's auc: 0.872066
# [2280]	train's auc: 0.999962	valid's auc: 0.871946
# [2300]	train's auc: 0.999965	valid's auc: 0.872057
# [2320]	train's auc: 0.999966	valid's auc: 0.872119
# [2340]	train's auc: 0.999968	valid's auc: 0.872274
# [2360]	train's auc: 0.99997	valid's auc: 0.872042
# [2380]	train's auc: 0.999974	valid's auc: 0.871676
# [2400]	train's auc: 0.999975	valid's auc: 0.871587
# [2420]	train's auc: 0.999978	valid's auc: 0.871477
# [2440]	train's auc: 0.999978	valid's auc: 0.8712
# [2460]	train's auc: 0.99998	valid's auc: 0.871028
# [2480]	train's auc: 0.999982	valid's auc: 0.870641
# [2500]	train's auc: 0.999983	valid's auc: 0.870694
# [2520]	train's auc: 0.999984	valid's auc: 0.8707
# [2540]	train's auc: 0.999985	valid's auc: 0.870716
# [2560]	train's auc: 0.999986	valid's auc: 0.870766
# [2580]	train's auc: 0.999987	valid's auc: 0.87081
# [2600]	train's auc: 0.999987	valid's auc: 0.870793
# [2620]	train's auc: 0.999988	valid's auc: 0.870637
# [2640]	train's auc: 0.999989	valid's auc: 0.87072
# [2660]	train's auc: 0.99999	valid's auc: 0.870763
# [2680]	train's auc: 0.999991	valid's auc: 0.870643
# [2700]	train's auc: 0.999991	valid's auc: 0.870373
# [2720]	train's auc: 0.999993	valid's auc: 0.870327
# [2740]	train's auc: 0.999993	valid's auc: 0.870379
# [2760]	train's auc: 0.999994	valid's auc: 0.870333
# [2780]	train's auc: 0.999995	valid's auc: 0.870045
# [2800]	train's auc: 0.999995	valid's auc: 0.869929
# [2820]	train's auc: 0.999996	valid's auc: 0.87001
# [2840]	train's auc: 0.999996	valid's auc: 0.87003
# [2860]	train's auc: 0.999997	valid's auc: 0.870013
# [2880]	train's auc: 0.999997	valid's auc: 0.870013
# [2900]	train's auc: 0.999997	valid's auc: 0.869819
# [2920]	train's auc: 0.999997	valid's auc: 0.869794
# [2940]	train's auc: 0.999998	valid's auc: 0.869808
# [2960]	train's auc: 0.999998	valid's auc: 0.869825
# [2980]	train's auc: 0.999998	valid's auc: 0.869212
# [3000]	train's auc: 0.999998	valid's auc: 0.868794
# [3020]	train's auc: 0.999998	valid's auc: 0.868648
# [3040]	train's auc: 0.999999	valid's auc: 0.868676
# [3060]	train's auc: 0.999999	valid's auc: 0.868557
# [3080]	train's auc: 0.999999	valid's auc: 0.86833
# [3100]	train's auc: 0.999999	valid's auc: 0.867899
# [3120]	train's auc: 0.999999	valid's auc: 0.867909
# [3140]	train's auc: 0.999999	valid's auc: 0.867638
# Early stopping, best iteration is:
# [2143]	train's auc: 0.99994	valid's auc: 0.872468
# train fold=2 21.499[s]
# Fold 1 AUC: 0.8725
# [LightGBM] [Info] Number of positive: 2743, number of negative: 3944
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008804 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9281
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 121
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.410199 -> initscore=-0.363143
# [LightGBM] [Info] Start training from score -0.363143
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.960605	valid's auc: 0.877095
# [40]	train's auc: 0.963092	valid's auc: 0.880632
# [60]	train's auc: 0.964859	valid's auc: 0.885285
# [80]	train's auc: 0.967487	valid's auc: 0.889876
# [100]	train's auc: 0.969195	valid's auc: 0.890906
# [120]	train's auc: 0.970654	valid's auc: 0.892496
# [140]	train's auc: 0.972418	valid's auc: 0.893346
# [160]	train's auc: 0.974299	valid's auc: 0.895083
# [180]	train's auc: 0.975667	valid's auc: 0.896365
# [200]	train's auc: 0.977088	valid's auc: 0.897625
# [220]	train's auc: 0.978385	valid's auc: 0.898315
# [240]	train's auc: 0.979634	valid's auc: 0.898098
# [260]	train's auc: 0.980882	valid's auc: 0.898942
# [280]	train's auc: 0.982035	valid's auc: 0.899528
# [300]	train's auc: 0.983026	valid's auc: 0.899773
# [320]	train's auc: 0.98409	valid's auc: 0.900443
# [340]	train's auc: 0.985076	valid's auc: 0.90133
# [360]	train's auc: 0.98602	valid's auc: 0.902078
# [380]	train's auc: 0.986917	valid's auc: 0.903371
# [400]	train's auc: 0.987796	valid's auc: 0.904307
# [420]	train's auc: 0.988611	valid's auc: 0.905027
# [440]	train's auc: 0.989396	valid's auc: 0.905356
# [460]	train's auc: 0.990121	valid's auc: 0.906166
# [480]	train's auc: 0.990795	valid's auc: 0.906676
# [500]	train's auc: 0.991421	valid's auc: 0.90714
# [520]	train's auc: 0.992001	valid's auc: 0.907241
# [540]	train's auc: 0.992557	valid's auc: 0.907234
# [560]	train's auc: 0.993077	valid's auc: 0.906925
# [580]	train's auc: 0.993529	valid's auc: 0.9069
# [600]	train's auc: 0.994007	valid's auc: 0.906562
# [620]	train's auc: 0.994428	valid's auc: 0.906822
# [640]	train's auc: 0.994805	valid's auc: 0.906517
# [660]	train's auc: 0.995156	valid's auc: 0.906545
# [680]	train's auc: 0.995502	valid's auc: 0.906073
# [700]	train's auc: 0.99583	valid's auc: 0.905992
# [720]	train's auc: 0.996122	valid's auc: 0.905753
# [740]	train's auc: 0.9964	valid's auc: 0.90567
# [760]	train's auc: 0.996643	valid's auc: 0.905071
# [780]	train's auc: 0.996882	valid's auc: 0.904534
# [800]	train's auc: 0.997132	valid's auc: 0.904149
# [820]	train's auc: 0.997347	valid's auc: 0.904274
# [840]	train's auc: 0.997551	valid's auc: 0.904044
# [860]	train's auc: 0.997756	valid's auc: 0.904027
# [880]	train's auc: 0.997928	valid's auc: 0.903679
# [900]	train's auc: 0.998077	valid's auc: 0.903507
# [920]	train's auc: 0.998242	valid's auc: 0.903353
# [940]	train's auc: 0.99839	valid's auc: 0.903254
# [960]	train's auc: 0.998527	valid's auc: 0.902901
# [980]	train's auc: 0.998647	valid's auc: 0.902963
# [1000]	train's auc: 0.998765	valid's auc: 0.902655
# [1020]	train's auc: 0.998874	valid's auc: 0.902476
# [1040]	train's auc: 0.998981	valid's auc: 0.902437
# [1060]	train's auc: 0.999068	valid's auc: 0.902413
# [1080]	train's auc: 0.999145	valid's auc: 0.902383
# [1100]	train's auc: 0.99921	valid's auc: 0.902248
# [1120]	train's auc: 0.999273	valid's auc: 0.902033
# [1140]	train's auc: 0.999337	valid's auc: 0.901693
# [1160]	train's auc: 0.999394	valid's auc: 0.901751
# [1180]	train's auc: 0.99944	valid's auc: 0.90163
# [1200]	train's auc: 0.999487	valid's auc: 0.901475
# [1220]	train's auc: 0.999532	valid's auc: 0.901589
# [1240]	train's auc: 0.999577	valid's auc: 0.901529
# [1260]	train's auc: 0.999612	valid's auc: 0.90131
# [1280]	train's auc: 0.999637	valid's auc: 0.90069
# [1300]	train's auc: 0.999672	valid's auc: 0.900273
# [1320]	train's auc: 0.999705	valid's auc: 0.899929
# [1340]	train's auc: 0.999733	valid's auc: 0.899566
# [1360]	train's auc: 0.999757	valid's auc: 0.899444
# [1380]	train's auc: 0.999777	valid's auc: 0.899047
# [1400]	train's auc: 0.9998	valid's auc: 0.898639
# [1420]	train's auc: 0.999818	valid's auc: 0.898569
# [1440]	train's auc: 0.999833	valid's auc: 0.898182
# [1460]	train's auc: 0.999847	valid's auc: 0.897818
# [1480]	train's auc: 0.999863	valid's auc: 0.897482
# [1500]	train's auc: 0.999875	valid's auc: 0.897277
# [1520]	train's auc: 0.999886	valid's auc: 0.897573
# Early stopping, best iteration is:
# [527]	train's auc: 0.992199	valid's auc: 0.907529
# train fold=3 11.587[s]
# Fold 2 AUC: 0.9075
# [LightGBM] [Info] Number of positive: 2825, number of negative: 3862
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9260
# [LightGBM] [Info] Number of data points in the train set: 6687, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.422461 -> initscore=-0.312677
# [LightGBM] [Info] Start training from score -0.312677
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.954264	valid's auc: 0.912809
# [40]	train's auc: 0.957781	valid's auc: 0.913338
# [60]	train's auc: 0.960085	valid's auc: 0.915888
# [80]	train's auc: 0.961445	valid's auc: 0.918166
# [100]	train's auc: 0.963419	valid's auc: 0.921834
# [120]	train's auc: 0.964886	valid's auc: 0.9239
# [140]	train's auc: 0.967062	valid's auc: 0.927189
# [160]	train's auc: 0.968919	valid's auc: 0.930558
# [180]	train's auc: 0.97047	valid's auc: 0.93306
# [200]	train's auc: 0.971938	valid's auc: 0.935381
# [220]	train's auc: 0.97333	valid's auc: 0.937061
# [240]	train's auc: 0.974615	valid's auc: 0.938247
# [260]	train's auc: 0.975993	valid's auc: 0.939482
# [280]	train's auc: 0.97723	valid's auc: 0.940354
# [300]	train's auc: 0.97851	valid's auc: 0.941406
# [320]	train's auc: 0.979621	valid's auc: 0.94219
# [340]	train's auc: 0.980811	valid's auc: 0.942987
# [360]	train's auc: 0.98193	valid's auc: 0.94361
# [380]	train's auc: 0.983009	valid's auc: 0.944109
# [400]	train's auc: 0.984009	valid's auc: 0.944576
# [420]	train's auc: 0.985005	valid's auc: 0.945054
# [440]	train's auc: 0.985888	valid's auc: 0.945621
# [460]	train's auc: 0.986712	valid's auc: 0.945928
# [480]	train's auc: 0.987418	valid's auc: 0.945981
# [500]	train's auc: 0.988155	valid's auc: 0.946381
# [520]	train's auc: 0.988884	valid's auc: 0.946613
# [540]	train's auc: 0.989503	valid's auc: 0.946892
# [560]	train's auc: 0.990083	valid's auc: 0.947234
# [580]	train's auc: 0.990594	valid's auc: 0.947516
# [600]	train's auc: 0.99112	valid's auc: 0.947452
# [620]	train's auc: 0.991631	valid's auc: 0.94746
# [640]	train's auc: 0.992131	valid's auc: 0.947371
# [660]	train's auc: 0.99261	valid's auc: 0.947514
# [680]	train's auc: 0.993067	valid's auc: 0.947618
# [700]	train's auc: 0.993478	valid's auc: 0.947583
# [720]	train's auc: 0.993865	valid's auc: 0.947629
# [740]	train's auc: 0.994203	valid's auc: 0.947599
# [760]	train's auc: 0.994565	valid's auc: 0.947611
# [780]	train's auc: 0.994892	valid's auc: 0.947438
# [800]	train's auc: 0.99521	valid's auc: 0.947345
# [820]	train's auc: 0.995502	valid's auc: 0.947308
# [840]	train's auc: 0.995811	valid's auc: 0.947164
# [860]	train's auc: 0.996071	valid's auc: 0.947135
# [880]	train's auc: 0.996309	valid's auc: 0.94708
# [900]	train's auc: 0.996535	valid's auc: 0.947036
# [920]	train's auc: 0.99675	valid's auc: 0.94699
# [940]	train's auc: 0.996946	valid's auc: 0.946856
# [960]	train's auc: 0.997118	valid's auc: 0.946762
# [980]	train's auc: 0.997293	valid's auc: 0.946732
# [1000]	train's auc: 0.997454	valid's auc: 0.946742
# [1020]	train's auc: 0.997643	valid's auc: 0.946778
# [1040]	train's auc: 0.997795	valid's auc: 0.946704
# [1060]	train's auc: 0.997938	valid's auc: 0.94663
# [1080]	train's auc: 0.998073	valid's auc: 0.946589
# [1100]	train's auc: 0.998192	valid's auc: 0.946404
# [1120]	train's auc: 0.998308	valid's auc: 0.946518
# [1140]	train's auc: 0.99843	valid's auc: 0.94654
# [1160]	train's auc: 0.998545	valid's auc: 0.946575
# [1180]	train's auc: 0.998662	valid's auc: 0.946591
# [1200]	train's auc: 0.99874	valid's auc: 0.946505
# [1220]	train's auc: 0.998816	valid's auc: 0.946468
# [1240]	train's auc: 0.998904	valid's auc: 0.946431
# [1260]	train's auc: 0.99896	valid's auc: 0.946435
# [1280]	train's auc: 0.999017	valid's auc: 0.946329
# [1300]	train's auc: 0.999079	valid's auc: 0.946273
# [1320]	train's auc: 0.999136	valid's auc: 0.946135
# [1340]	train's auc: 0.99919	valid's auc: 0.946051
# [1360]	train's auc: 0.999243	valid's auc: 0.94604
# [1380]	train's auc: 0.999292	valid's auc: 0.945928
# [1400]	train's auc: 0.999344	valid's auc: 0.945863
# [1420]	train's auc: 0.999386	valid's auc: 0.94564
# [1440]	train's auc: 0.999422	valid's auc: 0.945589
# [1460]	train's auc: 0.999464	valid's auc: 0.945541
# [1480]	train's auc: 0.999494	valid's auc: 0.945515
# [1500]	train's auc: 0.999538	valid's auc: 0.945588
# [1520]	train's auc: 0.999571	valid's auc: 0.945518
# [1540]	train's auc: 0.999596	valid's auc: 0.945594
# [1560]	train's auc: 0.999618	valid's auc: 0.945524
# [1580]	train's auc: 0.999645	valid's auc: 0.94556
# [1600]	train's auc: 0.999672	valid's auc: 0.945601
# [1620]	train's auc: 0.999692	valid's auc: 0.945477
# [1640]	train's auc: 0.999718	valid's auc: 0.945388
# [1660]	train's auc: 0.99974	valid's auc: 0.945426
# Early stopping, best iteration is:
# [670]	train's auc: 0.992842	valid's auc: 0.947671
# train fold=4 12.120[s]
# Fold 3 AUC: 0.9477
# [LightGBM] [Info] Number of positive: 3045, number of negative: 3643
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008799 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9211
# [LightGBM] [Info] Number of data points in the train set: 6688, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.455293 -> initscore=-0.179307
# [LightGBM] [Info] Start training from score -0.179307
# Training until validation scores don't improve for 1000 rounds
# [20]	train's auc: 0.951467	valid's auc: 0.928457
# [40]	train's auc: 0.955429	valid's auc: 0.93588
# [60]	train's auc: 0.958394	valid's auc: 0.935586
# [80]	train's auc: 0.960165	valid's auc: 0.936414
# [100]	train's auc: 0.962632	valid's auc: 0.93714
# [120]	train's auc: 0.965036	valid's auc: 0.938167
# [140]	train's auc: 0.967044	valid's auc: 0.939361
# [160]	train's auc: 0.968578	valid's auc: 0.94039
# [180]	train's auc: 0.969997	valid's auc: 0.940422
# [200]	train's auc: 0.971384	valid's auc: 0.941371
# [220]	train's auc: 0.972798	valid's auc: 0.942101
# [240]	train's auc: 0.974248	valid's auc: 0.942885
# [260]	train's auc: 0.975701	valid's auc: 0.943717
# [280]	train's auc: 0.977006	valid's auc: 0.944813
# [300]	train's auc: 0.978344	valid's auc: 0.945779
# [320]	train's auc: 0.97961	valid's auc: 0.94666
# [340]	train's auc: 0.980842	valid's auc: 0.94707
# [360]	train's auc: 0.982005	valid's auc: 0.947223
# [380]	train's auc: 0.98308	valid's auc: 0.947317
# [400]	train's auc: 0.984124	valid's auc: 0.947195
# [420]	train's auc: 0.985088	valid's auc: 0.947057
# [440]	train's auc: 0.986016	valid's auc: 0.946736
# [460]	train's auc: 0.98689	valid's auc: 0.946489
# [480]	train's auc: 0.987628	valid's auc: 0.946075
# [500]	train's auc: 0.988364	valid's auc: 0.945503
# [520]	train's auc: 0.989078	valid's auc: 0.945142
# [540]	train's auc: 0.98977	valid's auc: 0.944915
# [560]	train's auc: 0.990375	valid's auc: 0.944369
# [580]	train's auc: 0.99099	valid's auc: 0.944317
# [600]	train's auc: 0.991537	valid's auc: 0.944291
# [620]	train's auc: 0.992028	valid's auc: 0.9439
# [640]	train's auc: 0.992483	valid's auc: 0.943607
# [660]	train's auc: 0.992928	valid's auc: 0.943205
# [680]	train's auc: 0.993328	valid's auc: 0.943022
# [700]	train's auc: 0.993737	valid's auc: 0.942678
# [720]	train's auc: 0.994132	valid's auc: 0.942325
# [740]	train's auc: 0.99446	valid's auc: 0.942004
# [760]	train's auc: 0.994804	valid's auc: 0.941618
# [780]	train's auc: 0.995144	valid's auc: 0.941713
# [800]	train's auc: 0.995466	valid's auc: 0.941388
# [820]	train's auc: 0.995767	valid's auc: 0.940947
# [840]	train's auc: 0.995997	valid's auc: 0.940418
# [860]	train's auc: 0.996257	valid's auc: 0.940398
# [880]	train's auc: 0.996487	valid's auc: 0.940044
# [900]	train's auc: 0.996712	valid's auc: 0.939605
# [920]	train's auc: 0.996925	valid's auc: 0.93932
# [940]	train's auc: 0.997109	valid's auc: 0.938966
# [960]	train's auc: 0.997268	valid's auc: 0.938812
# [980]	train's auc: 0.997443	valid's auc: 0.938766
# [1000]	train's auc: 0.997609	valid's auc: 0.938583
# [1020]	train's auc: 0.997744	valid's auc: 0.938504
# [1040]	train's auc: 0.997875	valid's auc: 0.938051
# [1060]	train's auc: 0.998007	valid's auc: 0.937638
# [1080]	train's auc: 0.998133	valid's auc: 0.937339
# [1100]	train's auc: 0.998232	valid's auc: 0.937226
# [1120]	train's auc: 0.998341	valid's auc: 0.937031
# [1140]	train's auc: 0.998456	valid's auc: 0.936897
# [1160]	train's auc: 0.998552	valid's auc: 0.936953
# [1180]	train's auc: 0.998638	valid's auc: 0.93686
# [1200]	train's auc: 0.998723	valid's auc: 0.937016
# [1220]	train's auc: 0.998798	valid's auc: 0.936702
# [1240]	train's auc: 0.998879	valid's auc: 0.937009
# [1260]	train's auc: 0.998958	valid's auc: 0.937012
# [1280]	train's auc: 0.999032	valid's auc: 0.936938
# [1300]	train's auc: 0.999086	valid's auc: 0.936909
# [1320]	train's auc: 0.999156	valid's auc: 0.936851
# [1340]	train's auc: 0.999217	valid's auc: 0.936841
# [1360]	train's auc: 0.999267	valid's auc: 0.936821
# [1380]	train's auc: 0.999327	valid's auc: 0.93678
# Early stopping, best iteration is:
# [389]	train's auc: 0.983573	valid's auc: 0.947384
# train fold=5 9.657[s]
# Fold 4 AUC: 0.9474
# FINISHED; whole score: 0.8861
# (660, 4)
#                                                             0           1  \
# Year_of_Release                                          2003        1998
# le_Platform                                                29          15
# le_Genre                                                    0           0
# le_Rating                                                   5           8
# Critic_Score                                             0.84        0.91
# User_Score                                                0.8         0.9
# Critic_Count                                               23          17
# User_Count                                                 19         132
# is_tbd                                                  False       False
# multi_pf_count                                              3           1
# other_platform_1                                            0           0
# other_platform_2                                            0           0
# other_platform_3                                            0           0
# other_platform_4                                            0           0
# other_platform_5                                            0           0
# other_platform_6                                            0           0
# other_platform_7                                            0           0
# other_platform_8                                            1           0
# other_platform_9                                            0           0
# other_platform_10                                           0           0
# other_platform_11                                           0           0
# other_platform_12                                           0           0
# other_platform_13                                           0           0
# other_platform_14                                           0           0
# other_platform_15                                           0           0
# other_platform_16                                           0           0
# other_platform_17                                           1           0
# other_platform_18                                           0           0
# other_platform_19                                           0           0
# other_platform_20                                           0           0
# other_platform_21                                           0           0
# other_platform_22                                           0           0
# other_platform_23                                           0           0
# other_platform_24                                           0           0
# other_platform_25                                           0           0
# other_platform_26                                           0           0
# other_platform_27                                           0           0
# other_platform_28                                           0           0
# other_platform_29                                           0           0
# other_platform_30                                           0           0
# other_platform_31                                           0           0
# count_id_groupby_Platform                                 824        1197
# count_id_groupby_Genre                                   3370        3370
# count_id_groupby_Developer                                 20          25
# count_id_groupby_Rating                                  1563        2961
# count_id_groupby_Year_of_Release                          NaN         NaN
# count_Publisher_groupby_Developer                          20          25
# count_Genre_groupby_Developer                              20          25
# count_Platform_groupby_Developer                           20          25
# count_Year_of_Release_groupby_Developer                    19          24
# nunique_Developer_groupby_Publisher                        57          57
# nunique_Genre_groupby_Publisher                            12          12
# nunique_Platform_groupby_Publisher                         13          13
# nunique_Year_of_Release_groupby_Publisher                  14          14
# pca_0_count_id_pivotby_Developer_for_all             -11.2272     -14.933
# pca_1_count_id_pivotby_Developer_for_all              7.19395     10.6341
# pca_0_count_id_pivotby_Publisher_for_all             -25.8662    -25.8662
# pca_1_count_id_pivotby_Publisher_for_all              1.46487     1.46487
# pca_2_count_id_pivotby_Publisher_for_all             -18.9448    -18.9448
# pca_3_count_id_pivotby_Publisher_for_all              94.1167     94.1167
# pca_0_count_id_pivotby_Platform_for_all              -29.7794    -80.1888
# pca_1_count_id_pivotby_Platform_for_all              -108.204     97.2866
# pca_2_count_id_pivotby_Platform_for_all              -121.128    -146.626
# pca_3_count_id_pivotby_Platform_for_all               111.333     209.071
# pca_0_count_id_pivotby_Genre_for_all                  -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                  1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                  396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                  272.192     272.192
# count_over_500_Publisher                                False       False
# count_over_100_Publisher                                 True        True
# pca_0_name_bow_gt_count_5_3                        -0.0152347  -0.0153025
# pca_1_name_bow_gt_count_5_3                        -0.0164353  0.00957819
# pca_2_name_bow_gt_count_5_3                         -0.012102 -0.00259813
# pca_3_name_bow_gt_count_5_3                         -0.018614  -0.0132832
# num_word_series_1                                           1           1
# num_word_series_2                                           1           1
# num_word_series_3                                           1           1
# mean_User_Score_groupby_Platform                     0.750051    0.786543
# max_User_Score_groupby_Platform                          0.93        0.94
# min_User_Score_groupby_Platform                          0.05        0.12
# mean_User_Count_groupby_Platform                      24.2594     73.8519
# max_User_Count_groupby_Platform                          1283        1282
# min_User_Count_groupby_Platform                             4           4
# mean_Critic_Score_groupby_Platform                   0.698593     0.71515
# max_Critic_Score_groupby_Platform                        0.97        0.98
# min_Critic_Score_groupby_Platform                        0.19        0.26
# mean_Critic_Count_groupby_Platform                     26.371      10.415
# max_Critic_Count_groupby_Platform                          91          24
# min_Critic_Count_groupby_Platform                           4           4
# diff_User_Score_mean_User_Score_groupby_Platform    0.0499488    0.113457
# diff_User_Score_max_User_Score_groupby_Platform         -0.13       -0.04
# diff_User_Score_min_User_Score_groupby_Platform          0.75        0.78
# diff_User_Count_mean_User_Count_groupby_Platform     -5.25939     58.1481
# diff_User_Count_max_User_Count_groupby_Platform         -1264       -1150
# diff_User_Count_min_User_Count_groupby_Platform            15         128
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...   0.141407     0.19485
# diff_Critic_Score_max_Critic_Score_groupby_Plat...      -0.13       -0.07
# diff_Critic_Score_min_Critic_Score_groupby_Plat...       0.65        0.65
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...   -3.37103       6.585
# diff_Critic_Count_max_Critic_Count_groupby_Plat...        -68          -7
# diff_Critic_Count_min_Critic_Count_groupby_Plat...         19          13
# mean_User_Score_groupby_Year_of_Release                   NaN         NaN
# max_User_Score_groupby_Year_of_Release                    NaN         NaN
# min_User_Score_groupby_Year_of_Release                    NaN         NaN
# mean_User_Count_groupby_Year_of_Release                   NaN         NaN
# max_User_Count_groupby_Year_of_Release                    NaN         NaN
# min_User_Count_groupby_Year_of_Release                    NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                 NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                 NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...        NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...        NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...        NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...        NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...        NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...        NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...        NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...        NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...        NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...        NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...        NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...        NaN         NaN
# mean_target_groupby_Platform                        0.0700809    0.451172
# mean_target_groupby_Year_of_Release                       NaN         NaN
# mean_target_groupby_Genre                            0.378657    0.378657
# mean_target_groupby_Rating                           0.398964    0.353989
# year_rank_rate                                            0.5         0.5
# year_rank_plus                                            NaN         NaN
# diff_platform_min                                         NaN         NaN
#
#                                                              2           3  \
# Year_of_Release                                           2003        2011
# le_Platform                                                 29          28
# le_Genre                                                     0           0
# le_Rating                                                    5           5
# Critic_Score                                              0.87         0.7
# User_Score                                                0.85        0.69
# Critic_Count                                                28          54
# User_Count                                                  39         180
# is_tbd                                                   False       False
# multi_pf_count                                               2           2
# other_platform_1                                             0           0
# other_platform_2                                             0           0
# other_platform_3                                             0           0
# other_platform_4                                             0           0
# other_platform_5                                             0           0
# other_platform_6                                             0           0
# other_platform_7                                             0           0
# other_platform_8                                             0           0
# other_platform_9                                             0           0
# other_platform_10                                            0           0
# other_platform_11                                            0           0
# other_platform_12                                            0           0
# other_platform_13                                            0           0
# other_platform_14                                            0           0
# other_platform_15                                            0           0
# other_platform_16                                            0           0
# other_platform_17                                            1           0
# other_platform_18                                            0           1
# other_platform_19                                            0           0
# other_platform_20                                            0           0
# other_platform_21                                            0           0
# other_platform_22                                            0           0
# other_platform_23                                            0           0
# other_platform_24                                            0           0
# other_platform_25                                            0           0
# other_platform_26                                            0           0
# other_platform_27                                            0           0
# other_platform_28                                            0           0
# other_platform_29                                            0           0
# other_platform_30                                            0           0
# other_platform_31                                            0           0
# count_id_groupby_Platform                                  824        1262
# count_id_groupby_Genre                                    3370        3370
# count_id_groupby_Developer                                  12          22
# count_id_groupby_Rating                                   1563        1563
# count_id_groupby_Year_of_Release                           NaN         NaN
# count_Publisher_groupby_Developer                           12          22
# count_Genre_groupby_Developer                               12          22
# count_Platform_groupby_Developer                            12          22
# count_Year_of_Release_groupby_Developer                     11          20
# nunique_Developer_groupby_Publisher                         77          77
# nunique_Genre_groupby_Publisher                             12          12
# nunique_Platform_groupby_Publisher                          23          23
# nunique_Year_of_Release_groupby_Publisher                   30          30
# pca_0_count_id_pivotby_Developer_for_all              -3.87077    -12.9165
# pca_1_count_id_pivotby_Developer_for_all               2.35298     8.60969
# pca_0_count_id_pivotby_Publisher_for_all               65.3951     65.3951
# pca_1_count_id_pivotby_Publisher_for_all               44.4596     44.4596
# pca_2_count_id_pivotby_Publisher_for_all               89.2015     89.2015
# pca_3_count_id_pivotby_Publisher_for_all               437.574     437.574
# pca_0_count_id_pivotby_Platform_for_all               -29.7794     71.7324
# pca_1_count_id_pivotby_Platform_for_all               -108.204    -163.858
# pca_2_count_id_pivotby_Platform_for_all               -121.128     -106.81
# pca_3_count_id_pivotby_Platform_for_all                111.333     318.064
# pca_0_count_id_pivotby_Genre_for_all                   -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192     272.192
# count_over_500_Publisher                                  True        True
# count_over_100_Publisher                                  True        True
# pca_0_name_bow_gt_count_5_3                         -0.0193897  -0.0138348
# pca_1_name_bow_gt_count_5_3                         0.00287371  -0.0103677
# pca_2_name_bow_gt_count_5_3                         -0.0212004 -0.00993917
# pca_3_name_bow_gt_count_5_3                         -0.0539662  -0.0161403
# num_word_series_1                                           43           1
# num_word_series_2                                           20           1
# num_word_series_3                                           18           1
# mean_User_Score_groupby_Platform                      0.750051    0.668354
# max_User_Score_groupby_Platform                           0.93         0.9
# min_User_Score_groupby_Platform                           0.05        0.07
# mean_User_Count_groupby_Platform                       24.2594     187.156
# max_User_Count_groupby_Platform                           1283        8713
# min_User_Count_groupby_Platform                              4           4
# mean_Critic_Score_groupby_Platform                    0.698593    0.686168
# max_Critic_Score_groupby_Platform                         0.97        0.98
# min_Critic_Score_groupby_Platform                         0.19        0.19
# mean_Critic_Count_groupby_Platform                      26.371     42.1212
# max_Critic_Count_groupby_Platform                           91         100
# min_Critic_Count_groupby_Platform                            4           3
# diff_User_Score_mean_User_Score_groupby_Platform     0.0999488    0.021646
# diff_User_Score_max_User_Score_groupby_Platform          -0.08       -0.21
# diff_User_Score_min_User_Score_groupby_Platform            0.8        0.62
# diff_User_Count_mean_User_Count_groupby_Platform       14.7406    -7.15631
# diff_User_Count_max_User_Count_groupby_Platform          -1244       -8533
# diff_User_Count_min_User_Count_groupby_Platform             35         176
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...    0.171407   0.0138319
# diff_Critic_Score_max_Critic_Score_groupby_Plat...        -0.1       -0.28
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.68        0.51
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...     1.62897     11.8788
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -63         -46
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          24          51
# mean_User_Score_groupby_Year_of_Release                    NaN         NaN
# max_User_Score_groupby_Year_of_Release                     NaN         NaN
# min_User_Score_groupby_Year_of_Release                     NaN         NaN
# mean_User_Count_groupby_Year_of_Release                    NaN         NaN
# max_User_Count_groupby_Year_of_Release                     NaN         NaN
# min_User_Count_groupby_Year_of_Release                     NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN         NaN
# mean_target_groupby_Platform                         0.0700809    0.331633
# mean_target_groupby_Year_of_Release                        NaN         NaN
# mean_target_groupby_Genre                             0.378657    0.378657
# mean_target_groupby_Rating                            0.398964    0.398964
# year_rank_rate                                             0.5         0.5
# year_rank_plus                                             NaN         NaN
# diff_platform_min                                          NaN         NaN
#
#                                                              4
# Year_of_Release                                           2011
# le_Platform                                                 17
# le_Genre                                                     0
# le_Rating                                                    5
# Critic_Score                                              0.71
# User_Score                                                0.69
# Critic_Count                                                41
# User_Count                                                 143
# is_tbd                                                   False
# multi_pf_count                                               2
# other_platform_1                                             0
# other_platform_2                                             0
# other_platform_3                                             0
# other_platform_4                                             0
# other_platform_5                                             0
# other_platform_6                                             0
# other_platform_7                                             0
# other_platform_8                                             0
# other_platform_9                                             0
# other_platform_10                                            0
# other_platform_11                                            0
# other_platform_12                                            0
# other_platform_13                                            0
# other_platform_14                                            0
# other_platform_15                                            0
# other_platform_16                                            0
# other_platform_17                                            0
# other_platform_18                                            0
# other_platform_19                                            0
# other_platform_20                                            0
# other_platform_21                                            0
# other_platform_22                                            0
# other_platform_23                                            0
# other_platform_24                                            0
# other_platform_25                                            0
# other_platform_26                                            0
# other_platform_27                                            0
# other_platform_28                                            0
# other_platform_29                                            1
# other_platform_30                                            0
# other_platform_31                                            0
# count_id_groupby_Platform                                 1331
# count_id_groupby_Genre                                    3370
# count_id_groupby_Developer                                  22
# count_id_groupby_Rating                                   1563
# count_id_groupby_Year_of_Release                           NaN
# count_Publisher_groupby_Developer                           22
# count_Genre_groupby_Developer                               22
# count_Platform_groupby_Developer                            22
# count_Year_of_Release_groupby_Developer                     20
# nunique_Developer_groupby_Publisher                         77
# nunique_Genre_groupby_Publisher                             12
# nunique_Platform_groupby_Publisher                          23
# nunique_Year_of_Release_groupby_Publisher                   30
# pca_0_count_id_pivotby_Developer_for_all              -12.9165
# pca_1_count_id_pivotby_Developer_for_all               8.60969
# pca_0_count_id_pivotby_Publisher_for_all               65.3951
# pca_1_count_id_pivotby_Publisher_for_all               44.4596
# pca_2_count_id_pivotby_Publisher_for_all               89.2015
# pca_3_count_id_pivotby_Publisher_for_all               437.574
# pca_0_count_id_pivotby_Platform_for_all                96.8409
# pca_1_count_id_pivotby_Platform_for_all               -6.99518
# pca_2_count_id_pivotby_Platform_for_all               -118.399
# pca_3_count_id_pivotby_Platform_for_all                363.628
# pca_0_count_id_pivotby_Genre_for_all                   -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192
# count_over_500_Publisher                                  True
# count_over_100_Publisher                                  True
# pca_0_name_bow_gt_count_5_3                         -0.0138348
# pca_1_name_bow_gt_count_5_3                         -0.0103677
# pca_2_name_bow_gt_count_5_3                        -0.00993917
# pca_3_name_bow_gt_count_5_3                         -0.0161403
# num_word_series_1                                            1
# num_word_series_2                                            1
# num_word_series_3                                            1
# mean_User_Score_groupby_Platform                      0.672657
# max_User_Score_groupby_Platform                           0.91
# min_User_Score_groupby_Platform                           0.02
# mean_User_Count_groupby_Platform                       205.892
# max_User_Count_groupby_Platform                           8003
# min_User_Count_groupby_Platform                              4
# mean_Critic_Score_groupby_Platform                    0.703829
# max_Critic_Score_groupby_Platform                         0.98
# min_Critic_Score_groupby_Platform                         0.13
# mean_Critic_Count_groupby_Platform                     33.9012
# max_Critic_Count_groupby_Platform                          107
# min_Critic_Count_groupby_Platform                            4
# diff_User_Score_mean_User_Score_groupby_Platform     0.0173432
# diff_User_Score_max_User_Score_groupby_Platform          -0.22
# diff_User_Score_min_User_Score_groupby_Platform           0.67
# diff_User_Count_mean_User_Count_groupby_Platform      -62.8917
# diff_User_Count_max_User_Count_groupby_Platform          -7860
# diff_User_Count_min_User_Count_groupby_Platform            139
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...  0.00617073
# diff_Critic_Score_max_Critic_Score_groupby_Plat...       -0.27
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.58
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...     7.09878
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -66
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          37
# mean_User_Score_groupby_Year_of_Release                    NaN
# max_User_Score_groupby_Year_of_Release                     NaN
# min_User_Score_groupby_Year_of_Release                     NaN
# mean_User_Count_groupby_Year_of_Release                    NaN
# max_User_Count_groupby_Year_of_Release                     NaN
# min_User_Count_groupby_Year_of_Release                     NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN
# mean_target_groupby_Platform                          0.550544
# mean_target_groupby_Year_of_Release                        NaN
# mean_target_groupby_Genre                             0.378657
# mean_target_groupby_Rating                            0.398964
# year_rank_rate                                             0.5
# year_rank_plus                                             NaN
# diff_platform_min                                          NaN

# %%
visualize_oof(np.expm1(df_train.loc[:, 'target'].values), np.expm1(oof))
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train_preds = predict(models, df_f_train, df_train, df_train)
sub_df = pd.DataFrame({ target_column: train_preds })
sub_df.to_csv(ckptdir / f'train_{settings["name"]}.csv', index=False)
sub_df = pd.DataFrame({ target_column: oof })
sub_df.to_csv(ckptdir / f'oof_{settings["name"]}.csv', index=False)
# Out:
#                                                              0           1  \
# Year_of_Release                                           2009        2009
# le_Platform                                                 26          26
# le_Genre                                                     0           0
# le_Rating                                                    2           2
# Critic_Score                                              0.74        0.78
# User_Score                                                0.79        0.66
# Critic_Count                                                17          22
# User_Count                                                  22          28
# is_tbd                                                   False       False
# multi_pf_count                                               7           7
# other_platform_1                                             0           0
# other_platform_2                                             0           0
# other_platform_3                                             0           0
# other_platform_4                                             0           0
# other_platform_5                                             1           1
# other_platform_6                                             0           0
# other_platform_7                                             0           0
# other_platform_8                                             0           0
# other_platform_9                                             0           0
# other_platform_10                                            0           0
# other_platform_11                                            0           0
# other_platform_12                                            0           0
# other_platform_13                                            0           0
# other_platform_14                                            1           1
# other_platform_15                                            0           0
# other_platform_16                                            0           0
# other_platform_17                                            1           1
# other_platform_18                                            1           1
# other_platform_19                                            0           0
# other_platform_20                                            1           1
# other_platform_21                                            0           0
# other_platform_22                                            0           0
# other_platform_23                                            0           0
# other_platform_24                                            0           0
# other_platform_25                                            0           0
# other_platform_26                                            0           0
# other_platform_27                                            0           0
# other_platform_28                                            0           0
# other_platform_29                                            1           1
# other_platform_30                                            0           0
# other_platform_31                                            0           0
# count_id_groupby_Platform                                 1320        1320
# count_id_groupby_Genre                                    3370        3370
# count_id_groupby_Developer                                  77          77
# count_id_groupby_Rating                                   1420        1420
# count_id_groupby_Year_of_Release                           NaN         NaN
# count_Publisher_groupby_Developer                           77          77
# count_Genre_groupby_Developer                               77          77
# count_Platform_groupby_Developer                            77          77
# count_Year_of_Release_groupby_Developer                     65          65
# nunique_Developer_groupby_Publisher                         43          24
# nunique_Genre_groupby_Publisher                              9           7
# nunique_Platform_groupby_Publisher                          13          13
# nunique_Year_of_Release_groupby_Publisher                   13          16
# pca_0_count_id_pivotby_Developer_for_all              -53.3165    -53.3165
# pca_1_count_id_pivotby_Developer_for_all               34.0593     34.0593
# pca_0_count_id_pivotby_Publisher_for_all              -93.7891    -23.6107
# pca_1_count_id_pivotby_Publisher_for_all              -8.43031    -4.03868
# pca_2_count_id_pivotby_Publisher_for_all              -93.2896    -15.6729
# pca_3_count_id_pivotby_Publisher_for_all               118.894     38.1077
# pca_0_count_id_pivotby_Platform_for_all               -111.249    -111.249
# pca_1_count_id_pivotby_Platform_for_all               -104.843    -104.843
# pca_2_count_id_pivotby_Platform_for_all                86.7072     86.7072
# pca_3_count_id_pivotby_Platform_for_all                315.714     315.714
# pca_0_count_id_pivotby_Genre_for_all                   -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192     272.192
# count_over_500_Publisher                                 False       False
# count_over_100_Publisher                                  True       False
# pca_0_name_bow_gt_count_5_3                         -0.0145961  -0.0173708
# pca_1_name_bow_gt_count_5_3                         -0.0134632  -0.0177323
# pca_2_name_bow_gt_count_5_3                        -0.00905627  0.00231316
# pca_3_name_bow_gt_count_5_3                         -0.0172936  -0.0192902
# num_word_series_1                                            1           1
# num_word_series_2                                      3.14286           1
# num_word_series_3                                            1     1.85714
# mean_User_Score_groupby_Platform                      0.674268    0.674268
# max_User_Score_groupby_Platform                           0.93        0.93
# min_User_Score_groupby_Platform                           0.02        0.02
# mean_User_Count_groupby_Platform                       53.1232     53.1232
# max_User_Count_groupby_Platform                           2147        2147
# min_User_Count_groupby_Platform                              4           4
# mean_Critic_Score_groupby_Platform                    0.628239    0.628239
# max_Critic_Score_groupby_Platform                         0.97        0.97
# min_Critic_Score_groupby_Platform                         0.19        0.19
# mean_Critic_Count_groupby_Platform                     21.2479     21.2479
# max_Critic_Count_groupby_Platform                           87          87
# min_Critic_Count_groupby_Platform                            4           4
# diff_User_Score_mean_User_Score_groupby_Platform      0.115732  -0.0142679
# diff_User_Score_max_User_Score_groupby_Platform          -0.14       -0.27
# diff_User_Score_min_User_Score_groupby_Platform           0.77        0.64
# diff_User_Count_mean_User_Count_groupby_Platform      -31.1232    -25.1232
# diff_User_Count_max_User_Count_groupby_Platform          -2125       -2119
# diff_User_Count_min_User_Count_groupby_Platform             18          24
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...    0.111761    0.151761
# diff_Critic_Score_max_Critic_Score_groupby_Plat...       -0.23       -0.19
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.55        0.59
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...    -4.24786    0.752137
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -70         -65
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          13          18
# mean_User_Score_groupby_Year_of_Release                    NaN         NaN
# max_User_Score_groupby_Year_of_Release                     NaN         NaN
# min_User_Score_groupby_Year_of_Release                     NaN         NaN
# mean_User_Count_groupby_Year_of_Release                    NaN         NaN
# max_User_Count_groupby_Year_of_Release                     NaN         NaN
# min_User_Count_groupby_Year_of_Release                     NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN         NaN
# mean_target_groupby_Platform                          0.243411    0.243411
# mean_target_groupby_Year_of_Release                        NaN         NaN
# mean_target_groupby_Genre                             0.378657    0.378657
# mean_target_groupby_Rating                             0.21067     0.21067
# year_rank_rate                                             0.5         0.5
# year_rank_plus                                             NaN         NaN
# diff_platform_min                                          NaN         NaN
#
#                                                              2           3  \
# Year_of_Release                                           2006        1981
# le_Platform                                                 19           0
# le_Genre                                                     0           0
# le_Rating                                                    2           6
# Critic_Score                                              0.73         NaN
# User_Score                                                0.74         NaN
# Critic_Count                                                 5         NaN
# User_Count                                                  10         NaN
# is_tbd                                                   False       False
# multi_pf_count                                               7           1
# other_platform_1                                             0           0
# other_platform_2                                             0           0
# other_platform_3                                             0           0
# other_platform_4                                             0           0
# other_platform_5                                             1           0
# other_platform_6                                             0           0
# other_platform_7                                             0           0
# other_platform_8                                             0           0
# other_platform_9                                             0           0
# other_platform_10                                            0           0
# other_platform_11                                            0           0
# other_platform_12                                            0           0
# other_platform_13                                            0           0
# other_platform_14                                            1           0
# other_platform_15                                            0           0
# other_platform_16                                            0           0
# other_platform_17                                            1           0
# other_platform_18                                            1           0
# other_platform_19                                            0           0
# other_platform_20                                            0           0
# other_platform_21                                            0           0
# other_platform_22                                            0           0
# other_platform_23                                            0           0
# other_platform_24                                            0           0
# other_platform_25                                            0           0
# other_platform_26                                            0           0
# other_platform_27                                            1           0
# other_platform_28                                            0           0
# other_platform_29                                            1           0
# other_platform_30                                            0           0
# other_platform_31                                            0           0
# count_id_groupby_Platform                                 1209         133
# count_id_groupby_Genre                                    3370        3370
# count_id_groupby_Developer                                  77         NaN
# count_id_groupby_Rating                                   1420         NaN
# count_id_groupby_Year_of_Release                           NaN         NaN
# count_Publisher_groupby_Developer                           77         NaN
# count_Genre_groupby_Developer                               77         NaN
# count_Platform_groupby_Developer                            77         NaN
# count_Year_of_Release_groupby_Developer                     65         NaN
# nunique_Developer_groupby_Publisher                         43         127
# nunique_Genre_groupby_Publisher                              9          12
# nunique_Platform_groupby_Publisher                          13          15
# nunique_Year_of_Release_groupby_Publisher                   13          23
# pca_0_count_id_pivotby_Developer_for_all              -53.3165         NaN
# pca_1_count_id_pivotby_Developer_for_all               34.0593         NaN
# pca_0_count_id_pivotby_Publisher_for_all              -93.7891     30.9391
# pca_1_count_id_pivotby_Publisher_for_all              -8.43031    -13.7852
# pca_2_count_id_pivotby_Publisher_for_all              -93.2896     4.53849
# pca_3_count_id_pivotby_Publisher_for_all               118.894      154.97
# pca_0_count_id_pivotby_Platform_for_all                74.2622     10.2364
# pca_1_count_id_pivotby_Platform_for_all                 191.25    -17.3691
# pca_2_count_id_pivotby_Platform_for_all                6.18492    -2.75132
# pca_3_count_id_pivotby_Platform_for_all                236.698     -146.18
# pca_0_count_id_pivotby_Genre_for_all                   -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192     272.192
# count_over_500_Publisher                                 False       False
# count_over_100_Publisher                                  True        True
# pca_0_name_bow_gt_count_5_3                         -0.0145961  -0.0140941
# pca_1_name_bow_gt_count_5_3                         -0.0134632  -0.0106854
# pca_2_name_bow_gt_count_5_3                        -0.00905627 -0.00930718
# pca_3_name_bow_gt_count_5_3                         -0.0172936  -0.0152041
# num_word_series_1                                            1           1
# num_word_series_2                                      3.14286           1
# num_word_series_3                                            1           1
# mean_User_Score_groupby_Platform                      0.722827         NaN
# max_User_Score_groupby_Platform                           0.97         NaN
# min_User_Score_groupby_Platform                           0.06         NaN
# mean_User_Count_groupby_Platform                       30.4228         NaN
# max_User_Count_groupby_Platform                            565         NaN
# min_User_Count_groupby_Platform                              4         NaN
# mean_Critic_Score_groupby_Platform                    0.674242         NaN
# max_Critic_Score_groupby_Platform                         0.91         NaN
# min_Critic_Score_groupby_Platform                         0.28         NaN
# mean_Critic_Count_groupby_Platform                     23.3983         NaN
# max_Critic_Count_groupby_Platform                           79         NaN
# min_Critic_Count_groupby_Platform                            4         NaN
# diff_User_Score_mean_User_Score_groupby_Platform     0.0171734         NaN
# diff_User_Score_max_User_Score_groupby_Platform          -0.23         NaN
# diff_User_Score_min_User_Score_groupby_Platform           0.68         NaN
# diff_User_Count_mean_User_Count_groupby_Platform      -20.4228         NaN
# diff_User_Count_max_User_Count_groupby_Platform           -555         NaN
# diff_User_Count_min_User_Count_groupby_Platform              6         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...   0.0557576         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Plat...       -0.18         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.45         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...    -18.3983         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -74         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Plat...           1         NaN
# mean_User_Score_groupby_Year_of_Release                    NaN         NaN
# max_User_Score_groupby_Year_of_Release                     NaN         NaN
# min_User_Score_groupby_Year_of_Release                     NaN         NaN
# mean_User_Count_groupby_Year_of_Release                    NaN         NaN
# max_User_Count_groupby_Year_of_Release                     NaN         NaN
# min_User_Count_groupby_Year_of_Release                     NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN         NaN
# mean_target_groupby_Platform                          0.627726           0
# mean_target_groupby_Year_of_Release                        NaN         NaN
# mean_target_groupby_Genre                             0.378657    0.378657
# mean_target_groupby_Rating                             0.21067         NaN
# year_rank_rate                                             0.5         0.5
# year_rank_plus                                             NaN         NaN
# diff_platform_min                                          NaN         NaN
#
#                                                             4
# Year_of_Release                                          2009
# le_Platform                                                26
# le_Genre                                                    0
# le_Rating                                                   2
# Critic_Score                                             0.76
# User_Score                                               0.78
# Critic_Count                                                8
# User_Count                                                 13
# is_tbd                                                  False
# multi_pf_count                                              8
# other_platform_1                                            0
# other_platform_2                                            0
# other_platform_3                                            1
# other_platform_4                                            0
# other_platform_5                                            1
# other_platform_6                                            0
# other_platform_7                                            0
# other_platform_8                                            0
# other_platform_9                                            0
# other_platform_10                                           0
# other_platform_11                                           0
# other_platform_12                                           0
# other_platform_13                                           0
# other_platform_14                                           1
# other_platform_15                                           0
# other_platform_16                                           0
# other_platform_17                                           0
# other_platform_18                                           1
# other_platform_19                                           0
# other_platform_20                                           1
# other_platform_21                                           1
# other_platform_22                                           0
# other_platform_23                                           0
# other_platform_24                                           0
# other_platform_25                                           0
# other_platform_26                                           0
# other_platform_27                                           0
# other_platform_28                                           0
# other_platform_29                                           1
# other_platform_30                                           0
# other_platform_31                                           0
# count_id_groupby_Platform                                1320
# count_id_groupby_Genre                                   3370
# count_id_groupby_Developer                                 77
# count_id_groupby_Rating                                  1420
# count_id_groupby_Year_of_Release                          NaN
# count_Publisher_groupby_Developer                          77
# count_Genre_groupby_Developer                              77
# count_Platform_groupby_Developer                           77
# count_Year_of_Release_groupby_Developer                    65
# nunique_Developer_groupby_Publisher                        43
# nunique_Genre_groupby_Publisher                             9
# nunique_Platform_groupby_Publisher                         13
# nunique_Year_of_Release_groupby_Publisher                  13
# pca_0_count_id_pivotby_Developer_for_all             -53.3165
# pca_1_count_id_pivotby_Developer_for_all              34.0593
# pca_0_count_id_pivotby_Publisher_for_all             -93.7891
# pca_1_count_id_pivotby_Publisher_for_all             -8.43031
# pca_2_count_id_pivotby_Publisher_for_all             -93.2896
# pca_3_count_id_pivotby_Publisher_for_all              118.894
# pca_0_count_id_pivotby_Platform_for_all              -111.249
# pca_1_count_id_pivotby_Platform_for_all              -104.843
# pca_2_count_id_pivotby_Platform_for_all               86.7072
# pca_3_count_id_pivotby_Platform_for_all               315.714
# pca_0_count_id_pivotby_Genre_for_all                  -32.595
# pca_1_count_id_pivotby_Genre_for_all                  1.16093
# pca_2_count_id_pivotby_Genre_for_all                  396.248
# pca_3_count_id_pivotby_Genre_for_all                  272.192
# count_over_500_Publisher                                False
# count_over_100_Publisher                                 True
# pca_0_name_bow_gt_count_5_3                        -0.0153978
# pca_1_name_bow_gt_count_5_3                        -0.0141588
# pca_2_name_bow_gt_count_5_3                        -0.0100863
# pca_3_name_bow_gt_count_5_3                         -0.019106
# num_word_series_1                                           1
# num_word_series_2                                           1
# num_word_series_3                                       1.875
# mean_User_Score_groupby_Platform                     0.674268
# max_User_Score_groupby_Platform                          0.93
# min_User_Score_groupby_Platform                          0.02
# mean_User_Count_groupby_Platform                      53.1232
# max_User_Count_groupby_Platform                          2147
# min_User_Count_groupby_Platform                             4
# mean_Critic_Score_groupby_Platform                   0.628239
# max_Critic_Score_groupby_Platform                        0.97
# min_Critic_Score_groupby_Platform                        0.19
# mean_Critic_Count_groupby_Platform                    21.2479
# max_Critic_Count_groupby_Platform                          87
# min_Critic_Count_groupby_Platform                           4
# diff_User_Score_mean_User_Score_groupby_Platform     0.105732
# diff_User_Score_max_User_Score_groupby_Platform         -0.15
# diff_User_Score_min_User_Score_groupby_Platform          0.76
# diff_User_Count_mean_User_Count_groupby_Platform     -40.1232
# diff_User_Count_max_User_Count_groupby_Platform         -2134
# diff_User_Count_min_User_Count_groupby_Platform             9
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...   0.131761
# diff_Critic_Score_max_Critic_Score_groupby_Plat...      -0.21
# diff_Critic_Score_min_Critic_Score_groupby_Plat...       0.57
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...   -13.2479
# diff_Critic_Count_max_Critic_Count_groupby_Plat...        -79
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          4
# mean_User_Score_groupby_Year_of_Release                   NaN
# max_User_Score_groupby_Year_of_Release                    NaN
# min_User_Score_groupby_Year_of_Release                    NaN
# mean_User_Count_groupby_Year_of_Release                   NaN
# max_User_Count_groupby_Year_of_Release                    NaN
# min_User_Count_groupby_Year_of_Release                    NaN
# mean_Critic_Score_groupby_Year_of_Release                 NaN
# max_Critic_Score_groupby_Year_of_Release                  NaN
# min_Critic_Score_groupby_Year_of_Release                  NaN
# mean_Critic_Count_groupby_Year_of_Release                 NaN
# max_Critic_Count_groupby_Year_of_Release                  NaN
# min_Critic_Count_groupby_Year_of_Release                  NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...        NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...        NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...        NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...        NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...        NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...        NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...        NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...        NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...        NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...        NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...        NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...        NaN
# mean_target_groupby_Platform                         0.243411
# mean_target_groupby_Year_of_Release                       NaN
# mean_target_groupby_Genre                            0.378657
# mean_target_groupby_Rating                            0.21067
# year_rank_rate                                            0.5
# year_rank_plus                                            NaN
# diff_platform_min                                         NaN

# %%
df_f_train.shape, df_f_test.shape
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ((8359, 126), (8360, 126))

# %%
preds = predict(models, df_f_test, df_train, df_test)
# Out:
#                                                             0           1  \
# Year_of_Release                                          2003        1998
# le_Platform                                                29          15
# le_Genre                                                    0           0
# le_Rating                                                   5           8
# Critic_Score                                             0.84        0.91
# User_Score                                                0.8         0.9
# Critic_Count                                               23          17
# User_Count                                                 19         132
# is_tbd                                                  False       False
# multi_pf_count                                              3           1
# other_platform_1                                            0           0
# other_platform_2                                            0           0
# other_platform_3                                            0           0
# other_platform_4                                            0           0
# other_platform_5                                            0           0
# other_platform_6                                            0           0
# other_platform_7                                            0           0
# other_platform_8                                            1           0
# other_platform_9                                            0           0
# other_platform_10                                           0           0
# other_platform_11                                           0           0
# other_platform_12                                           0           0
# other_platform_13                                           0           0
# other_platform_14                                           0           0
# other_platform_15                                           0           0
# other_platform_16                                           0           0
# other_platform_17                                           1           0
# other_platform_18                                           0           0
# other_platform_19                                           0           0
# other_platform_20                                           0           0
# other_platform_21                                           0           0
# other_platform_22                                           0           0
# other_platform_23                                           0           0
# other_platform_24                                           0           0
# other_platform_25                                           0           0
# other_platform_26                                           0           0
# other_platform_27                                           0           0
# other_platform_28                                           0           0
# other_platform_29                                           0           0
# other_platform_30                                           0           0
# other_platform_31                                           0           0
# count_id_groupby_Platform                                 824        1197
# count_id_groupby_Genre                                   3370        3370
# count_id_groupby_Developer                                 20          25
# count_id_groupby_Rating                                  1563        2961
# count_id_groupby_Year_of_Release                          NaN         NaN
# count_Publisher_groupby_Developer                          20          25
# count_Genre_groupby_Developer                              20          25
# count_Platform_groupby_Developer                           20          25
# count_Year_of_Release_groupby_Developer                    19          24
# nunique_Developer_groupby_Publisher                        57          57
# nunique_Genre_groupby_Publisher                            12          12
# nunique_Platform_groupby_Publisher                         13          13
# nunique_Year_of_Release_groupby_Publisher                  14          14
# pca_0_count_id_pivotby_Developer_for_all             -11.2272     -14.933
# pca_1_count_id_pivotby_Developer_for_all              7.19395     10.6341
# pca_0_count_id_pivotby_Publisher_for_all             -25.8662    -25.8662
# pca_1_count_id_pivotby_Publisher_for_all              1.46487     1.46487
# pca_2_count_id_pivotby_Publisher_for_all             -18.9448    -18.9448
# pca_3_count_id_pivotby_Publisher_for_all              94.1167     94.1167
# pca_0_count_id_pivotby_Platform_for_all              -29.7794    -80.1888
# pca_1_count_id_pivotby_Platform_for_all              -108.204     97.2866
# pca_2_count_id_pivotby_Platform_for_all              -121.128    -146.626
# pca_3_count_id_pivotby_Platform_for_all               111.333     209.071
# pca_0_count_id_pivotby_Genre_for_all                  -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                  1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                  396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                  272.192     272.192
# count_over_500_Publisher                                False       False
# count_over_100_Publisher                                 True        True
# pca_0_name_bow_gt_count_5_3                        -0.0152347  -0.0153025
# pca_1_name_bow_gt_count_5_3                        -0.0164353  0.00957819
# pca_2_name_bow_gt_count_5_3                         -0.012102 -0.00259813
# pca_3_name_bow_gt_count_5_3                         -0.018614  -0.0132832
# num_word_series_1                                           1           1
# num_word_series_2                                           1           1
# num_word_series_3                                           1           1
# mean_User_Score_groupby_Platform                     0.750051    0.786543
# max_User_Score_groupby_Platform                          0.93        0.94
# min_User_Score_groupby_Platform                          0.05        0.12
# mean_User_Count_groupby_Platform                      24.2594     73.8519
# max_User_Count_groupby_Platform                          1283        1282
# min_User_Count_groupby_Platform                             4           4
# mean_Critic_Score_groupby_Platform                   0.698593     0.71515
# max_Critic_Score_groupby_Platform                        0.97        0.98
# min_Critic_Score_groupby_Platform                        0.19        0.26
# mean_Critic_Count_groupby_Platform                     26.371      10.415
# max_Critic_Count_groupby_Platform                          91          24
# min_Critic_Count_groupby_Platform                           4           4
# diff_User_Score_mean_User_Score_groupby_Platform    0.0499488    0.113457
# diff_User_Score_max_User_Score_groupby_Platform         -0.13       -0.04
# diff_User_Score_min_User_Score_groupby_Platform          0.75        0.78
# diff_User_Count_mean_User_Count_groupby_Platform     -5.25939     58.1481
# diff_User_Count_max_User_Count_groupby_Platform         -1264       -1150
# diff_User_Count_min_User_Count_groupby_Platform            15         128
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...   0.141407     0.19485
# diff_Critic_Score_max_Critic_Score_groupby_Plat...      -0.13       -0.07
# diff_Critic_Score_min_Critic_Score_groupby_Plat...       0.65        0.65
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...   -3.37103       6.585
# diff_Critic_Count_max_Critic_Count_groupby_Plat...        -68          -7
# diff_Critic_Count_min_Critic_Count_groupby_Plat...         19          13
# mean_User_Score_groupby_Year_of_Release                   NaN         NaN
# max_User_Score_groupby_Year_of_Release                    NaN         NaN
# min_User_Score_groupby_Year_of_Release                    NaN         NaN
# mean_User_Count_groupby_Year_of_Release                   NaN         NaN
# max_User_Count_groupby_Year_of_Release                    NaN         NaN
# min_User_Count_groupby_Year_of_Release                    NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                 NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                 NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...        NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...        NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...        NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...        NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...        NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...        NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...        NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...        NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...        NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...        NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...        NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...        NaN         NaN
# mean_target_groupby_Platform                        0.0700809    0.451172
# mean_target_groupby_Year_of_Release                       NaN         NaN
# mean_target_groupby_Genre                            0.378657    0.378657
# mean_target_groupby_Rating                           0.398964    0.353989
# year_rank_rate                                            0.5         0.5
# year_rank_plus                                            NaN         NaN
# diff_platform_min                                         NaN         NaN
#
#                                                              2           3  \
# Year_of_Release                                           2003        2011
# le_Platform                                                 29          28
# le_Genre                                                     0           0
# le_Rating                                                    5           5
# Critic_Score                                              0.87         0.7
# User_Score                                                0.85        0.69
# Critic_Count                                                28          54
# User_Count                                                  39         180
# is_tbd                                                   False       False
# multi_pf_count                                               2           2
# other_platform_1                                             0           0
# other_platform_2                                             0           0
# other_platform_3                                             0           0
# other_platform_4                                             0           0
# other_platform_5                                             0           0
# other_platform_6                                             0           0
# other_platform_7                                             0           0
# other_platform_8                                             0           0
# other_platform_9                                             0           0
# other_platform_10                                            0           0
# other_platform_11                                            0           0
# other_platform_12                                            0           0
# other_platform_13                                            0           0
# other_platform_14                                            0           0
# other_platform_15                                            0           0
# other_platform_16                                            0           0
# other_platform_17                                            1           0
# other_platform_18                                            0           1
# other_platform_19                                            0           0
# other_platform_20                                            0           0
# other_platform_21                                            0           0
# other_platform_22                                            0           0
# other_platform_23                                            0           0
# other_platform_24                                            0           0
# other_platform_25                                            0           0
# other_platform_26                                            0           0
# other_platform_27                                            0           0
# other_platform_28                                            0           0
# other_platform_29                                            0           0
# other_platform_30                                            0           0
# other_platform_31                                            0           0
# count_id_groupby_Platform                                  824        1262
# count_id_groupby_Genre                                    3370        3370
# count_id_groupby_Developer                                  12          22
# count_id_groupby_Rating                                   1563        1563
# count_id_groupby_Year_of_Release                           NaN         NaN
# count_Publisher_groupby_Developer                           12          22
# count_Genre_groupby_Developer                               12          22
# count_Platform_groupby_Developer                            12          22
# count_Year_of_Release_groupby_Developer                     11          20
# nunique_Developer_groupby_Publisher                         77          77
# nunique_Genre_groupby_Publisher                             12          12
# nunique_Platform_groupby_Publisher                          23          23
# nunique_Year_of_Release_groupby_Publisher                   30          30
# pca_0_count_id_pivotby_Developer_for_all              -3.87077    -12.9165
# pca_1_count_id_pivotby_Developer_for_all               2.35298     8.60969
# pca_0_count_id_pivotby_Publisher_for_all               65.3951     65.3951
# pca_1_count_id_pivotby_Publisher_for_all               44.4596     44.4596
# pca_2_count_id_pivotby_Publisher_for_all               89.2015     89.2015
# pca_3_count_id_pivotby_Publisher_for_all               437.574     437.574
# pca_0_count_id_pivotby_Platform_for_all               -29.7794     71.7324
# pca_1_count_id_pivotby_Platform_for_all               -108.204    -163.858
# pca_2_count_id_pivotby_Platform_for_all               -121.128     -106.81
# pca_3_count_id_pivotby_Platform_for_all                111.333     318.064
# pca_0_count_id_pivotby_Genre_for_all                   -32.595     -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093     1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248     396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192     272.192
# count_over_500_Publisher                                  True        True
# count_over_100_Publisher                                  True        True
# pca_0_name_bow_gt_count_5_3                         -0.0193897  -0.0138348
# pca_1_name_bow_gt_count_5_3                         0.00287371  -0.0103677
# pca_2_name_bow_gt_count_5_3                         -0.0212004 -0.00993917
# pca_3_name_bow_gt_count_5_3                         -0.0539662  -0.0161403
# num_word_series_1                                           43           1
# num_word_series_2                                           20           1
# num_word_series_3                                           18           1
# mean_User_Score_groupby_Platform                      0.750051    0.668354
# max_User_Score_groupby_Platform                           0.93         0.9
# min_User_Score_groupby_Platform                           0.05        0.07
# mean_User_Count_groupby_Platform                       24.2594     187.156
# max_User_Count_groupby_Platform                           1283        8713
# min_User_Count_groupby_Platform                              4           4
# mean_Critic_Score_groupby_Platform                    0.698593    0.686168
# max_Critic_Score_groupby_Platform                         0.97        0.98
# min_Critic_Score_groupby_Platform                         0.19        0.19
# mean_Critic_Count_groupby_Platform                      26.371     42.1212
# max_Critic_Count_groupby_Platform                           91         100
# min_Critic_Count_groupby_Platform                            4           3
# diff_User_Score_mean_User_Score_groupby_Platform     0.0999488    0.021646
# diff_User_Score_max_User_Score_groupby_Platform          -0.08       -0.21
# diff_User_Score_min_User_Score_groupby_Platform            0.8        0.62
# diff_User_Count_mean_User_Count_groupby_Platform       14.7406    -7.15631
# diff_User_Count_max_User_Count_groupby_Platform          -1244       -8533
# diff_User_Count_min_User_Count_groupby_Platform             35         176
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...    0.171407   0.0138319
# diff_Critic_Score_max_Critic_Score_groupby_Plat...        -0.1       -0.28
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.68        0.51
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...     1.62897     11.8788
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -63         -46
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          24          51
# mean_User_Score_groupby_Year_of_Release                    NaN         NaN
# max_User_Score_groupby_Year_of_Release                     NaN         NaN
# min_User_Score_groupby_Year_of_Release                     NaN         NaN
# mean_User_Count_groupby_Year_of_Release                    NaN         NaN
# max_User_Count_groupby_Year_of_Release                     NaN         NaN
# min_User_Count_groupby_Year_of_Release                     NaN         NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN         NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN         NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN         NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN         NaN
# mean_target_groupby_Platform                         0.0700809    0.331633
# mean_target_groupby_Year_of_Release                        NaN         NaN
# mean_target_groupby_Genre                             0.378657    0.378657
# mean_target_groupby_Rating                            0.398964    0.398964
# year_rank_rate                                             0.5         0.5
# year_rank_plus                                             NaN         NaN
# diff_platform_min                                          NaN         NaN
#
#                                                              4
# Year_of_Release                                           2011
# le_Platform                                                 17
# le_Genre                                                     0
# le_Rating                                                    5
# Critic_Score                                              0.71
# User_Score                                                0.69
# Critic_Count                                                41
# User_Count                                                 143
# is_tbd                                                   False
# multi_pf_count                                               2
# other_platform_1                                             0
# other_platform_2                                             0
# other_platform_3                                             0
# other_platform_4                                             0
# other_platform_5                                             0
# other_platform_6                                             0
# other_platform_7                                             0
# other_platform_8                                             0
# other_platform_9                                             0
# other_platform_10                                            0
# other_platform_11                                            0
# other_platform_12                                            0
# other_platform_13                                            0
# other_platform_14                                            0
# other_platform_15                                            0
# other_platform_16                                            0
# other_platform_17                                            0
# other_platform_18                                            0
# other_platform_19                                            0
# other_platform_20                                            0
# other_platform_21                                            0
# other_platform_22                                            0
# other_platform_23                                            0
# other_platform_24                                            0
# other_platform_25                                            0
# other_platform_26                                            0
# other_platform_27                                            0
# other_platform_28                                            0
# other_platform_29                                            1
# other_platform_30                                            0
# other_platform_31                                            0
# count_id_groupby_Platform                                 1331
# count_id_groupby_Genre                                    3370
# count_id_groupby_Developer                                  22
# count_id_groupby_Rating                                   1563
# count_id_groupby_Year_of_Release                           NaN
# count_Publisher_groupby_Developer                           22
# count_Genre_groupby_Developer                               22
# count_Platform_groupby_Developer                            22
# count_Year_of_Release_groupby_Developer                     20
# nunique_Developer_groupby_Publisher                         77
# nunique_Genre_groupby_Publisher                             12
# nunique_Platform_groupby_Publisher                          23
# nunique_Year_of_Release_groupby_Publisher                   30
# pca_0_count_id_pivotby_Developer_for_all              -12.9165
# pca_1_count_id_pivotby_Developer_for_all               8.60969
# pca_0_count_id_pivotby_Publisher_for_all               65.3951
# pca_1_count_id_pivotby_Publisher_for_all               44.4596
# pca_2_count_id_pivotby_Publisher_for_all               89.2015
# pca_3_count_id_pivotby_Publisher_for_all               437.574
# pca_0_count_id_pivotby_Platform_for_all                96.8409
# pca_1_count_id_pivotby_Platform_for_all               -6.99518
# pca_2_count_id_pivotby_Platform_for_all               -118.399
# pca_3_count_id_pivotby_Platform_for_all                363.628
# pca_0_count_id_pivotby_Genre_for_all                   -32.595
# pca_1_count_id_pivotby_Genre_for_all                   1.16093
# pca_2_count_id_pivotby_Genre_for_all                   396.248
# pca_3_count_id_pivotby_Genre_for_all                   272.192
# count_over_500_Publisher                                  True
# count_over_100_Publisher                                  True
# pca_0_name_bow_gt_count_5_3                         -0.0138348
# pca_1_name_bow_gt_count_5_3                         -0.0103677
# pca_2_name_bow_gt_count_5_3                        -0.00993917
# pca_3_name_bow_gt_count_5_3                         -0.0161403
# num_word_series_1                                            1
# num_word_series_2                                            1
# num_word_series_3                                            1
# mean_User_Score_groupby_Platform                      0.672657
# max_User_Score_groupby_Platform                           0.91
# min_User_Score_groupby_Platform                           0.02
# mean_User_Count_groupby_Platform                       205.892
# max_User_Count_groupby_Platform                           8003
# min_User_Count_groupby_Platform                              4
# mean_Critic_Score_groupby_Platform                    0.703829
# max_Critic_Score_groupby_Platform                         0.98
# min_Critic_Score_groupby_Platform                         0.13
# mean_Critic_Count_groupby_Platform                     33.9012
# max_Critic_Count_groupby_Platform                          107
# min_Critic_Count_groupby_Platform                            4
# diff_User_Score_mean_User_Score_groupby_Platform     0.0173432
# diff_User_Score_max_User_Score_groupby_Platform          -0.22
# diff_User_Score_min_User_Score_groupby_Platform           0.67
# diff_User_Count_mean_User_Count_groupby_Platform      -62.8917
# diff_User_Count_max_User_Count_groupby_Platform          -7860
# diff_User_Count_min_User_Count_groupby_Platform            139
# diff_Critic_Score_mean_Critic_Score_groupby_Pla...  0.00617073
# diff_Critic_Score_max_Critic_Score_groupby_Plat...       -0.27
# diff_Critic_Score_min_Critic_Score_groupby_Plat...        0.58
# diff_Critic_Count_mean_Critic_Count_groupby_Pla...     7.09878
# diff_Critic_Count_max_Critic_Count_groupby_Plat...         -66
# diff_Critic_Count_min_Critic_Count_groupby_Plat...          37
# mean_User_Score_groupby_Year_of_Release                    NaN
# max_User_Score_groupby_Year_of_Release                     NaN
# min_User_Score_groupby_Year_of_Release                     NaN
# mean_User_Count_groupby_Year_of_Release                    NaN
# max_User_Count_groupby_Year_of_Release                     NaN
# min_User_Count_groupby_Year_of_Release                     NaN
# mean_Critic_Score_groupby_Year_of_Release                  NaN
# max_Critic_Score_groupby_Year_of_Release                   NaN
# min_Critic_Score_groupby_Year_of_Release                   NaN
# mean_Critic_Count_groupby_Year_of_Release                  NaN
# max_Critic_Count_groupby_Year_of_Release                   NaN
# min_Critic_Count_groupby_Year_of_Release                   NaN
# diff_User_Score_mean_User_Score_groupby_Year_of...         NaN
# diff_User_Score_max_User_Score_groupby_Year_of_...         NaN
# diff_User_Score_min_User_Score_groupby_Year_of_...         NaN
# diff_User_Count_mean_User_Count_groupby_Year_of...         NaN
# diff_User_Count_max_User_Count_groupby_Year_of_...         NaN
# diff_User_Count_min_User_Count_groupby_Year_of_...         NaN
# diff_Critic_Score_mean_Critic_Score_groupby_Yea...         NaN
# diff_Critic_Score_max_Critic_Score_groupby_Year...         NaN
# diff_Critic_Score_min_Critic_Score_groupby_Year...         NaN
# diff_Critic_Count_mean_Critic_Count_groupby_Yea...         NaN
# diff_Critic_Count_max_Critic_Count_groupby_Year...         NaN
# diff_Critic_Count_min_Critic_Count_groupby_Year...         NaN
# mean_target_groupby_Platform                          0.550544
# mean_target_groupby_Year_of_Release                        NaN
# mean_target_groupby_Genre                             0.378657
# mean_target_groupby_Rating                            0.398964
# year_rank_rate                                             0.5
# year_rank_plus                                             NaN
# diff_platform_min                                          NaN
