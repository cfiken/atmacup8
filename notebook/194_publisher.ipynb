# %%
import os
import warnings
warnings.filterwarnings('ignore')
from typing import Any, Dict, List, Tuple
from pathlib import Path
import yaml
import json
import pickle
import copy

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport # profile report を作る用
from matplotlib_venn import venn2 # venn図を作成する用
from tqdm import tqdm
from contextlib import contextmanager
from time import time

from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb

from mykaggle.metric.mse import rmse
from mykaggle.util.ml_logger import MLLogger
from mykaggle.lib.lgbm_util import compute_importances, save_importances
from mykaggle.util.routine import fix_seed

sns.set_style('darkgrid')

# %%
seed = 1019

settings = yaml.safe_load(f'''
name: '194_publisher'
competition: atmacup8
description: 'count 高頻度のみ'
seed: {seed}
training:
    pca_dim: 4
    validation: 'group'
    num_folds: 5
    num_rounds: 10000
    early_stopping_rounds: 1000
    verbose_eval: 20
    sample_weight_division: 0.01  # 10/2/1
    sample_weight_threshold: 1000
feature:
    name_bow_pca_dim: 4
    name_bow_word_th1: 5
    name_bow_word_th2: 3
    name_bow_th1_upper: 130
    name_bow_th2_upper: 100
lgbm_params:
    # seed: {seed}
    objective: multiclass
    num_class: 81
    learning_rate: 0.02
    max_depth: -1
    num_leaves: 31
    colsample_bytree: .7
    metric: multi_logloss
    verbose: -1
''')
print(json.dumps(settings, indent=4))
# Out:
# {
#     "name": "193_publisher",
#     "competition": "atmacup8",
#     "description": "count \u9ad8\u983b\u5ea6\u306e\u307f",
#     "seed": 1019,
#     "training": {
#         "pca_dim": 4,
#         "validation": "group",
#         "num_folds": 5,
#         "num_rounds": 10000,
#         "early_stopping_rounds": 1000,
#         "verbose_eval": 20,
#         "sample_weight_division": 0.01,
#         "sample_weight_threshold": 1000
#     },
#     "feature": {
#         "name_bow_pca_dim": 4,
#         "name_bow_word_th1": 5,
#         "name_bow_word_th2": 3,
#         "name_bow_th1_upper": 130,
#         "name_bow_th2_upper": 100
#     },
#     "lgbm_params": {
#         "objective": "multiclass",
#         "num_class": 81,
#         "learning_rate": 0.02,
#         "max_depth": -1,
#         "num_leaves": 31,
#         "colsample_bytree": 0.7,
#         "metric": "multi_logloss",
#         "verbose": -1
#     }
# }
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fix_seed(settings['seed'])

# %%
datadir = Path('../data/')
ckptdir = Path('../ckpt/') / settings['name']
if not ckptdir.exists():
    ckptdir.mkdir()

# %%
df_train = pd.read_csv(datadir / 'publisher_train2.csv')
df_test = pd.read_csv(datadir / 'id_test.csv')
df_submission = pd.read_csv(datadir / 'atmaCup8_sample-submission.csv')
df_train.shape, df_test.shape
# Out:
# ((7317, 22), (8360, 12))

# %%
# target や weight の用意
target_column = 'Publisher'
# train_target_columns = ['Global_Sales', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']

# for c in train_target_columns:
#     df_train.loc[:, 'mod_' + c] = df_train.loc[:, c].apply(lambda x: np.log1p(x))
df_train['target'] = df_train.loc[:, f'{target_column}']
le = LabelEncoder()
df_train['target'] = le.fit_transform(df_train['target'])
num_classes = df_train['target'].nunique()
settings['lgbm_params']['num_class'] = num_classes

# %%
df_base_train = df_train.loc[:, ['id']]
df_base_test = df_test.loc[:, ['id']]

train_others = {
    'main': df_train.copy(),
    'another': df_test.copy()
}
test_others = {
    'main': df_test.copy(),
    'another': df_train.copy(),
}

# %%
from mykaggle.feature.le import LE
from mykaggle.feature.score import Score
from mykaggle.feature.score_tbd import ScoreTBD
from mykaggle.feature.multi_platform import MultiPlatform
from mykaggle.feature.other_platforms import OtherPlatforms
from mykaggle.feature.ce import CE
from mykaggle.feature.original import Original
from mykaggle.feature.platform_to_pub_genre_once import PlatformToPubGenreOnce
from mykaggle.feature.genre_to_all_once import GenreToAllOnce
from mykaggle.feature.dev_to_category import DevToCategory
from mykaggle.feature.pub_to_category import PubToCategory
from mykaggle.feature.pub_count_500 import PubCount500
from mykaggle.feature.dev_to_category_pivot_pca_all import DevToCategoryPivotPCAAll
from mykaggle.feature.pub_to_category_pivot_pca_all import PubToCategoryPivotPCAAll
from mykaggle.feature.name_bow2 import NameBOW2
from mykaggle.feature.has_sales import HasSales
from mykaggle.feature.name_series_count import NameSeriesCount
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %%
fhp = settings['feature']

original_train = Original(train=True)
original_test = Original(train=False)
le_train = LE(train=True)
le_test = LE(train=False)
score_train = Score(train=True)
score_test = Score(train=False)
score_tbd_train = ScoreTBD(train=True)
score_tbd_test = ScoreTBD(train=False)
mp_train = MultiPlatform(train=True)
mp_test = MultiPlatform(train=False)
op_train = OtherPlatforms(train=True)
op_test = OtherPlatforms(train=False)
ce_train = CE(train=True)
ce_test = CE(train=False)
dtc_train = DevToCategory(train=True)
dtc_test = DevToCategory(train=False)
# ptc_train = PubToCategory(train=True)
# ptc_test = PubToCategory(train=False)
dtcpa_train = DevToCategoryPivotPCAAll(train=True, n_components=2)
dtcpa_test = DevToCategoryPivotPCAAll(train=False, n_components=2)
# ptcpa_train = PubToCategoryPivotPCAAll(train=True, n_components=settings['training']['pca_dim'])
# ptcpa_test = PubToCategoryPivotPCAAll(train=False, n_components=settings['training']['pca_dim'])
pftao_train = PlatformToPubGenreOnce(train=True, n_components=4)
pftao_test = PlatformToPubGenreOnce(train=False, n_components=4)
gtao_train = GenreToAllOnce(train=True, n_components=4)
gtao_test = GenreToAllOnce(train=False, n_components=4)
# p500_train = PubCount500(train=True)
# p500_test = PubCount500(train=False)
nbow_train = NameBOW2(
    True, fhp['name_bow_pca_dim'], fhp['name_bow_word_th1'], fhp['name_bow_word_th2'],
    fhp['name_bow_th1_upper'], fhp['name_bow_th2_upper'],
)
nbow_test = NameBOW2(
    False, fhp['name_bow_pca_dim'], fhp['name_bow_word_th1'], fhp['name_bow_word_th2'],
    fhp['name_bow_th1_upper'], fhp['name_bow_th2_upper'],
)
# has_sales_train = HasSales(train=True)
# has_sales_test = HasSales(train=False)
nsc_train = NameSeriesCount(train=True)
nsc_test = NameSeriesCount(train=False)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_f_train = df_base_train.copy()
df_f_test = df_base_test.copy()

df_f_train = original_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = original_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = le_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = le_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = score_tbd_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = score_tbd_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = mp_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = mp_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = op_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = op_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = ce_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = ce_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = dtc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = dtc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
# df_f_train = ptc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
# df_f_test = ptc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = dtcpa_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = dtcpa_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
# df_f_train = ptcpa_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
# df_f_test = ptcpa_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = pftao_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = pftao_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = gtao_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = gtao_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
# df_f_train = p500_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
# df_f_test = p500_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = nbow_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = nbow_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
# df_f_train = has_sales_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
# df_f_test = has_sales_test(df_f_test, others=test_others, use_cache=False, save_cache=True)
df_f_train = nsc_train(df_f_train, others=train_others, use_cache=False, save_cache=True)
df_f_test = nsc_test(df_f_test, others=test_others, use_cache=False, save_cache=True)

df_f_train.shape, df_f_test.shape
# Out:
# ((7317, 68), (8360, 68))

# %%
# drop some columns
df_f_train = df_f_train.drop(['le_Developer'], axis=1)
df_f_test = df_f_test.drop(['le_Developer'], axis=1)
df_f_train.shape, df_f_test.shape
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ((7317, 67), (8360, 67))

# %%
pd.set_option('display.max_rows', 500)
df_f_train.head(10).T
# Out:
#                                                    0           1           2  \
# id                                                 0           1           2
# Year_of_Release                                  NaN         NaN         NaN
# le_Platform                                       25          25          18
# le_Genre                                           0           0           0
# le_Rating                                          2           2           2
# Critic_Score                                    0.74        0.78        0.73
# User_Score                                      0.79        0.66        0.74
# Critic_Count                                      17          22           5
# User_Count                                        22          28          10
# is_tbd                                         False       False       False
# multi_pf_count                                     7           7           7
# other_platform_1                                   0           0           0
# other_platform_2                                   0           0           0
# other_platform_3                                   0           0           0
# other_platform_4                                   0           0           0
# other_platform_5                                   1           1           1
# other_platform_6                                   0           0           0
# other_platform_7                                   0           0           0
# other_platform_8                                   0           0           0
# other_platform_9                                   0           0           0
# other_platform_10                                  0           0           0
# other_platform_11                                  0           0           0
# other_platform_12                                  0           0           0
# other_platform_13                                  0           0           0
# other_platform_14                                  1           1           1
# other_platform_15                                  0           0           0
# other_platform_16                                  1           1           1
# other_platform_17                                  1           1           1
# other_platform_18                                  0           0           0
# other_platform_19                                  1           1           0
# other_platform_20                                  0           0           0
# other_platform_21                                  0           0           0
# other_platform_22                                  0           0           0
# other_platform_23                                  0           0           0
# other_platform_24                                  0           0           0
# other_platform_25                                  0           0           0
# other_platform_26                                  0           0           1
# other_platform_27                                  0           0           0
# other_platform_28                                  1           1           1
# other_platform_29                                  0           0           0
# other_platform_30                                  0           0           0
# count_id_groupby_Platform                       1248        1248        1147
# count_id_groupby_Genre                          3245        3245        3245
# count_id_groupby_Developer                        77          77          77
# count_id_groupby_Rating                         1365        1365        1365
# count_id_groupby_Year_of_Release                 NaN         NaN         NaN
# count_Publisher_groupby_Developer                 77          77          77
# count_Genre_groupby_Developer                     77          77          77
# count_Platform_groupby_Developer                  77          77          77
# count_Year_of_Release_groupby_Developer           65          65          65
# pca_0_count_id_pivotby_Developer_for_all    -53.7417    -53.7417    -53.7417
# pca_1_count_id_pivotby_Developer_for_all     33.8005     33.8005     33.8005
# pca_0_count_id_pivotby_Platform_for_all     -101.516    -101.516     76.2875
# pca_1_count_id_pivotby_Platform_for_all     -90.0215    -90.0215     181.813
# pca_2_count_id_pivotby_Platform_for_all      98.1288     98.1288   -0.665182
# pca_3_count_id_pivotby_Platform_for_all      297.447     297.447     222.293
# pca_0_count_id_pivotby_Genre_for_all        -30.7844    -30.7844    -30.7844
# pca_1_count_id_pivotby_Genre_for_all       -0.146996   -0.146996   -0.146996
# pca_2_count_id_pivotby_Genre_for_all          393.64      393.64      393.64
# pca_3_count_id_pivotby_Genre_for_all         273.716     273.716     273.716
# pca_0_name_bow_gt_count_5_3               -0.0148533  -0.0172314  -0.0148533
# pca_1_name_bow_gt_count_5_3               -0.0128409  -0.0167396  -0.0128409
# pca_2_name_bow_gt_count_5_3              -0.00859731  0.00246155 -0.00859731
# pca_3_name_bow_gt_count_5_3               -0.0210577  -0.0215568  -0.0210577
# num_word_series_1                                  1           1           1
# num_word_series_2                            3.14286           1     3.14286
# num_word_series_3                                  1     1.85714           1
#
#                                                    3           4           5  \
# id                                                 3           4           5
# Year_of_Release                                  NaN         NaN         NaN
# le_Platform                                        0          25          27
# le_Genre                                           0           0           0
# le_Rating                                          6           2           2
# Critic_Score                                     NaN        0.76        0.77
# User_Score                                       NaN        0.78        0.79
# Critic_Count                                     NaN           8          35
# User_Count                                       NaN          13          39
# is_tbd                                         False       False       False
# multi_pf_count                                     1           8           8
# other_platform_1                                   0           0           0
# other_platform_2                                   0           0           0
# other_platform_3                                   0           1           1
# other_platform_4                                   0           0           0
# other_platform_5                                   0           1           1
# other_platform_6                                   0           0           0
# other_platform_7                                   0           0           0
# other_platform_8                                   0           0           0
# other_platform_9                                   0           0           0
# other_platform_10                                  0           0           0
# other_platform_11                                  0           0           0
# other_platform_12                                  0           0           0
# other_platform_13                                  0           0           0
# other_platform_14                                  0           1           1
# other_platform_15                                  0           0           0
# other_platform_16                                  0           0           0
# other_platform_17                                  0           1           1
# other_platform_18                                  0           0           0
# other_platform_19                                  0           1           1
# other_platform_20                                  0           1           1
# other_platform_21                                  0           0           0
# other_platform_22                                  0           0           0
# other_platform_23                                  0           0           0
# other_platform_24                                  0           0           0
# other_platform_25                                  0           0           0
# other_platform_26                                  0           0           1
# other_platform_27                                  0           0           0
# other_platform_28                                  0           1           0
# other_platform_29                                  0           0           0
# other_platform_30                                  0           0           0
# count_id_groupby_Platform                        100        1248        1219
# count_id_groupby_Genre                          3245        3245        3245
# count_id_groupby_Developer                       NaN          77          77
# count_id_groupby_Rating                          NaN        1365        1365
# count_id_groupby_Year_of_Release                 NaN         NaN         NaN
# count_Publisher_groupby_Developer                NaN          77          77
# count_Genre_groupby_Developer                    NaN          77          77
# count_Platform_groupby_Developer                 NaN          77          77
# count_Year_of_Release_groupby_Developer          NaN          65          65
# pca_0_count_id_pivotby_Developer_for_all         NaN    -53.7417    -53.7417
# pca_1_count_id_pivotby_Developer_for_all         NaN     33.8005     33.8005
# pca_0_count_id_pivotby_Platform_for_all       1.2352    -101.516     62.7991
# pca_1_count_id_pivotby_Platform_for_all     -12.4934    -90.0215     -160.39
# pca_2_count_id_pivotby_Platform_for_all     -2.75793     98.1288    -91.6806
# pca_3_count_id_pivotby_Platform_for_all      -156.12     297.447     312.316
# pca_0_count_id_pivotby_Genre_for_all        -30.7844    -30.7844    -30.7844
# pca_1_count_id_pivotby_Genre_for_all       -0.146996   -0.146996   -0.146996
# pca_2_count_id_pivotby_Genre_for_all          393.64      393.64      393.64
# pca_3_count_id_pivotby_Genre_for_all         273.716     273.716     273.716
# pca_0_name_bow_gt_count_5_3               -0.0141544  -0.0156526  -0.0156526
# pca_1_name_bow_gt_count_5_3              -0.00991422  -0.0135166  -0.0135166
# pca_2_name_bow_gt_count_5_3              -0.00898547 -0.00957989 -0.00957989
# pca_3_name_bow_gt_count_5_3               -0.0177762  -0.0229361  -0.0229361
# num_word_series_1                                  1           1           1
# num_word_series_2                                  1           1           1
# num_word_series_3                                  1       1.875       1.875
#
#                                                    6           7           8  \
# id                                                 6           7           8
# Year_of_Release                                  NaN         NaN         NaN
# le_Platform                                       16          16          27
# le_Genre                                           0           0           0
# le_Rating                                          5           2           5
# Critic_Score                                    0.78        0.76        0.61
# User_Score                                       0.8        0.83        0.74
# Critic_Count                                      59          27          48
# User_Count                                       177          48         113
# is_tbd                                         False       False       False
# multi_pf_count                                     1           8           3
# other_platform_1                                   0           0           0
# other_platform_2                                   0           0           0
# other_platform_3                                   0           1           0
# other_platform_4                                   0           0           0
# other_platform_5                                   0           1           0
# other_platform_6                                   0           0           0
# other_platform_7                                   0           0           0
# other_platform_8                                   0           0           0
# other_platform_9                                   0           0           0
# other_platform_10                                  0           0           0
# other_platform_11                                  0           0           0
# other_platform_12                                  0           0           0
# other_platform_13                                  0           0           0
# other_platform_14                                  0           1           1
# other_platform_15                                  0           0           0
# other_platform_16                                  0           0           0
# other_platform_17                                  0           0           1
# other_platform_18                                  0           0           0
# other_platform_19                                  0           1           0
# other_platform_20                                  0           1           0
# other_platform_21                                  0           0           0
# other_platform_22                                  0           0           0
# other_platform_23                                  0           0           0
# other_platform_24                                  0           0           0
# other_platform_25                                  0           0           0
# other_platform_26                                  0           1           0
# other_platform_27                                  0           0           0
# other_platform_28                                  0           1           0
# other_platform_29                                  0           0           0
# other_platform_30                                  0           0           0
# count_id_groupby_Platform                       1296        1296        1219
# count_id_groupby_Genre                          3245        3245        3245
# count_id_groupby_Developer                         5          77           8
# count_id_groupby_Rating                         1518        1365        1518
# count_id_groupby_Year_of_Release                 NaN         NaN         NaN
# count_Publisher_groupby_Developer                  5          77           8
# count_Genre_groupby_Developer                      5          77           8
# count_Platform_groupby_Developer                   5          77           8
# count_Year_of_Release_groupby_Developer            4          65           6
# pca_0_count_id_pivotby_Developer_for_all    -1.44141    -53.7417    -1.50418
# pca_1_count_id_pivotby_Developer_for_all   -0.718124     33.8005    0.366927
# pca_0_count_id_pivotby_Platform_for_all      104.947     104.947     62.7991
# pca_1_count_id_pivotby_Platform_for_all     -6.67457    -6.67457     -160.39
# pca_2_count_id_pivotby_Platform_for_all     -107.848    -107.848    -91.6806
# pca_3_count_id_pivotby_Platform_for_all      360.262     360.262     312.316
# pca_0_count_id_pivotby_Genre_for_all        -30.7844    -30.7844    -30.7844
# pca_1_count_id_pivotby_Genre_for_all       -0.146996   -0.146996   -0.146996
# pca_2_count_id_pivotby_Genre_for_all          393.64      393.64      393.64
# pca_3_count_id_pivotby_Genre_for_all         273.716     273.716     273.716
# pca_0_name_bow_gt_count_5_3               -0.0130932  -0.0156526  -0.0270075
# pca_1_name_bow_gt_count_5_3              -0.00952923  -0.0135166  -0.0384588
# pca_2_name_bow_gt_count_5_3              -0.00789799 -0.00957989 -0.00809499
# pca_3_name_bow_gt_count_5_3               -0.0161675  -0.0229361  -0.0309266
# num_word_series_1                                  1           1           1
# num_word_series_2                                  1           1     12.6667
# num_word_series_3                                  1       1.875          13
#
#                                                    9
# id                                                 9
# Year_of_Release                                  NaN
# le_Platform                                       16
# le_Genre                                           0
# le_Rating                                          5
# Critic_Score                                    0.63
# User_Score                                       0.7
# Critic_Count                                      33
# User_Count                                       100
# is_tbd                                         False
# multi_pf_count                                     3
# other_platform_1                                   0
# other_platform_2                                   0
# other_platform_3                                   0
# other_platform_4                                   0
# other_platform_5                                   0
# other_platform_6                                   0
# other_platform_7                                   0
# other_platform_8                                   0
# other_platform_9                                   0
# other_platform_10                                  0
# other_platform_11                                  0
# other_platform_12                                  0
# other_platform_13                                  0
# other_platform_14                                  1
# other_platform_15                                  0
# other_platform_16                                  0
# other_platform_17                                  0
# other_platform_18                                  0
# other_platform_19                                  0
# other_platform_20                                  0
# other_platform_21                                  0
# other_platform_22                                  0
# other_platform_23                                  0
# other_platform_24                                  0
# other_platform_25                                  0
# other_platform_26                                  0
# other_platform_27                                  0
# other_platform_28                                  1
# other_platform_29                                  0
# other_platform_30                                  0
# count_id_groupby_Platform                       1296
# count_id_groupby_Genre                          3245
# count_id_groupby_Developer                         8
# count_id_groupby_Rating                         1518
# count_id_groupby_Year_of_Release                 NaN
# count_Publisher_groupby_Developer                  8
# count_Genre_groupby_Developer                      8
# count_Platform_groupby_Developer                   8
# count_Year_of_Release_groupby_Developer            6
# pca_0_count_id_pivotby_Developer_for_all    -1.50418
# pca_1_count_id_pivotby_Developer_for_all    0.366927
# pca_0_count_id_pivotby_Platform_for_all      104.947
# pca_1_count_id_pivotby_Platform_for_all     -6.67457
# pca_2_count_id_pivotby_Platform_for_all     -107.848
# pca_3_count_id_pivotby_Platform_for_all      360.262
# pca_0_count_id_pivotby_Genre_for_all        -30.7844
# pca_1_count_id_pivotby_Genre_for_all       -0.146996
# pca_2_count_id_pivotby_Genre_for_all          393.64
# pca_3_count_id_pivotby_Genre_for_all         273.716
# pca_0_name_bow_gt_count_5_3               -0.0270075
# pca_1_name_bow_gt_count_5_3               -0.0384588
# pca_2_name_bow_gt_count_5_3              -0.00809499
# pca_3_name_bow_gt_count_5_3               -0.0309266
# num_word_series_1                                  1
# num_word_series_2                            12.6667
# num_word_series_3                                 13

# %%
@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)
# Out:
# /home/jupyter/workspace/atmacup8/.venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mykaggle.feature.te import TE
from mykaggle.feature.te_other_aggs import TEOtherAggs
from mykaggle.feature.te_year_platform import TEYearPlatform
from mykaggle.feature.te_year_genre import TEYearGenre
from mykaggle.feature.year_rank4 import YearRank4
from mykaggle.feature.platform_time_diff import PlatformTimeDiff


# te_train = TE(train=True)
# te_test = TE(train=False)
# te_oa_train = TEOtherAggs(train=True)
# te_oa_test = TEOtherAggs(train=False)
# te_yp_train = TEYearPlatform(train=True)
# te_yp_test = TEYearPlatform(train=False)
# te_yg_train = TEYearGenre(train=True)
# te_yg_test = TEYearGenre(train=False)
year_rank_train = YearRank4(train=True)
year_rank_test = YearRank4(train=False)
ptdiff_train = PlatformTimeDiff(train=True)
ptdiff_test = PlatformTimeDiff(train=False)


def get_oof_feature(
    df_train: pd.DataFrame, df_valid: pd.DataFrame, y_train: np.ndarray,
    df_train_original: pd.DataFrame, df_valid_original: pd.DataFrame
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    df_train.loc[:, 'target'] = y_train.copy()
    _train_others = copy.deepcopy(train_others)
    _test_others = copy.deepcopy(test_others)
    _train_others['main'] = df_train_original.copy().reset_index().drop('index', axis=1)
    _train_others['another'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['main'] = df_valid_original.copy().reset_index().drop('index', axis=1)
    _test_others['another'] = df_train_original.copy().reset_index().drop('index', axis=1)
    df_train = df_train.reset_index().drop('index', axis=1)
    df_valid = df_valid.reset_index().drop('index', axis=1)
#     df_train = te_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_oa_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_oa_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_yp_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_yp_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
#     df_train = te_yg_train(df_train, others=_train_others, use_cache=False, save_cache=False)
#     df_valid = te_yg_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = year_rank_train(df_train, others=_train_others, use_cache=False, save_cache=False)
    df_valid = year_rank_test(df_valid, others=_test_others, use_cache=False, save_cache=False)
    df_train = ptdiff_train(df_train, others=_train_others, use_cache=False, save_cache=True)
    df_valid = ptdiff_test(df_valid, others=_test_others, use_cache=False, save_cache=True)
    return df_train.drop(['id', 'target'], axis=1), df_valid.drop('id', axis=1)

# %%
def train(
    settings: Dict[str, Any],
    logger: MLLogger,
    df: pd.DataFrame,
    df_original: pd.DataFrame,
    y: np.ndarray,
    ckptdir: Path
) -> Tuple:
    logger.log_params(settings['training'])
    logger.log_params(settings['feature'])
    logger.log_params(settings['lgbm_params'])
    X = df.copy()
    lgbm_params = settings['lgbm_params']
    models = []
    oof_pred = np.zeros(shape=(len(y), lgbm_params['num_class']), dtype=np.float)
    importances = pd.DataFrame()
#     split_file = f'{settings["training"]["validation"]}_{settings["training"]["num_folds"]}fold.pkl'
#     splits = pickle.load(open(datadir / split_file, 'rb'))
    splitter = KFold(n_splits=settings["training"]["num_folds"], shuffle=True, random_state=settings['seed'])

    for i, (train_idx, valid_idx) in enumerate(splitter.split(X)): 
        x_train, y_train = X.iloc[train_idx], y[train_idx]
        x_valid, y_valid = X.iloc[valid_idx], y[valid_idx]
        x_train, x_valid = get_oof_feature(
            x_train, x_valid, y_train,
            df_original.iloc[train_idx], df_original.iloc[valid_idx]
        )
        train_data = lgb.Dataset(x_train.values, label=y_train)
        valid_data = lgb.Dataset(x_valid.values, label=y_valid)

        with timer(prefix='train fold={} '.format(i + 1)):
            clf = lgb.train(
                lgbm_params,
                train_data, 
                num_boost_round=settings['training']['num_rounds'],
                valid_names=['train', 'valid'],
                valid_sets=[train_data, valid_data],  
                early_stopping_rounds=settings['training']['early_stopping_rounds'],
#                 feval='multi_logloss',
                verbose_eval=settings['training']['verbose_eval']
            )
        pred_i = clf.predict(x_valid.values)
        oof_pred[valid_idx, :] = pred_i
        models.append(clf)
        importances = compute_importances(importances, x_train.columns, models[i], fold=i)
        fold_score = log_loss(y_valid, pred_i)
        logger.log_metric(f'rmsle_fold_{i}', fold_score)
        print(f'Fold {i} RMSLE: {fold_score:.4f}')
        clf.save_model(str(ckptdir / f'model.txt'))
        logger.log_artifact(str(ckptdir / f'model.txt'), artifact_path=f'{i}')

    score = log_loss(y, oof_pred)
    logger.log_metric(f'RMSLE', score)
    print('FINISHED; whole score: {:.4f}'.format(score))
    save_importances(importances, ckptdir)
    return oof_pred, models, score, importances

# %%
def visualize_oof(
    y_true: np.ndarray, y_pred: np.ndarray
) -> None:
    plt.figure(figsize=(5, 5))
    plt.plot([-100, 5000], [-100, 5000], color='black')
    plt.scatter(y_true, y_pred, alpha=0.2)
    plt.xlim(-100, 4000)
    plt.ylim(-100, 4000)
    plt.xlabel('True')
    plt.ylabel('Pred')


def predict(
    models: List[lgb.Booster],
    df_test: pd.DataFrame,
    df_train: pd.DataFrame,
    df_test_original: pd.DataFrame
) -> np.ndarray:
    '''
    fold 分のモデルと test の特徴 dataframe を受け取って、予測したものを返します。
    :param models: kfold 分のモデル
    :param test_df: test dataset の特徴
    :return: 予測
    '''
    _, test = get_oof_feature(
        df_train.copy(), df_test.copy(), df_train['target'].values, df_train.copy(), df_test_original.copy()
    )
    preds = np.array([model.predict(test) for model in models])
#     preds = np.expm1(preds)
    preds = np.mean(preds, axis=0)
    return preds

    
def submit(preds: np.ndarray, ckptdir: Path) -> pd.DataFrame:
    '''
    test data の prediction を受け取って submission ファイルを作成します。
    :param preds: test data の予測
    :param ckptdir: 保存場所
    :return: submission df
    '''
    sub_df = pd.DataFrame({ target_column: preds })
    sub_df.to_csv(ckptdir / f'{settings["name"]}.csv', index=False)
    return sub_df

# %%
logger = MLLogger('cfiken', ckptdir)

# %%
with logger.start(experiment_name=settings['competition'], run_name=settings['name']):
    oof, models, cv, importances = train(
        settings,
        logger,
        df_f_train,
        df_train,
        df_train.loc[:, 'target'].values,
        ckptdir
    )
    preds = predict(models, df_f_test, df_train, df_test)
    sub_df = submit(preds, ckptdir)
# Out:
# Training until validation scores don't improve for 1000 rounds
# [20]	train's multi_logloss: 1.57227	valid's multi_logloss: 2.19196
# [40]	train's multi_logloss: 1.02899	valid's multi_logloss: 1.85273
# [60]	train's multi_logloss: 0.726979	valid's multi_logloss: 1.66317
# [80]	train's multi_logloss: 0.535158	valid's multi_logloss: 1.54993
# [100]	train's multi_logloss: 0.404172	valid's multi_logloss: 1.47876
# [120]	train's multi_logloss: 0.312938	valid's multi_logloss: 1.44115
# [140]	train's multi_logloss: 0.246637	valid's multi_logloss: 1.4206
# [160]	train's multi_logloss: 0.197651	valid's multi_logloss: 1.41379
# [180]	train's multi_logloss: 0.159959	valid's multi_logloss: 1.41477
# [200]	train's multi_logloss: 0.13047	valid's multi_logloss: 1.41986
# [220]	train's multi_logloss: 0.106924	valid's multi_logloss: 1.4323
# [240]	train's multi_logloss: 0.088044	valid's multi_logloss: 1.44739
# [260]	train's multi_logloss: 0.0726695	valid's multi_logloss: 1.46746
# [280]	train's multi_logloss: 0.0601571	valid's multi_logloss: 1.48912
# [300]	train's multi_logloss: 0.049945	valid's multi_logloss: 1.51564
# [320]	train's multi_logloss: 0.0416	valid's multi_logloss: 1.53774
# [340]	train's multi_logloss: 0.0347933	valid's multi_logloss: 1.56098
# [360]	train's multi_logloss: 0.0290988	valid's multi_logloss: 1.58844
# [380]	train's multi_logloss: 0.0243608	valid's multi_logloss: 1.61458
# [400]	train's multi_logloss: 0.0204054	valid's multi_logloss: 1.63955
# [420]	train's multi_logloss: 0.0171267	valid's multi_logloss: 1.66628
# [440]	train's multi_logloss: 0.0143905	valid's multi_logloss: 1.69395
# [460]	train's multi_logloss: 0.0121409	valid's multi_logloss: 1.72034
# [480]	train's multi_logloss: 0.0102657	valid's multi_logloss: 1.74272
# [500]	train's multi_logloss: 0.00871313	valid's multi_logloss: 1.7632
# [520]	train's multi_logloss: 0.00740798	valid's multi_logloss: 1.78466
# [540]	train's multi_logloss: 0.00631597	valid's multi_logloss: 1.80633
# [560]	train's multi_logloss: 0.00536853	valid's multi_logloss: 1.82091
# [580]	train's multi_logloss: 0.00460441	valid's multi_logloss: 1.83338
# [600]	train's multi_logloss: 0.00396532	valid's multi_logloss: 1.84762
# [620]	train's multi_logloss: 0.00341964	valid's multi_logloss: 1.86387
# [640]	train's multi_logloss: 0.00296052	valid's multi_logloss: 1.87853
# [660]	train's multi_logloss: 0.00257527	valid's multi_logloss: 1.89457
# [680]	train's multi_logloss: 0.00225332	valid's multi_logloss: 1.90648
# [700]	train's multi_logloss: 0.00198157	valid's multi_logloss: 1.91762
# [720]	train's multi_logloss: 0.0017507	valid's multi_logloss: 1.92892
# [740]	train's multi_logloss: 0.00156205	valid's multi_logloss: 1.93896
# [760]	train's multi_logloss: 0.00139694	valid's multi_logloss: 1.94866
# [780]	train's multi_logloss: 0.00125788	valid's multi_logloss: 1.95797
# [800]	train's multi_logloss: 0.00114025	valid's multi_logloss: 1.96963
# [820]	train's multi_logloss: 0.00104284	valid's multi_logloss: 1.98079
# [840]	train's multi_logloss: 0.000962043	valid's multi_logloss: 1.99069
# [860]	train's multi_logloss: 0.000890349	valid's multi_logloss: 1.99844
# [880]	train's multi_logloss: 0.000831092	valid's multi_logloss: 2.00882
# [900]	train's multi_logloss: 0.000781294	valid's multi_logloss: 2.01474
# [920]	train's multi_logloss: 0.000738985	valid's multi_logloss: 2.0201
# [940]	train's multi_logloss: 0.000703232	valid's multi_logloss: 2.0264
# [960]	train's multi_logloss: 0.000672873	valid's multi_logloss: 2.03274
# [980]	train's multi_logloss: 0.000646897	valid's multi_logloss: 2.03845
# [1000]	train's multi_logloss: 0.000624492	valid's multi_logloss: 2.04362
# [1020]	train's multi_logloss: 0.000605382	valid's multi_logloss: 2.05022
# [1040]	train's multi_logloss: 0.000589518	valid's multi_logloss: 2.05623
# [1060]	train's multi_logloss: 0.000575641	valid's multi_logloss: 2.06122
# [1080]	train's multi_logloss: 0.000564041	valid's multi_logloss: 2.06497
# [1100]	train's multi_logloss: 0.000554171	valid's multi_logloss: 2.06917
# [1120]	train's multi_logloss: 0.000545649	valid's multi_logloss: 2.07299
# [1140]	train's multi_logloss: 0.000538141	valid's multi_logloss: 2.07543
# [1160]	train's multi_logloss: 0.000531934	valid's multi_logloss: 2.07813
# Early stopping, best iteration is:
# [167]	train's multi_logloss: 0.183514	valid's multi_logloss: 1.41352
# train fold=1 207.981[s]
# Fold 0 RMSLE: 1.4135
# Training until validation scores don't improve for 1000 rounds
# [20]	train's multi_logloss: 1.57578	valid's multi_logloss: 2.18062
# [40]	train's multi_logloss: 1.03482	valid's multi_logloss: 1.83626
# [60]	train's multi_logloss: 0.732019	valid's multi_logloss: 1.64795
# [80]	train's multi_logloss: 0.539026	valid's multi_logloss: 1.5347
# [100]	train's multi_logloss: 0.409777	valid's multi_logloss: 1.46987
# [120]	train's multi_logloss: 0.318626	valid's multi_logloss: 1.43234
# [140]	train's multi_logloss: 0.251959	valid's multi_logloss: 1.40907
# [160]	train's multi_logloss: 0.202061	valid's multi_logloss: 1.4007
# [180]	train's multi_logloss: 0.163793	valid's multi_logloss: 1.39911
# [200]	train's multi_logloss: 0.133865	valid's multi_logloss: 1.40707
# [220]	train's multi_logloss: 0.109978	valid's multi_logloss: 1.41671
# [240]	train's multi_logloss: 0.0909173	valid's multi_logloss: 1.4302
# [260]	train's multi_logloss: 0.0753041	valid's multi_logloss: 1.44631
# [280]	train's multi_logloss: 0.0625789	valid's multi_logloss: 1.4673
# [300]	train's multi_logloss: 0.052113	valid's multi_logloss: 1.49084
# [320]	train's multi_logloss: 0.0433859	valid's multi_logloss: 1.51339
# [340]	train's multi_logloss: 0.0361758	valid's multi_logloss: 1.53718
# [360]	train's multi_logloss: 0.0302245	valid's multi_logloss: 1.56173
# [380]	train's multi_logloss: 0.0252466	valid's multi_logloss: 1.58706
# [400]	train's multi_logloss: 0.0211451	valid's multi_logloss: 1.61109
# [420]	train's multi_logloss: 0.0177321	valid's multi_logloss: 1.6357
# [440]	train's multi_logloss: 0.0149171	valid's multi_logloss: 1.65831
# [460]	train's multi_logloss: 0.0125455	valid's multi_logloss: 1.67975
# [480]	train's multi_logloss: 0.0106098	valid's multi_logloss: 1.69909
# [500]	train's multi_logloss: 0.00895843	valid's multi_logloss: 1.71836
# [520]	train's multi_logloss: 0.00758515	valid's multi_logloss: 1.73478
# [540]	train's multi_logloss: 0.0064465	valid's multi_logloss: 1.74961
# [560]	train's multi_logloss: 0.00546756	valid's multi_logloss: 1.76466
# [580]	train's multi_logloss: 0.00464071	valid's multi_logloss: 1.77505
# [600]	train's multi_logloss: 0.00397057	valid's multi_logloss: 1.78616
# [620]	train's multi_logloss: 0.00339056	valid's multi_logloss: 1.7962
# [640]	train's multi_logloss: 0.00290447	valid's multi_logloss: 1.80726
# [660]	train's multi_logloss: 0.00249377	valid's multi_logloss: 1.8169
# [680]	train's multi_logloss: 0.00214589	valid's multi_logloss: 1.82655
# [700]	train's multi_logloss: 0.00185429	valid's multi_logloss: 1.83537
# [720]	train's multi_logloss: 0.0016062	valid's multi_logloss: 1.84354
# [740]	train's multi_logloss: 0.00139879	valid's multi_logloss: 1.85045
# [760]	train's multi_logloss: 0.00122772	valid's multi_logloss: 1.85891
# [780]	train's multi_logloss: 0.00108482	valid's multi_logloss: 1.86574
# [800]	train's multi_logloss: 0.000957085	valid's multi_logloss: 1.87297
# [820]	train's multi_logloss: 0.000851279	valid's multi_logloss: 1.87857
# [840]	train's multi_logloss: 0.000764436	valid's multi_logloss: 1.88546
# [860]	train's multi_logloss: 0.000686844	valid's multi_logloss: 1.89276
# [880]	train's multi_logloss: 0.000622634	valid's multi_logloss: 1.89891
# [900]	train's multi_logloss: 0.000568066	valid's multi_logloss: 1.90646
# [920]	train's multi_logloss: 0.000520727	valid's multi_logloss: 1.91197
# [940]	train's multi_logloss: 0.000481403	valid's multi_logloss: 1.91698
# [960]	train's multi_logloss: 0.000447951	valid's multi_logloss: 1.92176
# [980]	train's multi_logloss: 0.000420305	valid's multi_logloss: 1.92507
# [1000]	train's multi_logloss: 0.00039639	valid's multi_logloss: 1.9279
# [1020]	train's multi_logloss: 0.000376505	valid's multi_logloss: 1.93224
# [1040]	train's multi_logloss: 0.000358983	valid's multi_logloss: 1.93374
# [1060]	train's multi_logloss: 0.000344173	valid's multi_logloss: 1.93745
# [1080]	train's multi_logloss: 0.000331509	valid's multi_logloss: 1.93965
# [1100]	train's multi_logloss: 0.000321115	valid's multi_logloss: 1.94245
# [1120]	train's multi_logloss: 0.000311882	valid's multi_logloss: 1.9458
# [1140]	train's multi_logloss: 0.000304198	valid's multi_logloss: 1.94916
# [1160]	train's multi_logloss: 0.000297392	valid's multi_logloss: 1.95281
# Early stopping, best iteration is:
# [169]	train's multi_logloss: 0.183651	valid's multi_logloss: 1.39841
# train fold=2 207.416[s]
# Fold 1 RMSLE: 1.3984
# Training until validation scores don't improve for 1000 rounds
# [20]	train's multi_logloss: 1.58235	valid's multi_logloss: 2.14566
# [40]	train's multi_logloss: 1.03513	valid's multi_logloss: 1.80074
# [60]	train's multi_logloss: 0.729996	valid's multi_logloss: 1.60889
# [80]	train's multi_logloss: 0.53701	valid's multi_logloss: 1.49534
# [100]	train's multi_logloss: 0.405918	valid's multi_logloss: 1.42445
# [120]	train's multi_logloss: 0.313318	valid's multi_logloss: 1.38461
# [140]	train's multi_logloss: 0.24669	valid's multi_logloss: 1.362
# [160]	train's multi_logloss: 0.197291	valid's multi_logloss: 1.35339
# [180]	train's multi_logloss: 0.159763	valid's multi_logloss: 1.35576
# [200]	train's multi_logloss: 0.129909	valid's multi_logloss: 1.3605
# [220]	train's multi_logloss: 0.106307	valid's multi_logloss: 1.37224
# [240]	train's multi_logloss: 0.0878139	valid's multi_logloss: 1.38834
# [260]	train's multi_logloss: 0.0727681	valid's multi_logloss: 1.40405
# [280]	train's multi_logloss: 0.0604658	valid's multi_logloss: 1.42545
# [300]	train's multi_logloss: 0.0503332	valid's multi_logloss: 1.44754
# [320]	train's multi_logloss: 0.0418308	valid's multi_logloss: 1.4695
# [340]	train's multi_logloss: 0.034822	valid's multi_logloss: 1.49338
# [360]	train's multi_logloss: 0.029067	valid's multi_logloss: 1.51622
# [380]	train's multi_logloss: 0.0243031	valid's multi_logloss: 1.54139
# [400]	train's multi_logloss: 0.0202953	valid's multi_logloss: 1.56388
# [420]	train's multi_logloss: 0.017014	valid's multi_logloss: 1.58635
# [440]	train's multi_logloss: 0.0142218	valid's multi_logloss: 1.60628
# [460]	train's multi_logloss: 0.0119192	valid's multi_logloss: 1.62554
# [480]	train's multi_logloss: 0.00999875	valid's multi_logloss: 1.64498

# %%
visualize_oof(np.expm1(df_train.loc[:, 'target'].values), np.expm1(oof))
